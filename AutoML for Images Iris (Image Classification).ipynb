# %% [markdown]
# # AutoML for Images
#
# ### Iris Classification usecase with Azure ML and AutoML for Images (Image Classification Task)

# %% [markdown]
# ## Setup
# > To use this notebook, **you will need to install the private preview package for AutoML for Images from the private index**.

# %%
#!pip install --upgrade "azureml-train-core<0.1.1" "azureml-train-automl<0.1.1" "azureml-contrib-dataset<0.1.1" --extra-index-url "https://azuremlsdktestpypi.azureedge.net/automl_for_images_private_preview/"

# %%
#!pip install seaborn

# %% [markdown]
# ## 1. Informations

# %%
import numpy as np
import json
import os
import urllib
from zipfile import ZipFile
import seaborn as sns
import pandas as pd

# %%
import sys
print("Python version =", sys.version)
# Out:
# Python version = 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 19:07:31)
# [GCC 7.3.0]

# %%
import datetime
now = datetime.datetime.now()
print("Today =", now)
# Out:
# Today = 2021-05-18 13:24:54.418454

# %%
import azureml.core
print("You are using Azure ML version", azureml.core.VERSION)
# Out:
# You are using Azure ML version 0.1.0.36994775

# %%
# Your local platform
import platform,socket,re,uuid,json,psutil,logging

def getSystemInfo():
    try:
        info={}
        info['Platform']=platform.system()
        info['Platform-release']=platform.release()
        info['Platform-version']=platform.version()
        info['Architecture']=platform.machine()
        info['Hostname']=socket.gethostname()
        info['IP-address']=socket.gethostbyname(socket.gethostname())
        info['MAC-address']=':'.join(re.findall('..', '%012x' % uuid.getnode()))
        info['Processor']=platform.processor()
        info['RAM']=str(round(psutil.virtual_memory().total / (1024.0 **3)))+" Go"
        return json.dumps(info)
    except Exception as e:
        logging.exception(e)

json.loads(getSystemInfo())
# Out:
# {'Platform': 'Linux',
#  'Platform-release': '5.4.0-1046-azure',
#  'Platform-version': '#48~18.04.1-Ubuntu SMP Tue Apr 13 19:41:38 UTC 2021',
#  'Architecture': 'x86_64',
#  'Hostname': 'standardd15v2',
#  'IP-address': '127.0.0.1',
#  'MAC-address': '43:02:c0:77:ab:c1',
#  'Processor': 'x86_64',
#  'RAM': '138 Go'}

# %% [markdown]
# ## 2. Workspace setup
# In order to train and deploy models in Azure ML, you will first need to set up a workspace.
#
# An [Azure ML Workspace](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#workspace) is an Azure resource that organizes and coordinates the actions of many other Azure resources to assist in executing and sharing machine learning workflows. In particular, an Azure ML Workspace coordinates storage, databases, and compute resources providing added functionality for machine learning experimentation, deployment, inference, and the monitoring of deployed models.
#
# > Create an Azure ML Workspace within your Azure subscription, or load an existing workspace.

# %%
subscription_id='tobereplaced'   
resource_group='automlvision-rg'   
workspace_name='automlvision'

# %%
from azureml.core import Workspace
try:
   ws = Workspace(subscription_id = subscription_id, resource_group = resource_group, workspace_name = workspace_name)
   ws.write_config()
   print("OK")
except:
   print("Error: Workspace not found")
# Out:
# OK

# %%
from azureml.core import Workspace
ws = Workspace.from_config()

# %%
ws.name, ws.resource_group
# Out:
# ('automlvision', 'automlvision-rg')

# %% [markdown]
# ## 3. Azure ML GPU Compute target setup
# **You will need to provide a [Compute Target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) that will be used for your AutoML model training.** <br><br>
# **AutoML models for image tasks require GPU SKUs and support NC and ND families.** We recommend using the NCsv3-series (with v100 GPUs) for faster training. Using a compute target with a multi-GPU VM SKU will leverage the multiple GPUs to speed up training. Additionally, setting up a compute target with multiple nodes will allow for faster model training by leveraging parallelism, when tuning hyperparameters for your model.

# %%
from azureml.core.compute import AmlCompute, ComputeTarget

cluster_name = "gpu-iris-classif"

try:
    compute_target = ws.compute_targets[cluster_name]
    print('Found existing compute target.')
except KeyError:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_NC6', #GPU cluster
                                                           idle_seconds_before_scaledown=1800, #Time out
                                                           min_nodes=0, 
                                                           max_nodes=4)

    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

# Can poll for a minimum number of nodes and for a specific timeout.
# If no min_node_count is provided, it will use the scale settings for the cluster.
compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
# Out:
# Creating a new compute target...
# Creating.........
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
# Compute status
compute_target.provisioning_state
# Out:
# 'Succeeded'

# %%
# Compute cluster information
compute_target.get_status().serialize()
# Out:
# {'currentNodeCount': 0,
#  'targetNodeCount': 0,
#  'nodeStateCounts': {'preparingNodeCount': 0,
#   'runningNodeCount': 0,
#   'idleNodeCount': 0,
#   'unusableNodeCount': 0,
#   'leavingNodeCount': 0,
#   'preemptedNodeCount': 0},
#  'allocationState': 'Steady',
#  'allocationStateTransitionTime': '2021-05-18T13:25:33.451000+00:00',
#  'errors': None,
#  'creationTime': '2021-05-18T13:24:59.893257+00:00',
#  'modifiedTime': '2021-05-18T13:25:45.592791+00:00',
#  'provisioningState': 'Succeeded',
#  'provisioningStateTransitionTime': None,
#  'scaleSettings': {'minNodeCount': 0,
#   'maxNodeCount': 4,
#   'nodeIdleTimeBeforeScaleDown': 'PT1800S'},
#  'vmPriority': 'Dedicated',
#  'vmSize': 'STANDARD_NC6'}

# %%
# Compute VM size
compute_target.vm_size
# Out:
# 'STANDARD_NC6'

# %%
#List of available compute clusters in your Azure ML workspace
listcomputeservers = ws.compute_targets
for list in listcomputeservers:
    print(list)
# Out:
# cluster-aks-gpu
# computeinstancenbooks
# DefLabelNC6
# standardd15v2
# gpu-iris-classif

# %% [markdown]
# ## 4. Experiment Setup
# Create an [Experiment](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#experiment) in your workspace to track your model training runs

# %%
from azureml.core import Experiment

experiment_name = 'AutomlImages-IrisClassif' #Name of your experimentation
experiment = Experiment(ws, name=experiment_name)

# %%
experiment
# Out:
# Experiment(Name: AutomlImages-IrisClassif,
# Workspace: automlvision)

# %% [markdown]
# ## 5. Dataset with input Training Data
# In order to generate models for computer vision, you will need to bring in labeled image data as input for model training in the form of an AzureML Labeled Dataset. You can either use a Labeled Dataset that you have exported from a Data Labeling project, or create a new Labeled Dataset with your labeled training data

# %%
# %pwd
# Out:
# '/mnt/batch/tasks/shared/LS_root/mounts/clusters/standardd15v2/code/Users/seretkow/AutoML Iris Classification'

# %%
# %mkdir irisimages

# %%
# %cd irisimages
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/standardd15v2/code/Users/seretkow/AutoML Iris Classification/irisimages

# %%
# Download images files
download_url = 'https://github.com/retkowsky/AutoMLforImages/blob/main/images/iris.zip?raw=true'
zip_file = 'iris.zip'

urllib.request.urlretrieve(download_url, filename=zip_file)

# Unzip files
with ZipFile(zip_file, 'r') as zip:
    print('>> Unzip the zip file...')
    zip.extractall()
    print('Done!')
    
# Delete the downloaded zip file
print("\n>> Deleting the zip file...")
os.remove(zip_file)
print("Done!")
# Out:
# >> Unzip the zip file...
# Done!
#
# >> Deleting the zip file...
# Done!

# %% [markdown]
# ### List of images files

# %%
# We have some images for the tags
print(os.listdir('.'))
# Out:
# ['setosa', 'versicolour', 'virginica']

# %%
for root, _, files in os.walk('.'):
    print("Dir:", root, "with", len(files), "images files.")
# Out:
# Dir: . with 0 images files.
# Dir: ./setosa with 66 images files.
# Dir: ./versicolour with 268 images files.
# Dir: ./virginica with 84 images files.

# %%
# %ls *
# Out:
# setosa:
# 'setosa (1).jpg'*   'setosa (25).jpg'*  'setosa (40).jpg'*  'setosa (56).jpg'*
# 'setosa (10).jpg'*  'setosa (26).jpg'*  'setosa (41).jpg'*  'setosa (57).jpg'*
# 'setosa (11).jpg'*  'setosa (27).jpg'*  'setosa (42).jpg'*  'setosa (58).jpg'*
# 'setosa (12).jpg'*  'setosa (28).jpg'*  'setosa (43).jpg'*  'setosa (59).jpg'*
# 'setosa (13).jpg'*  'setosa (29).jpg'*  'setosa (44).jpg'*  'setosa (6).jpg'*
# 'setosa (14).jpg'*  'setosa (3).jpg'*   'setosa (45).jpg'*  'setosa (60).jpg'*
# 'setosa (15).jpg'*  'setosa (30).jpg'*  'setosa (46).jpg'*  'setosa (61).jpg'*
# 'setosa (16).jpg'*  'setosa (31).jpg'*  'setosa (47).jpg'*  'setosa (62).jpg'*
# 'virginica (13).jpg'*  'virginica (39).jpg'*  'virginica (64).jpg'*
# 'virginica (14).jpg'*  'virginica (4).jpg'*   'virginica (65).jpg'*
# 'virginica (15).jpg'*  'virginica (40).jpg'*  'virginica (66).jpg'*
# 'virginica (16).jpg'*  'virginica (41).jpg'*  'virginica (67).jpg'*
# 'virginica (17).jpg'*  'virginica (42).jpg'*  'virginica (68).jpg'*
# 'virginica (18).jpg'*  'virginica (43).jpg'*  'virginica (69).jpg'*
# 'virginica (19).jpg'*  'virginica (44).jpg'*  'virginica (7).jpg'*
# 'virginica (2).jpg'*   'virginica (45).jpg'*  'virginica (70).jpg'*
# 'virginica (20).jpg'*  'virginica (46).jpg'*  'virginica (71).jpg'*
# 'virginica (21).jpg'*  'virginica (47).jpg'*  'virginica (72).jpg'*
# 'virginica (22).jpg'*  'virginica (48).jpg'*  'virginica (73).jpg'*
# 'virginica (23).jpg'*  'virginica (49).jpg'*  'virginica (74).jpg'*
# 'virginica (24).jpg'*  'virginica (5).jpg'*   'virginica (75).jpg'*
# 'virginica (25).jpg'*  'virginica (50).jpg'*  'virginica (76).jpg'*
# 'virginica (26).jpg'*  'virginica (51).jpg'*  'virginica (77).jpg'*
# 'virginica (27).jpg'*  'virginica (52).jpg'*  'virginica (78).jpg'*
# 'virginica (28).jpg'*  'virginica (53).jpg'*  'virginica (79).jpg'*
# 'virginica (29).jpg'*  'virginica (54).jpg'*  'virginica (8).jpg'*
# 'virginica (3).jpg'*   'virginica (55).jpg'*  'virginica (80).jpg'*
# 'virginica (30).jpg'*  'virginica (56).jpg'*  'virginica (81).jpg'*
# 'virginica (31).jpg'*  'virginica (57).jpg'*  'virginica (82).jpg'*
# 'virginica (32).jpg'*  'virginica (58).jpg'*  'virginica (83).jpg'*
# 'virginica (33).jpg'*  'virginica (59).jpg'*  'virginica (84).jpg'*
# 'virginica (34).jpg'*  'virginica (6).jpg'*   'virginica (9).jpg'*

# %% [markdown]
# ### Some samples:

# %%
from IPython.display import Image
sample_image = '../irisimages/setosa/setosa (1).jpg'
Image(filename=sample_image)

# %%
sample_image = '../irisimages/versicolour/versicolour (1).jpg'
Image(filename=sample_image)

# %%
sample_image = '../irisimages/virginica/virginica (1).jpg'
Image(filename=sample_image)

# %% [markdown]
# ### Convert the downloaded data to JSONL

# %%
# %cd ..
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/standardd15v2/code/Users/seretkow/AutoML Iris Classification

# %%
src = "irisimages/"

train_validation_ratio = 5

# Retrieving default datastore that got automatically created when we setup a workspace
workspaceblobstore = ws.get_default_datastore().name

# Path to the training and validation files
train_annotations_file = os.path.join(src, "train_annotations.jsonl")
validation_annotations_file = os.path.join(src, "validation_annotations.jsonl")

# sample json line dictionary
json_line_sample = \
    {
        "image_url": "AmlDatastore://" + workspaceblobstore + "/"
                     + os.path.basename(os.path.dirname(src)),
        "label": "",
        "label_confidence": 1.0
    }

index = 0
# Scan each sub directary and generate jsonl line
with open(train_annotations_file, 'w') as train_f:
    with open(validation_annotations_file, 'w') as validation_f:
        for className in os.listdir(src):
            subDir = src + className
            if not os.path.isdir(subDir):
                continue
            # Scan each sub directary
            print("Parsing " + subDir)
            for image in os.listdir(subDir):
                json_line = dict(json_line_sample)
                json_line["image_url"] += f"/{className}/{image}"
                json_line["label"] = className

                if index % train_validation_ratio == 0:
                    # validation annotation
                    validation_f.write(json.dumps(json_line) + "\n")
                else:
                    # train annotation
                    train_f.write(json.dumps(json_line) + "\n")
                index += 1
# Out:
# Parsing irisimages/setosa
# Parsing irisimages/versicolour
# Parsing irisimages/virginica

# %% [markdown]
# ### Upload the JSONL file and images to Datastore
# In order to use the data for training in Azure ML, we upload it to our Azure ML Workspace via a [Datastore](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores). The datastore provides a mechanism for you to upload/download data, and interact with it from your remote compute targets. It is an abstraction over Azure Storage.

# %%
# Retrieving default datastore that got automatically created when we setup a workspace
ds = ws.get_default_datastore()
ds.upload(src_dir='./irisimages/', target_path='irisimages')
# Out:
# Uploading an estimated of 420 files
# Uploading ./irisimages/train_annotations.jsonl
# Uploaded ./irisimages/train_annotations.jsonl, 1 files out of an estimated total of 420
# Uploading ./irisimages/validation_annotations.jsonl
# Uploaded ./irisimages/validation_annotations.jsonl, 2 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (1).jpg
# Uploaded ./irisimages/setosa/setosa (1).jpg, 3 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (10).jpg
# Uploaded ./irisimages/setosa/setosa (10).jpg, 4 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (11).jpg
# Uploaded ./irisimages/setosa/setosa (11).jpg, 5 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (12).jpg
# Uploaded ./irisimages/setosa/setosa (12).jpg, 6 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (13).jpg
# Uploaded ./irisimages/setosa/setosa (13).jpg, 7 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (14).jpg
# Uploaded ./irisimages/setosa/setosa (14).jpg, 8 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (15).jpg
# Uploaded ./irisimages/setosa/setosa (15).jpg, 9 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (16).jpg
# Uploaded ./irisimages/setosa/setosa (16).jpg, 10 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (17).jpg
# Uploaded ./irisimages/setosa/setosa (17).jpg, 11 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (18).jpg
# Uploaded ./irisimages/setosa/setosa (18).jpg, 12 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (19).jpg
# Uploaded ./irisimages/setosa/setosa (19).jpg, 13 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (2).jpg
# Uploaded ./irisimages/setosa/setosa (2).jpg, 14 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (20).jpg
# Uploaded ./irisimages/setosa/setosa (20).jpg, 15 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (21).jpg
# Uploaded ./irisimages/setosa/setosa (21).jpg, 16 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (22).jpg
# Uploaded ./irisimages/setosa/setosa (22).jpg, 17 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (23).jpg
# Uploaded ./irisimages/setosa/setosa (23).jpg, 18 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (24).jpg
# Uploaded ./irisimages/setosa/setosa (24).jpg, 19 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (25).jpg
# Uploaded ./irisimages/setosa/setosa (25).jpg, 20 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (26).jpg
# Uploaded ./irisimages/setosa/setosa (26).jpg, 21 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (27).jpg
# Uploaded ./irisimages/setosa/setosa (27).jpg, 22 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (28).jpg
# Uploaded ./irisimages/setosa/setosa (28).jpg, 23 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (29).jpg
# Uploaded ./irisimages/setosa/setosa (29).jpg, 24 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (3).jpg
# Uploaded ./irisimages/setosa/setosa (3).jpg, 25 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (30).jpg
# Uploaded ./irisimages/setosa/setosa (30).jpg, 26 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (31).jpg
# Uploaded ./irisimages/setosa/setosa (31).jpg, 27 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (32).jpg
# Uploaded ./irisimages/setosa/setosa (32).jpg, 28 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (33).jpg
# Uploaded ./irisimages/setosa/setosa (33).jpg, 29 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (34).jpg
# Uploaded ./irisimages/setosa/setosa (34).jpg, 30 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (35).jpg
# Uploaded ./irisimages/setosa/setosa (35).jpg, 31 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (36).jpg
# Uploaded ./irisimages/setosa/setosa (36).jpg, 32 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (37).jpg
# Uploaded ./irisimages/setosa/setosa (37).jpg, 33 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (38).jpg
# Uploaded ./irisimages/setosa/setosa (38).jpg, 34 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (39).jpg
# Uploaded ./irisimages/setosa/setosa (39).jpg, 35 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (4).jpg
# Uploaded ./irisimages/setosa/setosa (4).jpg, 36 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (40).jpg
# Uploaded ./irisimages/setosa/setosa (40).jpg, 37 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (41).jpg
# Uploaded ./irisimages/setosa/setosa (41).jpg, 38 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (42).jpg
# Uploaded ./irisimages/setosa/setosa (42).jpg, 39 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (43).jpg
# Uploaded ./irisimages/setosa/setosa (43).jpg, 40 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (44).jpg
# Uploaded ./irisimages/setosa/setosa (44).jpg, 41 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (45).jpg
# Uploaded ./irisimages/setosa/setosa (45).jpg, 42 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (46).jpg
# Uploaded ./irisimages/setosa/setosa (46).jpg, 43 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (47).jpg
# Uploaded ./irisimages/setosa/setosa (47).jpg, 44 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (48).jpg
# Uploaded ./irisimages/setosa/setosa (48).jpg, 45 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (49).jpg
# Uploaded ./irisimages/setosa/setosa (49).jpg, 46 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (5).jpg
# Uploaded ./irisimages/setosa/setosa (5).jpg, 47 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (50).jpg
# Uploaded ./irisimages/setosa/setosa (50).jpg, 48 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (51).jpg
# Uploaded ./irisimages/setosa/setosa (51).jpg, 49 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (52).jpg
# Uploaded ./irisimages/setosa/setosa (52).jpg, 50 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (53).jpg
# Uploaded ./irisimages/setosa/setosa (53).jpg, 51 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (54).jpg
# Uploaded ./irisimages/setosa/setosa (54).jpg, 52 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (55).jpg
# Uploaded ./irisimages/setosa/setosa (55).jpg, 53 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (56).jpg
# Uploaded ./irisimages/setosa/setosa (56).jpg, 54 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (57).jpg
# Uploaded ./irisimages/setosa/setosa (57).jpg, 55 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (58).jpg
# Uploaded ./irisimages/setosa/setosa (58).jpg, 56 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (59).jpg
# Uploaded ./irisimages/setosa/setosa (59).jpg, 57 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (6).jpg
# Uploaded ./irisimages/setosa/setosa (6).jpg, 58 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (60).jpg
# Uploaded ./irisimages/setosa/setosa (60).jpg, 59 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (61).jpg
# Uploaded ./irisimages/setosa/setosa (61).jpg, 60 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (62).jpg
# Uploaded ./irisimages/setosa/setosa (62).jpg, 61 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (63).jpg
# Uploaded ./irisimages/setosa/setosa (63).jpg, 62 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (64).jpg
# Uploaded ./irisimages/setosa/setosa (64).jpg, 63 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (65).jpg
# Uploaded ./irisimages/setosa/setosa (65).jpg, 64 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (66).jpg
# Uploaded ./irisimages/setosa/setosa (66).jpg, 65 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (7).jpg
# Uploaded ./irisimages/setosa/setosa (7).jpg, 66 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (8).jpg
# Uploaded ./irisimages/setosa/setosa (8).jpg, 67 files out of an estimated total of 420
# Uploading ./irisimages/setosa/setosa (9).jpg
# Uploaded ./irisimages/setosa/setosa (9).jpg, 68 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour (1).jpg
# Uploaded ./irisimages/versicolour/versicolour (1).jpg, 69 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour (10).jpg
# Uploaded ./irisimages/versicolour/versicolour (10).jpg, 70 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour (100).jpg
# Uploaded ./irisimages/versicolour/versicolour (100).jpg, 71 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour (101).jpg
# Uploaded ./irisimages/versicolour/versicolour (101).jpg, 72 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour (102).jpg
# Uploaded ./irisimages/versicolour/versicolour (102).jpg, 73 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour (103).jpg
# Uploaded ./irisimages/versicolour/versicolour (103).jpg, 74 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour (104).jpg
# Uploaded ./irisimages/versicolour/versicolour (104).jpg, 75 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour (105).jpg
# Uploaded ./irisimages/versicolour/versicolour (105).jpg, 76 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour (106).jpg
# Uploaded ./irisimages/versicolour/versicolour (106).jpg, 77 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour (107).jpg
# Uploaded ./irisimages/versicolour/versicolour (107).jpg, 78 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour (108).jpg
# Uploaded ./irisimages/versicolour/versicolour (108).jpg, 79 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour (109).jpg
# Uploaded ./irisimages/versicolour/versicolour (109).jpg, 80 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour (11).jpg
# Uploaded ./irisimages/versicolour/versicolour (11).jpg, 81 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour (110).jpg
# Uploaded ./irisimages/versicolour/versicolour (110).jpg, 82 files out of an estimated total of 420
# Uploading ./irisimages/versicolour/versicolour
files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (57).jpg
# Uploaded ./irisimages/virginica/virginica (57).jpg, 389 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (58).jpg
# Uploaded ./irisimages/virginica/virginica (58).jpg, 390 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (59).jpg
# Uploaded ./irisimages/virginica/virginica (59).jpg, 391 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (6).jpg
# Uploaded ./irisimages/virginica/virginica (6).jpg, 392 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (60).jpg
# Uploaded ./irisimages/virginica/virginica (60).jpg, 393 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (61).jpg
# Uploaded ./irisimages/virginica/virginica (61).jpg, 394 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (62).jpg
# Uploaded ./irisimages/virginica/virginica (62).jpg, 395 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (63).jpg
# Uploaded ./irisimages/virginica/virginica (63).jpg, 396 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (64).jpg
# Uploaded ./irisimages/virginica/virginica (64).jpg, 397 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (65).jpg
# Uploaded ./irisimages/virginica/virginica (65).jpg, 398 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (66).jpg
# Uploaded ./irisimages/virginica/virginica (66).jpg, 399 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (68).jpg
# Uploaded ./irisimages/virginica/virginica (68).jpg, 400 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (69).jpg
# Uploaded ./irisimages/virginica/virginica (69).jpg, 401 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (7).jpg
# Uploaded ./irisimages/virginica/virginica (7).jpg, 402 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (73).jpg
# Uploaded ./irisimages/virginica/virginica (73).jpg, 403 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (74).jpg
# Uploaded ./irisimages/virginica/virginica (74).jpg, 404 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (67).jpg
# Uploaded ./irisimages/virginica/virginica (67).jpg, 405 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (70).jpg
# Uploaded ./irisimages/virginica/virginica (70).jpg, 406 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (71).jpg
# Uploaded ./irisimages/virginica/virginica (71).jpg, 407 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (72).jpg
# Uploaded ./irisimages/virginica/virginica (72).jpg, 408 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (75).jpg
# Uploaded ./irisimages/virginica/virginica (75).jpg, 409 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (76).jpg
# Uploaded ./irisimages/virginica/virginica (76).jpg, 410 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (77).jpg
# Uploaded ./irisimages/virginica/virginica (77).jpg, 411 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (78).jpg
# Uploaded ./irisimages/virginica/virginica (78).jpg, 412 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (79).jpg
# Uploaded ./irisimages/virginica/virginica (79).jpg, 413 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (8).jpg
# Uploaded ./irisimages/virginica/virginica (8).jpg, 414 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (80).jpg
# Uploaded ./irisimages/virginica/virginica (80).jpg, 415 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (81).jpg
# Uploaded ./irisimages/virginica/virginica (81).jpg, 416 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (82).jpg
# Uploaded ./irisimages/virginica/virginica (82).jpg, 417 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (83).jpg
# Uploaded ./irisimages/virginica/virginica (83).jpg, 418 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (84).jpg
# Uploaded ./irisimages/virginica/virginica (84).jpg, 419 files out of an estimated total of 420
# Uploading ./irisimages/virginica/virginica (9).jpg
# Uploaded ./irisimages/virginica/virginica (9).jpg, 420 files out of an estimated total of 420
# Uploaded 420 files
# $AZUREML_DATAREFERENCE_c5c76d41db39456c8967a4890a3b2676

# %% [markdown]
# Finally, we need to create an Azure ML [Dataset](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores) from the data we uploaded to the Datastore. We create one dataset for training and one for validation.

# %%
from azureml.contrib.dataset.labeled_dataset import _LabeledDatasetFactory, LabeledDatasetTask
from azureml.core import Dataset

training_dataset_name = 'IrisTrainingDataset'
if training_dataset_name in ws.datasets:
    training_dataset = ws.datasets.get(training_dataset_name)
    print('Found the training dataset', training_dataset_name)
else:
    # create training dataset
    training_dataset = _LabeledDatasetFactory.from_json_lines(
        task=LabeledDatasetTask.IMAGE_CLASSIFICATION, path=ds.path('irisimages/train_annotations.jsonl'))
    training_dataset = training_dataset.register(workspace=ws, name=training_dataset_name)
    
# create validation dataset
validation_dataset_name = "IrisValidationDataset"
if validation_dataset_name in ws.datasets:
    validation_dataset = ws.datasets.get(validation_dataset_name)
    print('Found the validation dataset', validation_dataset_name)
else:
    validation_dataset = _LabeledDatasetFactory.from_json_lines(
        task=LabeledDatasetTask.IMAGE_CLASSIFICATION, path=ds.path('irisimages/validation_annotations.jsonl'))
    validation_dataset = validation_dataset.register(workspace=ws, name=validation_dataset_name)

print()
print("Training dataset name:" + training_dataset.name)
print("Validation dataset name:" + validation_dataset.name)
# Out:
# Training dataset name:IrisTrainingDataset
# Validation dataset name:IrisValidationDataset

# %% [markdown]
# Validation dataset is optional. If no validation dataset is specified, by default 20% of your training data will be used for validation. You can control the percentage using the `split_ratio` argument - please refer to the documentation for more details.
#
# This is what the training dataset looks like

# %%
df=training_dataset.to_pandas_dataframe()

# %%
df.head()
# Out:
#                                            image_url   label  label_confidence
# 0  StreamInfo(AmlDatastore://irisimages/setosa/se...  setosa               1.0
# 1  StreamInfo(AmlDatastore://irisimages/setosa/se...  setosa               1.0
# 2  StreamInfo(AmlDatastore://irisimages/setosa/se...  setosa               1.0
# 3  StreamInfo(AmlDatastore://irisimages/setosa/se...  setosa               1.0
# 4  StreamInfo(AmlDatastore://irisimages/setosa/se...  setosa               1.0

# %%
df.shape
# Out:
# (334, 3)

# %%
# Counts images by labels
df['label'].value_counts()
# Out:
# versicolour    215
# virginica       67
# setosa          52
# Name: label, dtype: int64

# %%
# Percentage values
df['label'].value_counts(normalize=True)
# Out:
# versicolour    0.643713
# virginica      0.200599
# setosa         0.155689
# Name: label, dtype: float64

# %%
# Distribution
sns.catplot(x="label", kind="count", data=df, height=5).set(title='Number of images for our Computer Vision model')

# %% [markdown]
# ## 6. Configuring your AutoML run for image tasks
# AutoML allows you to easily train models for Image Classification, Object Detection & Instance Segmentation on your image data. You can control the model algorithm to be used, specify hyperparameter values for your model as well as perform a sweep across the hyperparameter space to generate an optimal model. Parameters for configuring your AutoML runs for image related tasks are specified using the 'AutoMLImageConfig' - please refer to the [documentation](https://github.com/swatig007/automlForImages#readme) for the details on the parameters that can be used and their values.

# %% [markdown]
# When using AutoML for image tasks, you need to specify the model algorithms using the `model_name` parameter. You can either specify a single model or choose to sweep over multiple ones.<br><br> **Currently supported model algorithms for image classification: 'resnet18', 'resnet34', 'resnet50', 'mobilenetv2', 'seresnext'.**
#
# ### Using default hyperparameter values for the specified algorithm
#
# Before doing a large sweep to search for the optimal models and hyperparameters, we recommend trying the default values to get a first baseline. Next, you can explore multiple hyperparameters for the same model before sweeping over multiple models and their parameters. This is for employing a more iterative approach, because with multiple models and multiple hyperparameters for each (as we showcase in the next section), the search space grows exponentially and you need more iterations to find optimal configurations.
#
# If you wish to use the default hyperparameter values for a given algorithm (say **resnet50**), you can specify the config for your AutoML Image runs as follows:

# %%
from azureml.train.automl import AutoMLImageConfig
from azureml.train.hyperdrive import RandomParameterSampling
from azureml.train.hyperdrive import GridParameterSampling
from azureml.train.hyperdrive import choice

# %%
# AutoML Configuration
image_config_resnet50 = AutoMLImageConfig(task='image-classification', # AutoML Vision task
                                          compute_target=compute_target, # Compute target
                                          training_data=training_dataset, # Training dataset
                                          validation_data=validation_dataset, # Validation dataset
                                          hyperparameter_sampling=GridParameterSampling({'model_name': 
                                                                                        choice('resnet50')})) # CV Model

# %% [markdown]
# ## 7. Submitting an AutoML run for Computer Vision tasks
# Once you've created the config settings for your run, **you can submit an AutoML run** using the config in order to train a vision model using your training dataset.

# %%
automl_image_run = experiment.submit(image_config_resnet50)
# Out:
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>AutomlImages-IrisClassif</td><td>AutoML_a61599f9-6714-4251-b2ff-e7c332b41048</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_a61599f9-6714-4251-b2ff-e7c332b41048?wsid=/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/automlvision-rg/workspaces/automlvision&amp;tid=72f988bf-86f1-41af-91ab-2d7cd011db47" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %%
automl_image_run.wait_for_completion(wait_post_processing=True) # Wait until automl run is finished
# Out:
# {'runId': 'AutoML_a61599f9-6714-4251-b2ff-e7c332b41048',
#  'target': 'gpu-iris-classif',
#  'status': 'Completed',
#  'startTimeUtc': '2021-05-18T13:30:26.094724Z',
#  'endTimeUtc': '2021-05-18T13:40:08.009666Z',
#  'properties': {'num_iterations': '1',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'accuracy',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': None,
#   'target': 'gpu-iris-classif',
#   'AMLSettingsJsonString': '{"path":null,"name":"AutomlImages-IrisClassif","subscription_id":"70b8f39e-8863-49f7-b6ba-34a80799550c","resource_group":"automlvision-rg","workspace_name":"automlvision","region":"westeurope","compute_target":"gpu-iris-classif","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":false,"enable_run_restructure":false,"start_auxiliary_runs_before_parent_complete":false,"enable_code_generation":false,"iterations":1,"primary_metric":"accuracy","task_type":"image-classification","data_script":null,"test_size":0.0,"validation_size":0.0,"n_cross_validations":null,"y_min":null,"y_max":null,"num_classes":null,"featurization":"off","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":1,"max_concurrent_iterations":1,"iteration_timeout_minutes":null,"mem_in_mb":null,"enforce_time_on_windows":false,"experiment_timeout_minutes":8640,"experiment_exit_score":null,"whitelist_models":null,"blacklist_algos":["TensorFlowDNN","TensorFlowLinearRegressor"],"supported_models":[],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":false,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"STANDARD_NC6","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":true,"scenario":"Vision","environment_label":null,"save_mlflow":false,"force_text_dnn":false,"enable_feature_sweeping":true,"enable_early_stopping":false,"early_stopping_n_iters":10,"arguments":null,"dataset_id":"08370273-2e1e-43ec-bfa6-7eb48aac15ef","hyperdrive_config":{"max_total_jobs":1,"max_concurrent_jobs":1,"generator_config":{"name":"GRID","parameter_space":"{\\"model_name\\": [\\"choice\\", [[\\"resnet50\\"]]]}","properties":null},"policy_config":null},"validation_dataset_id":"35f4e587-a4ea-495d-a5b4-a50b64a95726","run_source":"AutoMLImageSDK","metrics":null,"enable_metric_confidence":false,"enable_ensembling":false,"enable_stack_ensembling":false,"ensemble_iterations":null,"enable_tf":false,"enable_subsampling":false,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"allowed_private_models":[],"label_column_name":"label","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":false}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"08370273-2e1e-43ec-bfa6-7eb48aac15ef\\"}, \\"validation_data\\": {\\"datasetId\\": \\"35f4e587-a4ea-495d-a5b4-a50b64a95726\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': 'False',
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'automl',
#   'display_task_type': 'image-classification',
#   'dependencies_versions': '{"azureml-widgets": "1.27.0", "azureml-train": "1.27.0", "azureml-train-restclients-hyperdrive": "0.1.0.36994775", "azureml-train-core": "0.1.0.36994775", "azureml-train-automl": "0.1.0.36994775", "azureml-train-automl-runtime": "0.1.0.36994775", "azureml-train-automl-client": "0.1.0.36994775", "azureml-tensorboard": "1.27.0", "azureml-telemetry": "0.1.0.36994775", "azureml-sdk": "1.27.0", "azureml-samples": "0+unknown", "azureml-pipeline": "1.27.0", "azureml-pipeline-steps": "1.27.0", "azureml-pipeline-core": "1.27.0", "azureml-opendatasets": "1.27.0", "azureml-model-management-sdk": "1.0.1b6.post1", "azureml-mlflow": "1.27.0", "azureml-interpret": "0.1.0.36994775", "azureml-explain-model": "1.27.0", "azureml-defaults": "0.1.0.36994775", "azureml-dataset-runtime": "0.1.0.36994775", "azureml-dataprep": "2.15.0", "azureml-dataprep-rslex": "1.13.0", "azureml-dataprep-native": "33.0.0", "azureml-datadrift": "1.27.0", "azureml-core": "0.1.0.36994775", "azureml-contrib-services": "1.27.0", "azureml-contrib-server": "1.27.0", "azureml-contrib-reinforcementlearning": "1.27.0", "azureml-contrib-pipeline-steps": "1.27.0", "azureml-contrib-notebook": "1.27.0", "azureml-contrib-gbdt": "1.27.0", "azureml-contrib-fairness": "1.27.0", "azureml-contrib-dataset": "0.1.0.36994775", "azureml-cli-common": "1.27.0", "azureml-automl-runtime": "0.1.0.36994775", "azureml-automl-dnn-nlp": "1.27.0", "azureml-automl-core": "0.1.0.36994775", "azureml-accel-models": "1.27.0"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'environment_cpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_cpu_label': 'Latest',
#   'environment_gpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_gpu_label': 'Latest',
#   'root_attribution': 'automl',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://westeurope.api.azureml.ms/jasmine/v1.0/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourceGroups/automlvision-rg/providers/Microsoft.MachineLearningServices/workspaces/automlvision/experimentids/cafd1ca6-4147-416c-bdd6-387ce3fe105b/cancel/AutoML_a61599f9-6714-4251-b2ff-e7c332b41048',
#   'ClientSdkVersion': '1.28.0',
#   'snapshotId': '00000000-0000-0000-0000-000000000000'},
#  'inputDatasets': [{'dataset': {'id': '08370273-2e1e-43ec-bfa6-7eb48aac15ef'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}, {'dataset': {'id': '35f4e587-a4ea-495d-a5b4-a50b64a95726'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'validation_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Serge Retkowsky'}

# %%
automl_image_run.id
# Out:
# 'AutoML_a61599f9-6714-4251-b2ff-e7c332b41048'

# %%
experiment
# Out:
# Experiment(Name: AutomlImages-IrisClassif,
# Workspace: automlvision)

# %%
# List of all the AutoML for Images metrics values
automlvisionmetrics = automl_image_run.get_metrics()
metricsdf=pd.DataFrame(automl_image_run.get_metrics()) # Convert to a pandas df
metricsdf
# Out:
#     average_class_precision  average_sample_f2_score  average_class_recall  \
# 0                    21.032                   63.095                33.333
# 1                    21.032                   63.095                33.333
# 2                    45.857                   51.190                51.224
# 3                    54.878                   65.476                38.095
# 4                    55.417                   67.857                42.857
# 5                    68.506                   58.333                45.888
# 6                    89.912                   72.619                51.120
# 7                    71.693                   75.000                65.063
# 8                    84.876                   76.190                63.940
# 9                    85.873                   77.381                61.556
# 10                   89.912                   72.619                50.700
# 11                   83.918                   70.238                48.531
# 12                   76.859                   71.429                52.244
# 13                   84.222                   71.429                50.492
# 14                   77.858                   73.810                57.917
#
#        iou  average_class_f1_score  average_class_f2_score  precision  recall  \
# 0   63.095                  25.791                  29.842     21.032  33.333
# 1   63.095                  25.791                  29.842     21.032  33.333
# 2   51.190                  47.551                  49.453     45.857  51.224
# 3   65.476                  34.506                  35.792     54.878  38.095
# 4   67.857                  41.381                  41.362     55.417  42.857
# 5   58.333                  43.140                  44.302     68.506  45.888
# 6   72.619                  54.934                  51.375     89.912  51.120
# 7   75.000                  61.336                  63.065     71.693  65.063
# 8   76.190                  62.382                  62.799     84.876  63.940
# 9   77.381                  66.919                  62.827     85.873  61.556
# 10  72.619                  54.903                  51.042     89.912  50.700
# 11  70.238                  50.558                  48.295     83.918  48.531
# 12  71.429                  55.556                  52.642     76.859  52.244
# 13  71.429                  53.750                  50.681     84.222  50.492
# 14  73.810                  62.105                  58.866     77.858  57.917
#
#     average_sample_f1_score  accuracy
# 0                    63.095    63.095
# 1                    63.095    63.095
# 2                    51.190    51.190
# 3                    65.476    65.476
# 4                    67.857    67.857
# 5                    58.333    58.333
# 6                    72.619    72.619
# 7                    75.000    75.000
# 8                    76.190    76.190
# 9                    77.381    77.381
# 10                   72.619    72.619
# 11                   70.238    70.238
# 12                   71.429    71.429
# 13                   71.429    71.429
# 14                   73.810    73.810

# %%
# Let's plot the accuracy metric for the CV model, save the graph to a jpg file and log it to the Azure ML experiment
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (15,7))
plt.plot(automlvisionmetrics['accuracy'], 'r-', lw=4, alpha=.6)
plt.xlabel('iterations', fontsize=10)
plt.ylabel('accuracy', fontsize=10)
plt.title('resnet50 CV model accuracy', fontsize=12)

plt.savefig('accuracy_resnet50.jpg', dpi=150) # Saving image in a jpg file
automl_image_run.log_image(name='accuracy_resnet50.jpg', plot=plt) # Logging the graph into the Azure ML experiment

plt.show()

# %%
# Checking the output graph
# !ls accuracy_resnet50.jpg -l
# Out:
# -rwxrwxrwx 1 root root 105699 May 18 13:40 accuracy_resnet50.jpg

# %%
# You can view the jpg file in the experiment
experiment
# Out:
# Experiment(Name: AutomlImages-IrisClassif,
# Workspace: automlvision)

# %% [markdown]
# ## Let's improve using additionals models & hyperparameter tuning

# %% [markdown]
# ### Hyperparameter sweeping for your AutoML models for computer vision tasks
#
# When using AutoML for Images, you can perform a hyperparameter sweep over a defined parameter space, to find the optimal model. In this example, we sweep over the hyperparameters for each algorithm, **choosing from a range of values for learning_rate, optimizer, lr_scheduler, etc, to generate a model with the optimal 'accuracy'.** If hyperparameter values are not specified, then default values are used for the specified algorithm.
#
# We use **Random Sampling to pick samples from this parameter space and try a total of 20 iterations** with these different samples, running 4 iterations at a time on our compute target, which has been previously set up using 4 nodes. Please note that the more parameters the space has, the more iterations you need to find optimal models.
#
# We also leverage the **Bandit early termination policy** that terminates poor performing configs (those that are not within 20% slack of the best perfroming config), thus significantly saving compute resources.

# %% [markdown]
# ### List of model available for Image classification:
# Resnet18, Resnet34, Resnet50, Mobilenetv2, seresnext

# %%
from azureml.train.automl import AutoMLImageConfig
from azureml.train.hyperdrive import GridParameterSampling, RandomParameterSampling, BayesianParameterSampling
from azureml.train.hyperdrive import BanditPolicy, HyperDriveConfig, PrimaryMetricGoal
from azureml.train.hyperdrive import choice, uniform

#Options for the parameter space
parameter_space = {
    'model': choice(
        {
            'model_name': choice('seresnext', 'resnet50', 'resnet34'),
            'learning_rate': uniform(0.0001, 0.01),
            'optimizer': choice('sgd', 'adam'),
            'layers_to_freeze': choice(0, 1, 2, 3),

        },
        {
            'model_name': choice('seresnext'),
        }
    )
}

#Options for the tuning part
tuning_settings = {
    'iterations': 20,
    'max_concurrent_iterations': 4, 
    'hyperparameter_sampling': RandomParameterSampling(parameter_space),  
    'policy': BanditPolicy(evaluation_interval=2, slack_factor=0.2, delay_evaluation=6) # Bandit strategy
}

#Configuration definition
automl_image_config = AutoMLImageConfig(task='image-classification', # AutoML task
                                        compute_target=compute_target, # Compute Target
                                        training_data=training_dataset, # Training dataset
                                        validation_data=validation_dataset, # Validation dataset
                                        primary_metric='accuracy', # AutoML Metric
                                        **tuning_settings)

# %%
automl_image_run = experiment.submit(automl_image_config)
# Out:
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>AutomlImages-IrisClassif</td><td>AutoML_d6fce25d-b5b7-4c6a-8334-ac2c098402fc</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_d6fce25d-b5b7-4c6a-8334-ac2c098402fc?wsid=/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/automlvision-rg/workspaces/automlvision&amp;tid=72f988bf-86f1-41af-91ab-2d7cd011db47" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %%
automl_image_run.wait_for_completion(wait_post_processing=True)
# Out:
# {'runId': 'AutoML_d6fce25d-b5b7-4c6a-8334-ac2c098402fc',
#  'target': 'gpu-iris-classif',
#  'status': 'Completed',
#  'startTimeUtc': '2021-05-18T13:46:34.369066Z',
#  'endTimeUtc': '2021-05-18T14:10:45.902533Z',
#  'properties': {'num_iterations': '1',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'accuracy',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': None,
#   'target': 'gpu-iris-classif',
#   'AMLSettingsJsonString': '{"path":null,"name":"AutomlImages-IrisClassif","subscription_id":"70b8f39e-8863-49f7-b6ba-34a80799550c","resource_group":"automlvision-rg","workspace_name":"automlvision","region":"westeurope","compute_target":"gpu-iris-classif","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":false,"enable_run_restructure":false,"start_auxiliary_runs_before_parent_complete":false,"enable_code_generation":false,"iterations":1,"primary_metric":"accuracy","task_type":"image-classification","data_script":null,"test_size":0.0,"validation_size":0.0,"n_cross_validations":null,"y_min":null,"y_max":null,"num_classes":null,"featurization":"off","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":1,"max_concurrent_iterations":1,"iteration_timeout_minutes":null,"mem_in_mb":null,"enforce_time_on_windows":false,"experiment_timeout_minutes":8640,"experiment_exit_score":null,"whitelist_models":null,"blacklist_algos":["TensorFlowDNN","TensorFlowLinearRegressor"],"supported_models":[],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":false,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"STANDARD_NC6","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":true,"scenario":"Vision","environment_label":null,"save_mlflow":false,"force_text_dnn":false,"enable_feature_sweeping":true,"enable_early_stopping":false,"early_stopping_n_iters":10,"arguments":null,"dataset_id":"08370273-2e1e-43ec-bfa6-7eb48aac15ef","hyperdrive_config":{"max_total_jobs":20,"max_concurrent_jobs":4,"generator_config":{"name":"RANDOM","parameter_space":"{\\"model\\": [\\"choice\\", [[{\\"model_name\\": [\\"choice\\", [[\\"seresnext\\", \\"resnet50\\", \\"resnet34\\"]]], \\"learning_rate\\": [\\"uniform\\", [0.0001, 0.01]], \\"optimizer\\": [\\"choice\\", [[\\"sgd\\", \\"adam\\"]]], \\"layers_to_freeze\\": [\\"choice\\", [[0, 1, 2, 3]]]}, {\\"model_name\\": [\\"choice\\", [[\\"seresnext\\"]]]}]]]}","properties":null},"policy_config":{"name":"Bandit","properties":{"evaluation_interval":2,"delay_evaluation":6,"slack_factor":0.2}}},"validation_dataset_id":"35f4e587-a4ea-495d-a5b4-a50b64a95726","run_source":"AutoMLImageSDK","metrics":null,"enable_metric_confidence":false,"enable_ensembling":false,"enable_stack_ensembling":false,"ensemble_iterations":null,"enable_tf":false,"enable_subsampling":false,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"allowed_private_models":[],"label_column_name":"label","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":false}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"08370273-2e1e-43ec-bfa6-7eb48aac15ef\\"}, \\"validation_data\\": {\\"datasetId\\": \\"35f4e587-a4ea-495d-a5b4-a50b64a95726\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': 'False',
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'automl',
#   'display_task_type': 'image-classification',
#   'dependencies_versions': '{"azureml-widgets": "1.27.0", "azureml-train": "1.27.0", "azureml-train-restclients-hyperdrive": "0.1.0.36994775", "azureml-train-core": "0.1.0.36994775", "azureml-train-automl": "0.1.0.36994775", "azureml-train-automl-runtime": "0.1.0.36994775", "azureml-train-automl-client": "0.1.0.36994775", "azureml-tensorboard": "1.27.0", "azureml-telemetry": "0.1.0.36994775", "azureml-sdk": "1.27.0", "azureml-samples": "0+unknown", "azureml-pipeline": "1.27.0", "azureml-pipeline-steps": "1.27.0", "azureml-pipeline-core": "1.27.0", "azureml-opendatasets": "1.27.0", "azureml-model-management-sdk": "1.0.1b6.post1", "azureml-mlflow": "1.27.0", "azureml-interpret": "0.1.0.36994775", "azureml-explain-model": "1.27.0", "azureml-defaults": "0.1.0.36994775", "azureml-dataset-runtime": "0.1.0.36994775", "azureml-dataprep": "2.15.0", "azureml-dataprep-rslex": "1.13.0", "azureml-dataprep-native": "33.0.0", "azureml-datadrift": "1.27.0", "azureml-core": "0.1.0.36994775", "azureml-contrib-services": "1.27.0", "azureml-contrib-server": "1.27.0", "azureml-contrib-reinforcementlearning": "1.27.0", "azureml-contrib-pipeline-steps": "1.27.0", "azureml-contrib-notebook": "1.27.0", "azureml-contrib-gbdt": "1.27.0", "azureml-contrib-fairness": "1.27.0", "azureml-contrib-dataset": "0.1.0.36994775", "azureml-cli-common": "1.27.0", "azureml-automl-runtime": "0.1.0.36994775", "azureml-automl-dnn-nlp": "1.27.0", "azureml-automl-core": "0.1.0.36994775", "azureml-accel-models": "1.27.0"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'environment_cpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_cpu_label': 'Latest',
#   'environment_gpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_gpu_label': 'Latest',
#   'root_attribution': 'automl',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://westeurope.api.azureml.ms/jasmine/v1.0/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourceGroups/automlvision-rg/providers/Microsoft.MachineLearningServices/workspaces/automlvision/experimentids/cafd1ca6-4147-416c-bdd6-387ce3fe105b/cancel/AutoML_d6fce25d-b5b7-4c6a-8334-ac2c098402fc',
#   'ClientSdkVersion': '1.28.0',
#   'snapshotId': '00000000-0000-0000-0000-000000000000'},
#  'inputDatasets': [{'dataset': {'id': '08370273-2e1e-43ec-bfa6-7eb48aac15ef'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}, {'dataset': {'id': '35f4e587-a4ea-495d-a5b4-a50b64a95726'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'validation_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Serge Retkowsky'}

# %% [markdown]
# > When doing a hyperparameter sweep, **it can be useful to visualize the different configurations that were tried using the HyperDrive UI**. <br><br>You can navigate to this UI by going to the **'Child runs' tab in the UI of the main automl_image_run** from above, which is the HyperDrive parent run. Then you can go into the 'Child runs' tab of this one.

# %%
experiment
# Out:
# Experiment(Name: AutomlImages-IrisClassif,
# Workspace: automlvision)

# %% [markdown]
# ### You will see all the AutoML runs from the Child runs section.
# The **model column** will display detailled information about each model.<br>
# Example:

# %% [markdown]
# <img src="https://github.com/retkowsky/images/blob/master/automlvision.jpg?raw=true">

# %% [markdown]
# > You can find all the artefacts from the output+logs section of Azure ML

# %% [markdown]
# ## 8. Register the optimal CV model from the AutoML run
# Once the run completes, we can register the model that was created from the best run (configuration that resulted in the best primary metric)

# %%
from azureml.core import Run
hyperdrive_run = Run(experiment=experiment, run_id=automl_image_run.id + '_HD')
hyperdrive_run
# Out:
# Run(Experiment: AutomlImages-IrisClassif,
# Id: AutoML_d6fce25d-b5b7-4c6a-8334-ac2c098402fc_HD,
# Type: hyperdrive,
# Status: Completed)

# %%
# Defining tags for the custom vision model
cvmodel_tags={"Data": "Images", 
              "Context" : "Iris Classification",
              "Task" : "Best AutoML Images",
              "Framework" : "AzureML AutoML for Images",
              "AutoML Metric" : "Accuracy"}

# %%
# Register the best model from the AutoML Vision run
best_child_run = automl_image_run.get_best_child()
model_name = best_child_run.properties['model_name']

model = best_child_run.register_model(model_name = model_name,
                                      model_path='outputs/model.pt',
                                      description='Iris Classification CV model',
                                      tags=cvmodel_tags)

# %%
# We can download the CV model
model.download(target_dir='.', exist_ok=False, exists_ok=None)
# Out:
# 'model.pt'

# %%
# Checking the downloaded .pt model file
# !ls model.pt -l
# Out:
# -rwxrwxrwx 1 root root 203636099 May 18 14:10 model.pt

# %% [markdown]
# ### Model informations from the Azure ML model repository

# %%
model
# Out:
# Model(workspace=Workspace.create(name='automlvision', subscription_id='70b8f39e-8863-49f7-b6ba-34a80799550c', resource_group='automlvision-rg'), name=AutoMLd6fce25db3, id=AutoMLd6fce25db3:1, version=1, tags={'Data': 'Images', 'Context': 'Iris Classification', 'Task': 'Best AutoML Images', 'Framework': 'AzureML AutoML for Images', 'AutoML Metric': 'Accuracy'}, properties={})

# %%
model.id
# Out:
# 'AutoMLd6fce25db3:1'

# %%
model.name
# Out:
# 'AutoMLd6fce25db3'

# %%
model.version
# Out:
# 1

# %%
model.tags
# Out:
# {'Data': 'Images',
#  'Context': 'Iris Classification',
#  'Task': 'Best AutoML Images',
#  'Framework': 'AzureML AutoML for Images',
#  'AutoML Metric': 'Accuracy'}

# %%
model.created_time
# Out:
# datetime.datetime(2021, 5, 18, 14, 10, 50, 764451, tzinfo=<isodate.tzinfo.Utc object at 0x7fab898bb400>)

# %% [markdown]
# ## 9. Deploy model as a web service
# Once you have your trained model, you can deploy the model on Azure. **You can deploy your trained model as a web service on Azure Container Instances ([ACI](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-container-instance)) or Azure Kubernetes Service ([AKS](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-kubernetes-service)).**<br><br> ACI is the perfect option for testing deployments, while AKS is better suited for for high-scale, production usage. <br><br>
# **In this tutorial, we will deploy the model as a web service in AKS.**
# You will need to first create an AKS compute cluster, or use an existing AKS cluster. <br>
# You can use either GPU or CPU VM SKUs for your deployment cluster

# %%
# %%time
from azureml.core.compute import ComputeTarget, AksCompute
from azureml.exceptions import ComputeTargetException

# Choose a name for your cluster
aks_name = "cluster-aks-gpu"

# Check to see if the cluster already exists
try:
    aks_target = ComputeTarget(workspace=ws, name=aks_name)
    print('Found existing compute target.')
except ComputeTargetException:
    print('Creating a new compute target...')
    # Provision AKS cluster with GPU machine
    prov_config = AksCompute.provisioning_configuration(vm_size="STANDARD_NC6", 
                                                        location="eastus2")
    # Create the cluster
    aks_target = ComputeTarget.create(workspace=ws, 
                                      name=aks_name, 
                                      provisioning_configuration=prov_config)
    aks_target.wait_for_completion(show_output=True)
# Out:
# Found existing compute target.
# CPU times: user 21.9 ms, sys: 0 ns, total: 21.9 ms
# Wall time: 386 ms

# %% [markdown]
# Next, you will need to define the inference configuration, that describes how to set up the web-service containing your model. You can use the scoring script and the environment from the training run in your inference config.
# You can then deploy the model as an AKS web service.

# %%
# Settings

from azureml.core.model import InferenceConfig
from azureml.core.webservice import AksWebservice
from azureml.core.webservice import Webservice
from azureml.core.model import Model
from azureml.core.environment import Environment

best_child_run.download_file('outputs/scoring_file_v_1_0_0.py', output_file_path='score.py')
environment = best_child_run.get_environment()
inference_config = InferenceConfig(entry_script='score.py', environment=environment)

endpoint_name='automlirismodel' #Name of the deployed model

aks_tags={"Data": "Images", 
          "Topic" : "iris Classification Custom Vision model", 
          "Task" : "Image Classification",
          "Framework" : "AutoML Images best model", 
          "AKS" : "True"}

aks_description="Computer vision model to detect iris species"

aks_config = AksWebservice.deploy_configuration(autoscale_enabled=True,                                                    
                                                cpu_cores=1,
                                                memory_gb=50,
                                                enable_app_insights=True,
                                                description=aks_description,
                                                tags=aks_tags)

# %%
# Checking the file we downloaded
# !ls score.py -l
# Out:
# -rwxrwxrwx 1 root root 1921 May 18 14:10 score.py

# %%
# Viewing the score.py file
with open(os.path.join('score.py'), 'r') as f:
    print(f.read())
# Out:
# # ---------------------------------------------------------
# # Copyright (c) Microsoft Corporation. All rights reserved.
# # ---------------------------------------------------------
# import os
# import tempfile
# import logging
#
# from azureml.contrib.services.aml_request import rawhttp
# from azureml.automl.core.shared import logging_utilities
# from azureml.contrib.services.aml_response import AMLResponse
#
# from azureml.contrib.automl.dnn.vision.common.utils import _set_logging_parameters
# from azureml.contrib.automl.dnn.vision.common.model_export_utils import load_model, run_inference
# from azureml.contrib.automl.dnn.vision.common.logging_utils import get_logger
#
# from azureml.contrib.automl.dnn.vision.classification.inference.score import _score_with_model
#
# TASK_TYPE = 'image-classification'
# logger = get_logger('azureml.automl.core.scoring_script_images')
#
#
# def init():
#     global model
#
#     # Set up logging
#     _set_logging_parameters(TASK_TYPE, {})
#
#     model_path = os.path.join(os.getenv('AZUREML_MODEL_DIR'), 'model.pt')
#
#     try:
#         logger.info("Loading model from path: {}.".format(model_path))
#         model_settings = {"resize_size": 256, "crop_size": 224}
#         model = load_model(TASK_TYPE, model_path, **model_settings)
#         logger.info("Loading successful.")
#     except Exception as e:
#         logging_utilities.log_traceback(e, logger)
#         raise
#
#
# @rawhttp
# def run(request):
#     logger.info("Request: [{0}]".format(request))
#     if request.method == 'GET':
#         response_body = str.encode(request.full_path)
#         return AMLResponse(response_body, 200)
#     elif request.method == 'POST':
#         request_body = request.get_data()
#         logger.info("Running inference.")
#         result = run_inference(model, request_body, _score_with_model)
#         logger.info("Finished inferencing.")
#         return AMLResponse(result, 200)
#     else:
#         return AMLResponse("bad request", 500)

# %% [markdown]
# ### Let's deploy the CV model into AKS

# %%
# %%time
aks_service = Model.deploy(ws,
                           models=[model],
                           inference_config=inference_config,
                           deployment_config=aks_config,
                           deployment_target=aks_target,
                           name=endpoint_name,
                           overwrite=True)

aks_service.wait_for_deployment(show_output=True)
print()
print("Done. Model is deployed. Ready to use!")
print("\nAKS service status=", aks_service.state)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running
# 2021-05-18 14:11:06+00:00 Creating Container Registry if not exists.
# 2021-05-18 14:11:07+00:00 Registering the environment.
# 2021-05-18 14:11:08+00:00 Use the existing image..
# 2021-05-18 14:11:10+00:00 Creating resources in AKS.
# 2021-05-18 14:11:14+00:00 Submitting deployment to compute.
# 2021-05-18 14:11:14+00:00 Checking the status of deployment automlirismodel..
# 2021-05-18 14:11:58+00:00 Checking the status of inference endpoint automlirismodel.
# Succeeded
# AKS service creation operation finished, operation "Succeeded"
#
# Done. Model is deployed. Ready to use!
#
# AKS service status= Healthy
# CPU times: user 303 ms, sys: 52.4 ms, total: 355 ms
# Wall time: 1min 9s

# %% [markdown]
# > Usually it takes 2 or 3 minutes to deploy. You can see the endpoint in Azure ML Studio

# %%
print("Computer Vision model endpoint:", aks_service.scoring_uri)
# Out:
# Computer Vision model endpoint: http://20.62.49.4:80/api/v1/service/automlirismodel/score

# %%
print("Computer Vision model endpoint properties:", aks_service.properties)
# Out:
# Computer Vision model endpoint properties: {'hasInferenceSchema': 'False', 'hasHttps': 'False'}

# %%
print("Computer Vision model endpoint tags:", aks_service.tags)
# Out:
# Computer Vision model endpoint tags: {'Data': 'Images', 'Topic': 'iris Classification Custom Vision model', 'Task': 'Image Classification', 'Framework': 'AutoML Images best model', 'AKS': 'True'}

# %%
# You can have access to the logs
#print(aks_service.get_logs())

# %% [markdown]
# ## 10. Test our deployed CV model
# Finally, let's test our deployed Computer Vision model to predict new images. You can pass in any image.

# %%
print("Our Computer Vision model endpoint:", aks_service.scoring_uri)
print("\nStatus=", aks_service.state)
# Out:
# Our Computer Vision model endpoint: http://20.62.49.4:80/api/v1/service/automlirismodel/score
#
# Status= Healthy

# %% [markdown]
# ### Test 1

# %% [markdown]
# Let's download an image file to test:

# %%
image_url = 'https://github.com/retkowsky/AutoMLforImages/blob/main/images/irissetosa.jpg?raw=true'
image_file = 'test1.jpg'
urllib.request.urlretrieve(image_url, filename=image_file)
print("Image is downloaded and ready to be predicted.")
# Out:
# Image is downloaded and ready to be predicted.

# %%
import cv2 as cv
img = cv.imread(image_file)
print("Image informations:")
print("- Image filename:", image_file)
print("- Image shape:", img.shape)
print("- Image size:", img.size)
# Out:
# Image informations:
# - Image filename: test1.jpg
# - Image shape: (256, 256, 3)
# - Image size: 196608

# %%
from IPython.display import Image
Image(filename=image_file)

# %%
import requests

# URL for the web service
scoring_uri = aks_service.scoring_uri

# If the service is authenticated, set the key or token
key, _ = aks_service.get_keys()

# Load image data
data = open(image_file, 'rb').read()

# Set the content type
headers = {'Content-Type': 'application/octet-stream'}

# If authentication is enabled, set the authorization header
headers['Authorization'] = f'Bearer {key}'

# Make the request and display the response
resp = requests.post(scoring_uri, data, headers=headers)
print("Status code=",resp.status_code)
print("\nElapsed=", resp.elapsed)
print("\nResults=", resp.text)
# Out:
# Status code= 200
#
# Elapsed= 0:00:00.365153
#
# Results= {"filename": "/tmp/tmpbc4a2l_m", "probs": [0.9460779428482056, 0.023147447034716606, 0.030774682760238647], "labels": ["setosa", "versicolour", "virginica"]}

# %%
prediction=pd.DataFrame(resp.json()) #Convert the Json into a pandas dataframe
prediction
# Out:
#            filename     probs       labels
# 0  /tmp/tmpbc4a2l_m  0.946078       setosa
# 1  /tmp/tmpbc4a2l_m  0.023147  versicolour
# 2  /tmp/tmpbc4a2l_m  0.030775    virginica

# %%
prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs']) # to take the max prob
label = prediction['labels'][label_index]
conf_score = prediction['probs'][label_index]

print("Image file =", image_file)
print("Model prediction =", label, "\nwith Probability =", conf_score)
print("\nThis iris is", label,"with a probability of", round((conf_score*100), 2), "%")
# Out:
# Image file = test1.jpg
# Model prediction = setosa
# with Probability = 0.9460779428482056
#
# This iris is setosa with a probability of 94.61 %

# %% [markdown]
# ## Visualize predictions
# Now that we have scored a test image, we can visualize the prediction for this image

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import numpy as np
import json

IMAGE_SIZE = (18,12)
plt.figure(figsize=IMAGE_SIZE)
img_np=mpimg.imread(image_file)
img = Image.fromarray(img_np.astype('uint8'),'RGB')
x, y = img.size

fig,ax = plt.subplots(1, figsize=(15,15))
# Display the image
ax.imshow(img_np)

prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs'])
label = prediction['labels'][label_index]
conf_score = prediction['probs'][label_index]

display_text = '{} ({})'.format(label, round(conf_score, 4))
print(display_text)

color = 'yellow' # Text color
plt.text(30, 30, display_text, color=color, fontsize=30)

fig.savefig('predictiontest1.jpg', dpi=150) #Saving image

plt.show()
# Out:
# setosa (0.9461)

# %% [markdown]
# ## Test 2

# %%
image_url = 'https://github.com/retkowsky/AutoMLforImages/blob/main/images/irisversicolour.jpg?raw=true'
image_file = 'test2.jpg'
urllib.request.urlretrieve(image_url, filename=image_file)
print("Image is downloaded and ready to be predicted.")
# Out:
# Image is downloaded and ready to be predicted.

# %%
from IPython.display import Image
Image(filename=image_file)

# %%
import cv2 as cv
img = cv.imread(image_file)
print("Image informations:")
print("- Image filename:", image_file)
print("- Image shape:", img.shape)
print("- Image size:", img.size)
# Out:
# Image informations:
# - Image filename: test2.jpg
# - Image shape: (256, 256, 3)
# - Image size: 196608

# %%
import requests

# URL for the web service
scoring_uri = aks_service.scoring_uri

# If the service is authenticated, set the key or token
key, _ = aks_service.get_keys()

# Load image data
data = open(image_file, 'rb').read()

# Set the content type
headers = {'Content-Type': 'application/octet-stream'}

# If authentication is enabled, set the authorization header
headers['Authorization'] = f'Bearer {key}'

# Make the request and display the response
resp = requests.post(scoring_uri, data, headers=headers)
print("Status code=",resp.status_code)
print("\nElapsed=", resp.elapsed)
print("\nResults=", resp.text)
# Out:
# Status code= 200
#
# Elapsed= 0:00:00.353900
#
# Results= {"filename": "/tmp/tmpdhr92ehc", "probs": [0.00011069758329540491, 0.9809677004814148, 0.018921643495559692], "labels": ["setosa", "versicolour", "virginica"]}

# %%
prediction=pd.DataFrame(resp.json()) #Convert the Json into a pandas dataframe
prediction.sort_values(by='probs', ascending=False)

prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs'])
label = prediction['labels'][label_index]
conf_score = prediction['probs'][label_index]

# %%
print("Image file =", image_file)
print("Model prediction =", label, "\nwith Probability =", conf_score)
print("\nThis iris is", label,"with a probability of", round((conf_score*100), 2), "%")
# Out:
# Image file = test2.jpg
# Model prediction = versicolour
# with Probability = 0.9809677004814148
#
# This iris is versicolour with a probability of 98.1 %

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import numpy as np
import json

IMAGE_SIZE = (18,12)
plt.figure(figsize=IMAGE_SIZE)
img_np=mpimg.imread(image_file)
img = Image.fromarray(img_np.astype('uint8'),'RGB')
x, y = img.size

fig,ax = plt.subplots(1, figsize=(15,15))
# Display the image
ax.imshow(img_np)

prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs'])
label = prediction['labels'][label_index]
conf_score = prediction['probs'][label_index]

display_text = '{} ({})'.format(label, round(conf_score, 4))
print(display_text)

color = 'yellow' #Text Color
plt.text(30, 30, display_text, color=color, fontsize=30)

fig.savefig('predictiontest3.jpg', dpi=150) #Saving image

plt.show()
# Out:
# versicolour (0.981)

# %% [markdown]
# ## 11. Clean up ressources

# %%
# Let's delete the service
aks_service.delete()

# %%
# Let's delete our Azure ML GPU compute cluster
compute_target.delete()

# %% [markdown]
# > End of notebook
