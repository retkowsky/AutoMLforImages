# %% [markdown]
# # AutoML for Images
#
# ### Jobs Classifier Detection usecase with Azure ML and AutoML for Images (Image Classification Task)

# %% [markdown]
# <img src="https://github.com/retkowsky/AutoMLforImages/blob/main/images/capturepro.png?raw=true" width=500>

# %% [markdown]
# We will use **IdenProf.** IdenProf is a dataset of identifiable professionals, collected in order to ensure that machine learning systems can be trained to recognize professionals by their mode of dressing as humans can observe.
#
# This is part of our mission to train machine learning systems to perceive, understand and act accordingly in any environment they are deployed.
#
# This is the first release of the IdenProf dataset.
# The professions included in this release are:
# - Chef
# - Doctor
# - Engineer
# - Farmer
# - Firefighter
# - Judge
# - Mechanic
# - Pilot
# - Police
# - Waiter

# %% [markdown]
# ## Setup
# > To use this notebook, **you will need to install the private preview package for AutoML for Images from the private index**.

# %%
#!pip install --upgrade "azureml-train-core<0.1.1" "azureml-train-automl<0.1.1" "azureml-contrib-dataset<0.1.1" --extra-index-url "https://azuremlsdktestpypi.azureedge.net/automl_for_images_private_preview/"

# %%
#!pip install seaborn

# %% [markdown]
# ## 1. Informations

# %%
import numpy as np
import json
import os
import urllib
from zipfile import ZipFile
import seaborn as sns
import pandas as pd

# %%
import sys
print("Python version =", sys.version)
# Out:
# Python version = 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 19:07:31)
# [GCC 7.3.0]

# %%
import datetime
now = datetime.datetime.now()
print("Today =", now)
# Out:
# Today = 2021-06-07 14:06:59.513763

# %%
import azureml.core
print("You are using Azure ML version", azureml.core.VERSION)
# Out:
# You are using Azure ML version 0.1.0.36994775

# %%
# Your local platform
import platform,socket,re,uuid,json,psutil,logging

def getSystemInfo():
    try:
        info={}
        info['Platform']=platform.system()
        info['Platform-release']=platform.release()
        info['Platform-version']=platform.version()
        info['Architecture']=platform.machine()
        info['Hostname']=socket.gethostname()
        info['IP-address']=socket.gethostbyname(socket.gethostname())
        info['MAC-address']=':'.join(re.findall('..', '%012x' % uuid.getnode()))
        info['Processor']=platform.processor()
        info['RAM']=str(round(psutil.virtual_memory().total / (1024.0 **3)))+" Go"
        return json.dumps(info)
    except Exception as e:
        logging.exception(e)

json.loads(getSystemInfo())
# Out:
# {'Platform': 'Linux',
#  'Platform-release': '5.4.0-1046-azure',
#  'Platform-version': '#48~18.04.1-Ubuntu SMP Tue Apr 13 19:41:38 UTC 2021',
#  'Architecture': 'x86_64',
#  'Hostname': 'standardd15v2',
#  'IP-address': '127.0.0.1',
#  'MAC-address': 'ed:fa:3e:5b:64:be',
#  'Processor': 'x86_64',
#  'RAM': '138 Go'}

# %% [markdown]
# ## 2. Workspace setup
# In order to train and deploy models in Azure ML, you will first need to set up a workspace.
#
# An [Azure ML Workspace](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#workspace) is an Azure resource that organizes and coordinates the actions of many other Azure resources to assist in executing and sharing machine learning workflows. In particular, an Azure ML Workspace coordinates storage, databases, and compute resources providing added functionality for machine learning experimentation, deployment, inference, and the monitoring of deployed models.
#
# > Create an Azure ML Workspace within your Azure subscription, or load an existing workspace.

# %%
subscription_id='tobereplaced'   
resource_group='automlvision-rg'   
workspace_name='automlvision'

# %%
from azureml.core import Workspace
try:
   ws = Workspace(subscription_id = subscription_id, resource_group = resource_group, workspace_name = workspace_name)
   ws.write_config()
   print("OK")
except:
   print("Error: Workspace not found")
# Out:
# OK

# %%
from azureml.core import Workspace
ws = Workspace.from_config()

# %%
ws.name, ws.resource_group
# Out:
# ('automlvision', 'automlvision-rg')

# %% [markdown]
# ## 3. Azure ML GPU Compute target setup
# **You will need to provide a [Compute Target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) that will be used for your AutoML model training.** <br><br>
# **AutoML models for image tasks require GPU SKUs and support NC and ND families.** We recommend using the NCsv3-series (with v100 GPUs) for faster training. Using a compute target with a multi-GPU VM SKU will leverage the multiple GPUs to speed up training. Additionally, setting up a compute target with multiple nodes will allow for faster model training by leveraging parallelism, when tuning hyperparameters for your model.

# %%
from azureml.core.compute import AmlCompute, ComputeTarget

cluster_name = "gpu-jobs"

try:
    compute_target = ws.compute_targets[cluster_name]
    print('Found existing compute target.')
except KeyError:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_NC6', #GPU cluster
                                                           idle_seconds_before_scaledown=1800, #Time out
                                                           min_nodes=0, 
                                                           max_nodes=4)

    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

# Can poll for a minimum number of nodes and for a specific timeout.
# If no min_node_count is provided, it will use the scale settings for the cluster.
compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
# Out:
# Creating a new compute target...
# Creating.........
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
# Compute status
compute_target.provisioning_state
# Out:
# 'Succeeded'

# %%
# Compute cluster information
compute_target.get_status().serialize()
# Out:
# {'currentNodeCount': 0,
#  'targetNodeCount': 0,
#  'nodeStateCounts': {'preparingNodeCount': 0,
#   'runningNodeCount': 0,
#   'idleNodeCount': 0,
#   'unusableNodeCount': 0,
#   'leavingNodeCount': 0,
#   'preemptedNodeCount': 0},
#  'allocationState': 'Steady',
#  'allocationStateTransitionTime': '2021-06-07T14:07:52.614000+00:00',
#  'errors': None,
#  'creationTime': '2021-06-07T14:07:20.355747+00:00',
#  'modifiedTime': '2021-06-07T14:08:05.892203+00:00',
#  'provisioningState': 'Succeeded',
#  'provisioningStateTransitionTime': None,
#  'scaleSettings': {'minNodeCount': 0,
#   'maxNodeCount': 4,
#   'nodeIdleTimeBeforeScaleDown': 'PT1800S'},
#  'vmPriority': 'Dedicated',
#  'vmSize': 'STANDARD_NC6'}

# %%
# Compute VM size
compute_target.vm_size
# Out:
# 'STANDARD_NC6'

# %% [markdown]
# ## 4. Experiment Setup
# Create an [Experiment](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#experiment) in your workspace to track your model training runs

# %%
from azureml.core import Experiment

experiment_name = 'AutomlImages-Jobs' #Name of your experimentation
experiment = Experiment(ws, name=experiment_name)

# %%
experiment
# Out:
# Experiment(Name: AutomlImages-Jobs,
# Workspace: automlvision)

# %% [markdown]
# ## 5. Dataset with input Training Data
# In order to generate models for computer vision, you will need to bring in labeled image data as input for model training in the form of an AzureML Labeled Dataset. You can either use a Labeled Dataset that you have exported from a Data Labeling project, or create a new Labeled Dataset with your labeled training data

# %% [markdown]
# > Images can be downloaded from:https://github.com/OlafenwaMoses/IdenProf

# %%
# %pwd
# Out:
# '/mnt/batch/tasks/shared/LS_root/mounts/clusters/standardd15v2/code/Users/seretkow/AutoML JobsClassifier'

# %%
# %cd jobsimages
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/standardd15v2/code/Users/seretkow/AutoML JobsClassifier/jobsimages

# %% [markdown]
# ### List of images files

# %%
print(os.listdir('.'))
# Out:
# ['.ipynb_checkpoints', 'chef', 'doctor', 'engineer', 'farmer', 'firefighter', 'judge', 'mechanic', 'pilot', 'police', 'train_annotations.jsonl', 'validation_annotations.jsonl', 'waiter']

# %%
for root, _, files in os.walk('.'):
    print("Dir:", root, "with", len(files), "images files.")
# Out:
# Dir: . with 2 images files.
# Dir: ./.ipynb_checkpoints with 0 images files.
# Dir: ./chef with 900 images files.
# Dir: ./doctor with 901 images files.
# Dir: ./engineer with 901 images files.
# Dir: ./farmer with 900 images files.
# Dir: ./firefighter with 900 images files.
# Dir: ./judge with 900 images files.
# Dir: ./mechanic with 900 images files.
# Dir: ./pilot with 900 images files.
# Dir: ./police with 901 images files.
# Dir: ./waiter with 900 images files.

# %% [markdown]
# ### Some samples:

# %%
from IPython.display import Image
sample_image = '../jobsimages/chef/chef-100.jpg'
Image(filename=sample_image)

# %%
from IPython.display import Image
sample_image = '../jobsimages/doctor/doctor-10.jpg'
Image(filename=sample_image)

# %%
from IPython.display import Image
sample_image = '../jobsimages/engineer/engineer-10.jpg'
Image(filename=sample_image)

# %%
sample_image = '../jobsimages/farmer/farmer-100.jpg'
Image(filename=sample_image)

# %%
sample_image = '../jobsimages/firefighter/firefighter-100.jpg'
Image(filename=sample_image)

# %% [markdown]
# ### Convert the downloaded data to JSONL

# %%
# %cd ..
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/standardd15v2/code/Users/seretkow/AutoML JobsClassifier

# %%
src = "jobsimages/"

train_validation_ratio = 5

# Retrieving default datastore that got automatically created when we setup a workspace
workspaceblobstore = ws.get_default_datastore().name

# Path to the training and validation files
train_annotations_file = os.path.join(src, "train_annotations.jsonl")
validation_annotations_file = os.path.join(src, "validation_annotations.jsonl")

# sample json line dictionary
json_line_sample = \
    {
        "image_url": "AmlDatastore://" + workspaceblobstore + "/"
                     + os.path.basename(os.path.dirname(src)),
        "label": "",
        "label_confidence": 1.0
    }

index = 0
# Scan each sub directary and generate jsonl line
with open(train_annotations_file, 'w') as train_f:
    with open(validation_annotations_file, 'w') as validation_f:
        for className in os.listdir(src):
            subDir = src + className
            if not os.path.isdir(subDir):
                continue
            # Scan each sub directary
            print("Parsing " + subDir)
            for image in os.listdir(subDir):
                json_line = dict(json_line_sample)
                json_line["image_url"] += f"/{className}/{image}"
                json_line["label"] = className

                if index % train_validation_ratio == 0:
                    # validation annotation
                    validation_f.write(json.dumps(json_line) + "\n")
                else:
                    # train annotation
                    train_f.write(json.dumps(json_line) + "\n")
                index += 1
# Out:
# Parsing jobsimages/.ipynb_checkpoints
# Parsing jobsimages/chef
# Parsing jobsimages/doctor
# Parsing jobsimages/engineer
# Parsing jobsimages/farmer
# Parsing jobsimages/firefighter
# Parsing jobsimages/judge
# Parsing jobsimages/mechanic
# Parsing jobsimages/pilot
# Parsing jobsimages/police
# Parsing jobsimages/waiter

# %% [markdown]
# ### Upload the JSONL file and images to Datastore
# In order to use the data for training in Azure ML, we upload it to our Azure ML Workspace via a [Datastore](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores). The datastore provides a mechanism for you to upload/download data, and interact with it from your remote compute targets. It is an abstraction over Azure Storage.

# %%
# Retrieving default datastore that got automatically created when we setup a workspace
ds = ws.get_default_datastore()
ds.upload(src_dir='./jobsimages/', target_path='jobsimages')
# Out:
# Uploading an estimated of 9005 files
# Target already exists. Skipping upload for jobsimages/train_annotations.jsonl
# Target already exists. Skipping upload for jobsimages/validation_annotations.jsonl
# Target already exists. Skipping upload for jobsimages/chef/chef-1.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-10.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-100.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-101.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-102.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-103.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-104.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-105.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-106.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-107.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-108.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-109.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-11.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-110.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-111.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-112.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-113.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-114.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-115.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-116.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-117.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-118.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-119.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-12.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-120.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-121.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-122.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-123.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-124.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-125.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-126.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-127.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-128.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-129.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-13.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-130.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-131.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-132.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-133.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-134.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-135.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-136.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-137.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-138.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-139.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-14.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-140.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-141.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-142.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-143.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-144.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-145.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-146.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-147.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-148.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-149.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-15.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-150.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-151.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-152.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-153.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-154.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-155.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-156.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-157.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-158.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-159.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-16.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-160.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-161.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-162.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-163.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-164.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-165.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-166.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-167.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-168.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-169.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-17.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-170.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-171.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-172.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-173.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-174.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-175.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-176.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-177.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-178.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-179.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-18.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-180.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-181.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-182.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-183.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-184.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-185.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-186.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-187.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-188.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-189.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-19.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-190.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-191.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-192.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-193.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-194.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-195.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-196.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-197.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-198.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-199.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-2.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-20.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-200.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-201.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-202.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-203.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-204.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-205.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-206.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-207.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-208.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-209.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-21.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-210.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-211.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-212.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-213.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-214.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-215.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-216.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-217.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-218.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-219.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-22.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-220.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-221.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-222.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-223.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-224.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-225.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-226.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-227.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-228.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-229.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-23.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-230.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-231.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-232.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-233.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-234.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-235.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-236.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-237.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-238.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-239.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-24.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-240.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-241.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-242.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-243.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-244.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-245.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-246.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-247.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-248.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-249.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-25.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-250.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-251.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-252.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-253.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-254.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-255.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-256.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-257.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-258.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-259.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-26.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-260.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-261.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-262.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-263.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-264.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-265.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-266.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-267.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-268.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-269.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-27.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-270.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-271.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-272.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-273.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-274.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-275.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-276.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-277.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-278.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-279.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-28.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-280.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-281.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-282.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-283.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-284.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-285.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-286.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-287.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-288.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-289.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-29.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-290.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-291.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-292.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-293.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-294.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-295.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-296.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-297.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-298.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-299.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-3.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-30.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-300.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-301.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-302.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-303.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-304.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-305.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-306.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-307.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-308.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-309.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-31.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-310.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-311.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-312.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-313.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-314.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-315.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-316.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-317.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-318.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-319.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-32.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-320.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-321.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-322.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-323.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-324.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-325.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-326.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-327.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-328.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-329.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-33.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-330.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-331.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-332.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-333.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-334.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-335.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-336.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-337.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-338.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-339.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-34.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-340.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-341.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-342.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-343.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-344.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-345.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-346.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-347.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-348.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-349.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-35.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-350.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-351.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-352.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-353.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-354.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-355.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-356.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-357.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-358.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-359.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-36.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-360.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-361.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-362.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-363.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-364.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-365.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-366.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-367.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-368.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-369.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-37.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-370.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-371.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-372.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-373.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-374.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-375.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-376.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-377.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-378.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-379.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-38.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-380.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-381.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-382.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-383.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-384.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-385.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-386.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-387.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-388.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-389.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-39.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-390.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-391.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-392.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-393.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-394.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-395.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-396.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-397.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-398.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-399.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-4.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-40.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-400.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-401.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-402.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-403.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-404.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-405.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-406.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-407.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-408.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-409.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-41.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-410.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-411.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-412.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-413.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-414.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-415.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-416.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-417.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-418.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-419.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-42.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-420.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-421.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-422.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-423.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-424.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-425.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-426.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-427.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-428.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-429.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-43.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-430.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-431.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-432.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-433.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-434.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-435.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-436.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-437.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-438.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-439.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-44.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-440.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-441.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-442.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-443.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-444.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-445.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-446.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-447.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-448.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-449.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-45.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-450.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-451.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-452.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-453.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-454.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-455.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-456.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-457.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-458.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-459.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-46.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-460.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-461.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-462.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-463.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-464.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-465.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-466.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-467.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-468.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-469.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-47.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-470.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-471.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-472.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-473.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-474.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-475.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-476.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-477.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-478.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-479.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-48.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-480.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-481.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-482.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-483.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-484.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-485.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-486.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-487.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-488.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-489.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-49.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-490.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-491.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-492.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-493.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-494.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-495.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-496.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-497.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-498.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-499.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-5.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-50.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-500.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-501.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-502.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-503.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-504.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-505.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-506.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-507.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-508.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-509.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-51.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-510.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-511.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-512.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-513.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-514.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-515.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-516.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-517.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-518.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-519.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-52.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-520.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-521.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-522.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-523.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-524.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-525.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-526.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-527.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-528.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-529.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-53.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-530.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-531.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-532.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-533.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-534.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-535.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-536.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-537.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-538.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-539.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-54.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-540.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-541.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-542.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-543.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-544.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-545.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-546.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-547.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-548.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-549.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-55.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-550.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-551.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-552.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-553.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-554.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-555.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-556.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-557.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-558.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-559.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-56.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-560.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-561.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-562.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-563.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-564.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-565.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-566.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-567.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-568.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-569.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-57.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-570.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-571.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-572.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-573.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-574.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-575.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-576.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-577.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-578.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-579.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-58.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-580.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-581.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-582.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-583.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-584.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-585.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-586.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-587.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-588.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-589.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-59.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-590.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-591.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-592.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-593.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-594.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-595.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-596.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-597.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-598.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-599.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-6.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-60.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-600.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-601.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-602.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-603.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-604.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-605.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-606.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-607.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-608.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-609.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-61.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-610.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-611.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-612.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-613.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-614.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-615.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-616.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-617.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-618.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-619.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-62.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-620.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-621.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-622.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-623.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-624.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-625.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-626.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-627.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-628.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-629.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-63.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-630.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-631.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-632.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-633.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-634.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-635.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-636.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-637.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-638.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-639.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-64.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-640.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-641.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-642.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-643.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-644.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-645.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-646.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-647.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-648.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-649.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-65.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-650.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-651.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-652.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-653.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-654.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-655.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-656.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-657.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-658.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-659.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-66.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-660.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-661.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-662.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-663.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-664.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-665.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-666.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-667.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-668.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-669.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-67.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-670.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-671.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-672.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-673.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-674.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-675.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-676.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-677.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-678.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-679.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-68.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-680.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-681.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-682.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-683.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-684.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-685.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-686.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-687.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-688.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-689.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-69.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-690.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-691.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-692.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-693.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-694.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-695.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-696.jpg
# Target already exists. Skipping upload for jobsimages/chef/chef-697.jpg
# ...
# Target already exists. Skipping upload for jobsimages/waiter/waiter-721.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-722.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-723.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-724.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-725.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-726.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-727.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-728.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-729.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-73.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-730.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-731.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-732.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-733.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-734.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-735.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-736.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-737.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-738.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-739.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-74.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-740.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-741.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-742.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-743.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-744.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-745.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-746.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-747.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-748.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-749.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-75.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-750.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-751.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-752.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-753.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-754.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-755.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-756.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-757.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-758.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-759.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-76.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-760.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-761.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-762.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-763.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-764.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-765.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-766.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-767.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-768.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-769.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-77.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-770.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-771.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-772.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-773.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-774.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-775.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-776.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-777.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-778.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-779.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-78.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-780.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-781.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-782.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-783.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-784.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-785.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-786.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-787.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-788.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-789.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-79.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-790.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-791.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-792.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-793.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-794.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-795.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-796.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-797.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-798.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-799.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-8.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-80.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-800.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-801.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-802.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-803.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-804.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-805.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-806.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-807.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-808.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-809.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-81.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-810.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-811.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-812.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-813.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-814.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-815.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-816.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-817.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-818.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-819.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-82.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-820.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-821.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-822.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-823.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-824.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-825.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-826.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-827.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-828.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-829.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-83.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-830.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-831.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-832.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-833.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-834.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-835.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-836.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-837.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-838.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-839.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-84.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-840.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-841.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-842.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-843.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-844.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-845.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-846.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-847.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-848.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-849.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-85.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-850.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-851.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-852.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-853.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-854.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-855.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-856.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-857.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-858.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-859.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-86.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-860.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-861.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-862.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-863.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-864.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-865.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-866.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-867.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-868.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-869.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-87.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-870.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-871.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-872.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-873.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-874.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-875.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-876.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-877.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-878.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-879.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-88.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-880.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-881.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-882.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-883.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-884.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-885.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-886.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-887.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-888.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-889.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-89.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-890.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-891.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-892.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-893.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-894.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-895.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-896.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-897.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-898.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-899.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-9.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-90.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-900.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-91.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-92.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-93.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-94.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-95.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-96.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-97.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-98.jpg
# Target already exists. Skipping upload for jobsimages/waiter/waiter-99.jpg
# Uploaded 0 files
# $AZUREML_DATAREFERENCE_0f4abebd466040b282180d44b78d5b3f

# %% [markdown]
# Finally, we need to create an Azure ML [Dataset](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores) from the data we uploaded to the Datastore. We create one dataset for training and one for validation.

# %%
from azureml.contrib.dataset.labeled_dataset import _LabeledDatasetFactory, LabeledDatasetTask
from azureml.core import Dataset

training_dataset_name = 'JobsTrainingDataset'
if training_dataset_name in ws.datasets:
    training_dataset = ws.datasets.get(training_dataset_name)
    print('Found the training dataset', training_dataset_name)
else:
    # create training dataset
    training_dataset = _LabeledDatasetFactory.from_json_lines(
        task=LabeledDatasetTask.IMAGE_CLASSIFICATION, path=ds.path('jobsimages/train_annotations.jsonl'))
    training_dataset = training_dataset.register(workspace=ws, name=training_dataset_name)
    
# create validation dataset
validation_dataset_name = "JobsValidationDataset"
if validation_dataset_name in ws.datasets:
    validation_dataset = ws.datasets.get(validation_dataset_name)
    print('Found the validation dataset', validation_dataset_name)
else:
    validation_dataset = _LabeledDatasetFactory.from_json_lines(
        task=LabeledDatasetTask.IMAGE_CLASSIFICATION, path=ds.path('jobsimages/validation_annotations.jsonl'))
    validation_dataset = validation_dataset.register(workspace=ws, name=validation_dataset_name)

print()
print("Training dataset name:" + training_dataset.name)
print("Validation dataset name:" + validation_dataset.name)
# Out:
# Training dataset name:JobsTrainingDataset
# Validation dataset name:JobsValidationDataset

# %% [markdown]
# Validation dataset is optional. If no validation dataset is specified, by default 20% of your training data will be used for validation. You can control the percentage using the `split_ratio` argument - please refer to the documentation for more details.
#
# This is what the training dataset looks like

# %%
df=training_dataset.to_pandas_dataframe()

# %%
df.shape
# Out:
# (7202, 3)

# %%
df.head(7202)
# Out:
#                                               image_url   label  \
# 0     StreamInfo(AmlDatastore://jobsimages/chef/chef...    chef
# 1     StreamInfo(AmlDatastore://jobsimages/chef/chef...    chef
# 2     StreamInfo(AmlDatastore://jobsimages/chef/chef...    chef
# 3     StreamInfo(AmlDatastore://jobsimages/chef/chef...    chef
# 4     StreamInfo(AmlDatastore://jobsimages/chef/chef...    chef
# ...                                                 ...     ...
# 7197  StreamInfo(AmlDatastore://jobsimages/waiter/wa...  waiter
# 7198  StreamInfo(AmlDatastore://jobsimages/waiter/wa...  waiter
# 7199  StreamInfo(AmlDatastore://jobsimages/waiter/wa...  waiter
# 7200  StreamInfo(AmlDatastore://jobsimages/waiter/wa...  waiter
# 7201  StreamInfo(AmlDatastore://jobsimages/waiter/wa...  waiter
#
#       label_confidence
# 0                  1.0
# 1                  1.0
# 2                  1.0
# 3                  1.0
# 4                  1.0
# ...                ...
# 7197               1.0
# 7198               1.0
# 7199               1.0
# 7200               1.0
# 7201               1.0
#
# [7202 rows x 3 columns]

# %%
# Counts images by labels
df['label'].value_counts()
# Out:
# engineer       721
# police         721
# farmer         720
# chef           720
# doctor         720
# mechanic       720
# waiter         720
# pilot          720
# judge          720
# firefighter    720
# Name: label, dtype: int64

# %%
# Percentage values
df['label'].value_counts(normalize=True)
# Out:
# engineer       0.100111
# police         0.100111
# farmer         0.099972
# chef           0.099972
# doctor         0.099972
# mechanic       0.099972
# waiter         0.099972
# pilot          0.099972
# judge          0.099972
# firefighter    0.099972
# Name: label, dtype: float64

# %% [markdown]
# ## 6. Configuring your AutoML run for image tasks
# AutoML allows you to easily train models for Image Classification, Object Detection & Instance Segmentation on your image data. You can control the model algorithm to be used, specify hyperparameter values for your model as well as perform a sweep across the hyperparameter space to generate an optimal model. Parameters for configuring your AutoML runs for image related tasks are specified using the 'AutoMLImageConfig' - please refer to the [documentation](https://github.com/swatig007/automlForImages#readme) for the details on the parameters that can be used and their values.

# %% [markdown]
# When using AutoML for image tasks, you need to specify the model algorithms using the `model_name` parameter. You can either specify a single model or choose to sweep over multiple ones.<br><br> **Currently supported model algorithms for image classification: 'resnet18', 'resnet34', 'resnet50', 'mobilenetv2', 'seresnext'.**
#
# ### Using default hyperparameter values for the specified algorithm
#
# Before doing a large sweep to search for the optimal models and hyperparameters, we recommend trying the default values to get a first baseline. Next, you can explore multiple hyperparameters for the same model before sweeping over multiple models and their parameters. This is for employing a more iterative approach, because with multiple models and multiple hyperparameters for each (as we showcase in the next section), the search space grows exponentially and you need more iterations to find optimal configurations.
#
# If you wish to use the default hyperparameter values for a given algorithm (say **seresnext**), you can specify the config for your AutoML Image runs as follows:

# %%
from azureml.train.automl import AutoMLImageConfig
from azureml.train.hyperdrive import RandomParameterSampling
from azureml.train.hyperdrive import GridParameterSampling
from azureml.train.hyperdrive import choice

# %%
# AutoML Configuration
automlimage_config = AutoMLImageConfig(task='image-classification', # AutoML Vision task
                                       compute_target=compute_target, # Compute target
                                       training_data=training_dataset, # Training dataset
                                       validation_data=validation_dataset, # Validation dataset
                                       hyperparameter_sampling=GridParameterSampling({'model_name': 
                                                                                      choice('seresnext')})) # CV Model

# %% [markdown]
# ## 7. Submitting an AutoML run for Computer Vision tasks
# Once you've created the config settings for your run, **you can submit an AutoML run** using the config in order to train a vision model using your training dataset.

# %%
automl_image_run = experiment.submit(automlimage_config)
# Out:
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>AutomlImages-Jobs</td><td>AutoML_437bf282-74c5-41b3-9ff2-31074a7a7987</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_437bf282-74c5-41b3-9ff2-31074a7a7987?wsid=/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/automlvision-rg/workspaces/automlvision&amp;tid=72f988bf-86f1-41af-91ab-2d7cd011db47" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %%
automl_image_run.wait_for_completion(wait_post_processing=True) # Wait until automl run is finished
# Out:
# {'runId': 'AutoML_437bf282-74c5-41b3-9ff2-31074a7a7987',
#  'target': 'gpu-jobs',
#  'status': 'Completed',
#  'startTimeUtc': '2021-06-07T14:14:04.704275Z',
#  'endTimeUtc': '2021-06-07T15:44:30.714522Z',
#  'properties': {'num_iterations': '1',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'accuracy',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': None,
#   'target': 'gpu-jobs',
#   'AMLSettingsJsonString': '{"path":null,"name":"AutomlImages-Jobs","subscription_id":"70b8f39e-8863-49f7-b6ba-34a80799550c","resource_group":"automlvision-rg","workspace_name":"automlvision","region":"westeurope","compute_target":"gpu-jobs","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":false,"enable_run_restructure":false,"start_auxiliary_runs_before_parent_complete":false,"enable_code_generation":false,"iterations":1,"primary_metric":"accuracy","task_type":"image-classification","data_script":null,"test_size":0.0,"validation_size":0.0,"n_cross_validations":null,"y_min":null,"y_max":null,"num_classes":null,"featurization":"off","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":1,"max_concurrent_iterations":1,"iteration_timeout_minutes":null,"mem_in_mb":null,"enforce_time_on_windows":false,"experiment_timeout_minutes":8640,"experiment_exit_score":null,"whitelist_models":null,"blacklist_algos":["TensorFlowDNN","TensorFlowLinearRegressor"],"supported_models":[],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":false,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"STANDARD_NC6","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":true,"scenario":"Vision","environment_label":null,"save_mlflow":false,"force_text_dnn":false,"enable_feature_sweeping":true,"enable_early_stopping":false,"early_stopping_n_iters":10,"arguments":null,"dataset_id":"e9c23b83-80fc-4d64-9d24-4a6d3c80a0e1","hyperdrive_config":{"max_total_jobs":1,"max_concurrent_jobs":1,"generator_config":{"name":"GRID","parameter_space":"{\\"model_name\\": [\\"choice\\", [[\\"seresnext\\"]]]}","properties":null},"policy_config":null},"validation_dataset_id":"18002232-0d01-411b-bc03-0814301c22be","run_source":"AutoMLImageSDK","metrics":null,"enable_metric_confidence":false,"enable_ensembling":false,"enable_stack_ensembling":false,"ensemble_iterations":null,"enable_tf":false,"enable_subsampling":false,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"allowed_private_models":[],"label_column_name":"label","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":false}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"e9c23b83-80fc-4d64-9d24-4a6d3c80a0e1\\"}, \\"validation_data\\": {\\"datasetId\\": \\"18002232-0d01-411b-bc03-0814301c22be\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': 'False',
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'automl',
#   'display_task_type': 'image-classification',
#   'dependencies_versions': '{"azureml-widgets": "1.27.0", "azureml-train": "1.27.0", "azureml-train-restclients-hyperdrive": "0.1.0.36994775", "azureml-train-core": "0.1.0.36994775", "azureml-train-automl": "0.1.0.36994775", "azureml-train-automl-runtime": "0.1.0.36994775", "azureml-train-automl-client": "0.1.0.36994775", "azureml-tensorboard": "1.27.0", "azureml-telemetry": "0.1.0.36994775", "azureml-sdk": "1.27.0", "azureml-samples": "0+unknown", "azureml-pipeline": "1.27.0", "azureml-pipeline-steps": "1.27.0", "azureml-pipeline-core": "1.27.0", "azureml-opendatasets": "1.27.0", "azureml-model-management-sdk": "1.0.1b6.post1", "azureml-mlflow": "1.27.0", "azureml-interpret": "0.1.0.36994775", "azureml-explain-model": "1.27.0", "azureml-defaults": "0.1.0.36994775", "azureml-dataset-runtime": "0.1.0.36994775", "azureml-dataprep": "2.15.0", "azureml-dataprep-rslex": "1.13.0", "azureml-dataprep-native": "33.0.0", "azureml-datadrift": "1.27.0", "azureml-core": "0.1.0.36994775", "azureml-contrib-services": "1.27.0", "azureml-contrib-server": "1.27.0", "azureml-contrib-reinforcementlearning": "1.27.0", "azureml-contrib-pipeline-steps": "1.27.0", "azureml-contrib-notebook": "1.27.0", "azureml-contrib-gbdt": "1.27.0", "azureml-contrib-fairness": "1.27.0", "azureml-contrib-dataset": "0.1.0.36994775", "azureml-cli-common": "1.27.0", "azureml-automl-runtime": "0.1.0.36994775", "azureml-automl-dnn-nlp": "1.27.0", "azureml-automl-core": "0.1.0.36994775", "azureml-accel-models": "1.27.0"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'environment_cpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_cpu_label': 'Latest',
#   'environment_gpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_gpu_label': 'Latest',
#   'root_attribution': 'automl',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://westeurope.api.azureml.ms/jasmine/v1.0/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourceGroups/automlvision-rg/providers/Microsoft.MachineLearningServices/workspaces/automlvision/experimentids/5bf31669-2dc9-4f9e-9617-653cdeea83e3/cancel/AutoML_437bf282-74c5-41b3-9ff2-31074a7a7987',
#   'ClientSdkVersion': '1.29.0.post1',
#   'snapshotId': '00000000-0000-0000-0000-000000000000'},
#  'inputDatasets': [{'dataset': {'id': 'e9c23b83-80fc-4d64-9d24-4a6d3c80a0e1'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}, {'dataset': {'id': '18002232-0d01-411b-bc03-0814301c22be'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'validation_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Serge Retkowsky'}

# %%
automl_image_run.id
# Out:
# 'AutoML_437bf282-74c5-41b3-9ff2-31074a7a7987'

# %%
experiment
# Out:
# Experiment(Name: AutomlImages-Jobs,
# Workspace: automlvision)

# %%
# List of all the AutoML for Images metrics values
automlvisionmetrics = automl_image_run.get_metrics()
metricsdf=pd.DataFrame(automl_image_run.get_metrics()) # Convert to a pandas df
metricsdf
# Out:
#     average_sample_f1_score  average_sample_f2_score  average_class_f2_score  \
# 0                    88.556                   88.556                  88.560
# 1                    91.611                   91.611                  91.596
# 2                    92.667                   92.667                  92.644
# 3                    93.056                   93.056                  93.044
# 4                    92.611                   92.611                  92.597
# 5                    93.111                   93.111                  93.081
# 6                    92.167                   92.167                  92.116
# 7                    93.556                   93.556                  93.544
# 8                    93.722                   93.722                  93.690
# 9                    93.222                   93.222                  93.217
# 10                   93.722                   93.722                  93.701
# 11                   94.000                   94.000                  93.982
# 12                   93.944                   93.944                  93.929
# 13                   94.056                   94.056                  94.047
# 14                   94.056                   94.056                  94.038
#
#     average_class_recall     iou  average_class_f1_score  \
# 0                 88.556  88.556                  88.613
# 1                 91.611  91.611                  91.652
# 2                 92.667  92.667                  92.658
# 3                 93.056  93.056                  93.062
# 4                 92.611  92.611                  92.622
# 5                 93.111  93.111                  93.068
# 6                 92.167  92.167                  92.135
# 7                 93.556  93.556                  93.539
# 8                 93.722  93.722                  93.683
# 9                 93.222  93.222                  93.222
# 10                93.722  93.722                  93.684
# 11                94.000  94.000                  93.965
# 12                93.944  93.944                  93.914
# 13                94.056  94.056                  94.045
# 14                94.056  94.056                  94.022
#
#     average_class_precision  recall  precision  accuracy
# 0                    88.818  88.556     88.818    88.556
# 1                    91.955  91.611     91.955    91.611
# 2                    92.813  92.667     92.813    92.667
# 3                    93.185  93.056     93.185    93.056
# 4                    92.786  92.611     92.786    92.611
# 5                    93.126  93.111     93.126    93.111
# 6                    92.427  92.167     92.427    92.167
# 7                    93.567  93.556     93.567    93.556
# 8                    93.786  93.722     93.786    93.722
# 9                    93.261  93.222     93.261    93.222
# 10                   93.693  93.722     93.693    93.722
# 11                   93.967  94.000     93.967    94.000
# 12                   93.911  93.944     93.911    93.944
# 13                   94.072  94.056     94.072    94.056
# 14                   94.027  94.056     94.027    94.056

# %%
# Let's plot the accuracy metric for the CV model, save the graph to a jpg file and log it to the Azure ML experiment
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (15,7))
plt.plot(automlvisionmetrics['accuracy'], 'r-', lw=4, alpha=.6)
plt.xlabel('iterations', fontsize=10)
plt.ylabel('accuracy', fontsize=10)
plt.title('seresnext CV model accuracy', fontsize=12)

plt.savefig('accuracy_seresnext.jpg', dpi=150) # Saving image in a jpg file
automl_image_run.log_image(name='accuracy_seresnext.jpg', plot=plt) # Logging the graph into the Azure ML experiment

plt.show()

# %%
# Checking the output graph
# !ls accuracy_seresnext.jpg -l
# Out:
# -rwxrwxrwx 1 root root 99349 Jun  7 15:49 accuracy_seresnext.jpg

# %%
# You can view the jpg file in the experiment
experiment
# Out:
# Experiment(Name: AutomlImages-Jobs,
# Workspace: automlvision)

# %% [markdown]
# ## Let's improve using additionals models & hyperparameter tuning

# %% [markdown]
# ### Hyperparameter sweeping for your AutoML models for computer vision tasks
#
# When using AutoML for Images, you can perform a hyperparameter sweep over a defined parameter space, to find the optimal model. In this example, we sweep over the hyperparameters for each algorithm, **choosing from a range of values for learning_rate, optimizer, lr_scheduler, etc, to generate a model with the optimal 'accuracy'.** If hyperparameter values are not specified, then default values are used for the specified algorithm.
#
# We use **Random Sampling to pick samples from this parameter space and try a total of 20 iterations** with these different samples, running 4 iterations at a time on our compute target, which has been previously set up using 4 nodes. Please note that the more parameters the space has, the more iterations you need to find optimal models.
#
# We also leverage the **Bandit early termination policy** that terminates poor performing configs (those that are not within 20% slack of the best perfroming config), thus significantly saving compute resources.

# %% [markdown]
# ### List of model available for Image classification:
# Resnet18, Resnet34, Resnet50, Mobilenetv2, seresnext

# %% [markdown]
# from azureml.train.automl import AutoMLImageConfig
# from azureml.train.hyperdrive import GridParameterSampling, RandomParameterSampling, BayesianParameterSampling
# from azureml.train.hyperdrive import BanditPolicy, HyperDriveConfig, PrimaryMetricGoal
# from azureml.train.hyperdrive import choice, uniform
#
# #Options for the parameter space
# parameter_space = {
#     'model': choice(
#         {
#             'model_name': choice('seresnext', 'resnet50', 'resnet34'),
#             'learning_rate': uniform(0.0001, 0.01),
#             'optimizer': choice('sgd', 'adam'),
#             'layers_to_freeze': choice(0, 1, 2, 3),
#
#         },
#         {
#             'model_name': choice('seresnext'),
#             'resize_size': choice(288, 320, 352), # model-specific
#             'crop_size': choice(224, 256), # model-specific, crop_size should be smaller or equal than resize_size
#         }
#     )
# }
#
# #Options for the tuning part
# tuning_settings = {
#     'iterations': 10,
#     'max_concurrent_iterations': 4,
#     'hyperparameter_sampling': RandomParameterSampling(parameter_space),
#     'policy': BanditPolicy(evaluation_interval=2, slack_factor=0.2, delay_evaluation=6) # Bandit strategy
# }
#
# #Configuration definition
# automl_image_config = AutoMLImageConfig(task='image-classification', # AutoML task
#                                         compute_target=compute_target, # Compute Target
#                                         training_data=training_dataset, # Training dataset
#                                         validation_data=validation_dataset, # Validation dataset
#                                         primary_metric='accuracy', # AutoML Metric
#                                         **tuning_settings)

# %% [markdown]
# automl_image_run = experiment.submit(automl_image_config)

# %% [markdown]
# automl_image_run.wait_for_completion(wait_post_processing=True)

# %% [markdown]
# > When doing a hyperparameter sweep, **it can be useful to visualize the different configurations that were tried using the HyperDrive UI**. <br><br>You can navigate to this UI by going to the **'Child runs' tab in the UI of the main automl_image_run** from above, which is the HyperDrive parent run. Then you can go into the 'Child runs' tab of this one.

# %%
experiment
# Out:
# Experiment(Name: AutomlImages-Jobs,
# Workspace: automlvision)

# %% [markdown]
# ### You will see all the AutoML runs from the Child runs section.
# The **model column** will display detailled information about each model.<br>
# Example:

# %% [markdown]
# <img src="https://github.com/retkowsky/images/blob/master/automlvision.jpg?raw=true">

# %% [markdown]
# > You can find all the artefacts from the output+logs section of Azure ML

# %% [markdown]
# ## 8. Register the optimal CV model from the AutoML run
# Once the run completes, we can register the model that was created from the best run (configuration that resulted in the best primary metric)

# %%
from azureml.core import Run
hyperdrive_run = Run(experiment=experiment, run_id=automl_image_run.id + '_HD')
hyperdrive_run
# Out:
# Run(Experiment: AutomlImages-Jobs,
# Id: AutoML_437bf282-74c5-41b3-9ff2-31074a7a7987_HD,
# Type: hyperdrive,
# Status: Completed)

# %%
# Defining tags for the custom vision model
cvmodel_tags={"Data": "Images", 
              "Context" : "Jobs Detection",
              "Task" : "Best AutoML Images",
              "Framework" : "AzureML AutoML for Images",
              "AutoML Metric" : "Accuracy"}

# %%
# Register the best model from the AutoML Vision run
best_child_run = automl_image_run.get_best_child()
model_name = best_child_run.properties['model_name']

model = best_child_run.register_model(model_name = model_name,
                                      model_path='outputs/model.pt',
                                      description='Jobs Detection Classification CV model',
                                      tags=cvmodel_tags)

# %%
# We can download the CV model
model.download(target_dir='models', exist_ok=False, exists_ok=None)
# Out:
# 'models/model.pt'

# %%
# Checking the downloaded .pt model file
# !ls models/*.pt -l
# Out:
# -rwxrwxrwx 1 root root 204727704 Jun  7 15:50 models/model.pt

# %% [markdown]
# ### Model informations from the Azure ML model repository

# %%
model
# Out:
# Model(workspace=Workspace.create(name='automlvision', subscription_id='70b8f39e-8863-49f7-b6ba-34a80799550c', resource_group='automlvision-rg'), name=AutoML437bf28270, id=AutoML437bf28270:2, version=2, tags={'Data': 'Images', 'Context': 'Jobs Detection', 'Task': 'Best AutoML Images', 'Framework': 'AzureML AutoML for Images', 'AutoML Metric': 'Accuracy'}, properties={})

# %%
model.id
# Out:
# 'AutoML437bf28270:2'

# %%
model.name
# Out:
# 'AutoML437bf28270'

# %%
model.version
# Out:
# 2

# %%
model.tags
# Out:
# {'Data': 'Images',
#  'Context': 'Jobs Detection',
#  'Task': 'Best AutoML Images',
#  'Framework': 'AzureML AutoML for Images',
#  'AutoML Metric': 'Accuracy'}

# %%
model.created_time
# Out:
# datetime.datetime(2021, 6, 7, 15, 50, 6, 729963, tzinfo=<isodate.tzinfo.Utc object at 0x7f506470d978>)

# %% [markdown]
# ## 9. Deploy model as a web service
# Once you have your trained model, you can deploy the model on Azure. **You can deploy your trained model as a web service on Azure Container Instances ([ACI](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-container-instance)) or Azure Kubernetes Service ([AKS](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-kubernetes-service)).**<br><br> ACI is the perfect option for testing deployments, while AKS is better suited for for high-scale, production usage. <br><br>
# **In this tutorial, we will deploy the model as a web service in AKS.**
# You will need to first create an AKS compute cluster, or use an existing AKS cluster. <br>
# You can use either GPU or CPU VM SKUs for your deployment cluster

# %%
# %%time
from azureml.core.compute import ComputeTarget, AksCompute
from azureml.exceptions import ComputeTargetException

# Choose a name for your cluster
aks_name = "cluster-aks-gpu"

# Check to see if the cluster already exists
try:
    aks_target = ComputeTarget(workspace=ws, name=aks_name)
    print('Found existing compute target.')

except ComputeTargetException:
    print('Creating a new compute target...')
    # Provision AKS cluster with GPU machine
    prov_config = AksCompute.provisioning_configuration(vm_size="STANDARD_NC6", 
                                                        location="eastus2")
    # Create the cluster
    aks_target = ComputeTarget.create(workspace=ws, 
                                      name=aks_name, 
                                      provisioning_configuration=prov_config)
    aks_target.wait_for_completion(show_output=True)
# Out:
# Found existing compute target.
# CPU times: user 14.8 ms, sys: 8.09 ms, total: 22.9 ms
# Wall time: 300 ms

# %% [markdown]
# Next, you will need to define the inference configuration, that describes how to set up the web-service containing your model. You can use the scoring script and the environment from the training run in your inference config.
# You can then deploy the model as an AKS web service.

# %%
from azureml.core.model import InferenceConfig
from azureml.core.webservice import AksWebservice
from azureml.core.webservice import Webservice
from azureml.core.model import Model
from azureml.core.environment import Environment

best_child_run.download_file('outputs/scoring_file_v_1_0_0.py', output_file_path='score.py')
environment = best_child_run.get_environment()

inference_config = InferenceConfig(entry_script='score.py', environment=environment)

endpoint_name='automljobsmodel' #Name of the deployed model

aks_tags={"Data": "Images", 
          "Topic" : "Jobs Detection Custom Vision model", 
          "Task" : "Image Classification",
          "Framework" : "AutoML Images best model", 
          "AKS" : "True"}

aks_description="Computer vision model to detect Jobs"

aks_config = AksWebservice.deploy_configuration(autoscale_enabled=True,                                                    
                                                cpu_cores=1,
                                                memory_gb=50,
                                                enable_app_insights=True,
                                                description=aks_description,
                                                tags=aks_tags)

# %%
# Checking the file we downloaded
# !ls score.py -l
# Out:
# -rwxrwxrwx 1 root root 1921 Jun  7 15:51 score.py

# %%
# Viewing the score.py file
with open(os.path.join('score.py'), 'r') as f:
    print(f.read())
# Out:
# # ---------------------------------------------------------
# # Copyright (c) Microsoft Corporation. All rights reserved.
# # ---------------------------------------------------------
# import os
# import tempfile
# import logging
#
# from azureml.contrib.services.aml_request import rawhttp
# from azureml.automl.core.shared import logging_utilities
# from azureml.contrib.services.aml_response import AMLResponse
#
# from azureml.contrib.automl.dnn.vision.common.utils import _set_logging_parameters
# from azureml.contrib.automl.dnn.vision.common.model_export_utils import load_model, run_inference
# from azureml.contrib.automl.dnn.vision.common.logging_utils import get_logger
#
# from azureml.contrib.automl.dnn.vision.classification.inference.score import _score_with_model
#
# TASK_TYPE = 'image-classification'
# logger = get_logger('azureml.automl.core.scoring_script_images')
#
#
# def init():
#     global model
#
#     # Set up logging
#     _set_logging_parameters(TASK_TYPE, {})
#
#     model_path = os.path.join(os.getenv('AZUREML_MODEL_DIR'), 'model.pt')
#
#     try:
#         logger.info("Loading model from path: {}.".format(model_path))
#         model_settings = {"resize_size": 256, "crop_size": 224}
#         model = load_model(TASK_TYPE, model_path, **model_settings)
#         logger.info("Loading successful.")
#     except Exception as e:
#         logging_utilities.log_traceback(e, logger)
#         raise
#
#
# @rawhttp
# def run(request):
#     logger.info("Request: [{0}]".format(request))
#     if request.method == 'GET':
#         response_body = str.encode(request.full_path)
#         return AMLResponse(response_body, 200)
#     elif request.method == 'POST':
#         request_body = request.get_data()
#         logger.info("Running inference.")
#         result = run_inference(model, request_body, _score_with_model)
#         logger.info("Finished inferencing.")
#         return AMLResponse(result, 200)
#     else:
#         return AMLResponse("bad request", 500)

# %% [markdown]
# ### Let's deploy the CV model into AKS

# %%
# %%time
aks_service = Model.deploy(ws,
                           models=[model],
                           inference_config=inference_config,
                           deployment_config=aks_config,
                           deployment_target=aks_target,
                           name=endpoint_name,
                           overwrite=True)

aks_service.wait_for_deployment(show_output=True)
print()
print("Done. Model is deployed. Ready to use!")
print("\nAKS service status=", aks_service.state)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running
# 2021-06-07 15:51:49+00:00 Creating Container Registry if not exists.
# 2021-06-07 15:51:49+00:00 Registering the environment.
# 2021-06-07 15:51:49+00:00 Use the existing image.
# 2021-06-07 15:51:52+00:00 Creating resources in AKS..
# 2021-06-07 15:51:55+00:00 Submitting deployment to compute.
# 2021-06-07 15:51:56+00:00 Checking the status of deployment automljobsmodel..
# 2021-06-07 15:52:27+00:00 Checking the status of inference endpoint automljobsmodel.
# Succeeded
# AKS service creation operation finished, operation "Succeeded"
#
# Done. Model is deployed. Ready to use!
#
# AKS service status= Healthy
# CPU times: user 279 ms, sys: 65 ms, total: 344 ms
# Wall time: 53 s

# %% [markdown]
# > Usually it takes 2 or 3 minutes to deploy. You can see the endpoint in Azure ML Studio

# %%
print("Computer Vision model endpoint:", aks_service.scoring_uri)
# Out:
# Computer Vision model endpoint: http://52.184.247.39:80/api/v1/service/automljobsmodel/score

# %%
print("Computer Vision model endpoint properties:", aks_service.properties)
# Out:
# Computer Vision model endpoint properties: {'hasInferenceSchema': 'False', 'hasHttps': 'False'}

# %%
print("Computer Vision model endpoint tags:", aks_service.tags)
# Out:
# Computer Vision model endpoint tags: {'Data': 'Images', 'Topic': 'Jobs Detection Custom Vision model', 'Task': 'Image Classification', 'Framework': 'AutoML Images best model', 'AKS': 'True'}

# %%
# You can have access to the logs
print(aks_service.get_logs())
# Out:
# 2021-06-07T15:52:14,610949029+00:00 - iot-server/run
# 2021-06-07T15:52:14,612247416+00:00 - gunicorn/run
# 2021-06-07T15:52:14,612775210+00:00 - nginx/run
# 2021-06-07T15:52:14,613022408+00:00 - rsyslog/run
# EdgeHubConnectionString and IOTEDGE_IOTHUBHOSTNAME are not set. Exiting...
# 2021-06-07T15:52:14,680967907+00:00 - iot-server/finish 1 0
# 2021-06-07T15:52:14,682174494+00:00 - Exit code 1 is normal. Not restarting iot-server.
# Starting gunicorn 20.1.0
# Listening at: http://127.0.0.1:31311 (10)
# Using worker: sync
# worker timeout is set to 300
# Booting worker with pid: 43
# SPARK_HOME not set. Skipping PySpark Initialization.
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception cannot import name 'RunType' from 'azureml.automl.core._run.types' (/azureml-envs/azureml_f203cd3b3834257ea19a1bb09b1dc760/lib/python3.7/site-packages/azureml/automl/core/_run/types.py).
# generated new fontManager
# Initializing logger
# 2021-06-07 15:52:18,912 | root | INFO | Starting up app insights client
# 2021-06-07 15:52:18,913 | root | INFO | Starting up request id generator
# 2021-06-07 15:52:18,913 | root | INFO | Starting up app insight hooks
# 2021-06-07 15:52:18,913 | root | INFO | Invoking user's init function
# 2021-06-07 15:52:18,913 | azureml.core.run | INFO | Could not load the run context. Logging offline
# Could not load the run context. Logging offline
# Loading model from path: /var/azureml-app/azureml-models/AutoML437bf28270/2/model.pt.
# Loading successful.
# 2021-06-07 15:52:21,363 | root | INFO | Users's init has completed successfully
# 2021-06-07 15:52:21,366 | root | INFO | Skipping middleware: dbg_model_info as it's not enabled.
# 2021-06-07 15:52:21,366 | root | INFO | Skipping middleware: dbg_resource_usage as it's not enabled.
# 2021-06-07 15:52:21,366 | root | INFO | Scoring timeout setting is not found. Use default timeout: 3600000 ms
# 2021-06-07 15:52:28,301 | root | INFO | Swagger file not present
# 2021-06-07 15:52:28,301 | root | INFO | 404
# 127.0.0.1 - - [07/Jun/2021:15:52:28 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "hackney/1.17.4"
# 2021-06-07 15:52:29,018 | root | INFO | Swagger file not present
# 2021-06-07 15:52:29,019 | root | INFO | 404
# 127.0.0.1 - - [07/Jun/2021:15:52:29 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "curl/7.67.0"
# 2021-06-07 15:52:32,508 | root | INFO | Swagger file not present
# 2021-06-07 15:52:32,508 | root | INFO | 404
# 127.0.0.1 - - [07/Jun/2021:15:52:32 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "hackney/1.17.4"
# 2021-06-07 15:52:33,213 | root | INFO | Swagger file not present
# 2021-06-07 15:52:33,213 | root | INFO | 404
# 127.0.0.1 - - [07/Jun/2021:15:52:33 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "curl/7.67.0"

# %% [markdown]
# ## 10. Test our deployed CV model
# Finally, let's test our deployed Computer Vision model to predict new images. You can pass in any image.

# %%
print("Our Computer Vision model endpoint:", aks_service.scoring_uri)
print("\nStatus=", aks_service.state)
# Out:
# Our Computer Vision model endpoint: http://52.184.247.39:80/api/v1/service/automljobsmodel/score
#
# Status= Healthy

# %% [markdown]
# ### Test 1

# %% [markdown]
# Let's download an image file to test:

# %%
image_url = 'https://th.bing.com/th/id/Rf488dcd925c90a3dc01abc87e98a0274?rik=GCLhBgI4t84B1A&pid=ImgRaw'
image_file = 'test1.jpg'
urllib.request.urlretrieve(image_url, filename=image_file)
print("Image is downloaded and ready to be predicted.")
# Out:
# Image is downloaded and ready to be predicted.

# %%
import cv2 as cv
img = cv.imread(image_file)
print("Image informations:")
print("- Image filename:", image_file)
print("- Image shape:", img.shape)
print("- Image size:", img.size)
# Out:
# Image informations:
# - Image filename: test1.jpg
# - Image shape: (685, 1024, 3)
# - Image size: 2104320

# %%
from IPython.display import Image
Image(filename=image_file)

# %%
import requests

# URL for the web service
scoring_uri = aks_service.scoring_uri
# If the service is authenticated, set the key or token
key, _ = aks_service.get_keys()
# Load image data
data = open(image_file, 'rb').read()
# Set the content type
headers = {'Content-Type': 'application/octet-stream'}
# If authentication is enabled, set the authorization header
headers['Authorization'] = f'Bearer {key}'
# Make the request and display the response
resp = requests.post(scoring_uri, data, headers=headers)
print("Status code=",resp.status_code)
print("\nElapsed=", resp.elapsed)
print("\nResults=", resp.text)
# Out:
# Status code= 200
#
# Elapsed= 0:00:00.456595
#
# Results= {"filename": "/tmp/tmplsjcmg1n", "probs": [8.875153071130626e-06, 9.256169141735882e-05, 0.0013134608743712306, 3.4178735859313747e-06, 0.8156740665435791, 5.2172495088598225e-06, 0.0008253199048340321, 0.02056126296520233, 0.161515474319458, 3.9555399666824087e-07], "labels": ["chef", "doctor", "engineer", "farmer", "firefighter", "judge", "mechanic", "pilot", "police", "waiter"]}

# %%
prediction=pd.DataFrame(resp.json()) #Convert the Json into a pandas dataframe
prediction.sort_values(by=['probs'], ascending=False)
# Out:
#            filename         probs       labels
# 4  /tmp/tmplsjcmg1n  8.156741e-01  firefighter
# 8  /tmp/tmplsjcmg1n  1.615155e-01       police
# 7  /tmp/tmplsjcmg1n  2.056126e-02        pilot
# 2  /tmp/tmplsjcmg1n  1.313461e-03     engineer
# 6  /tmp/tmplsjcmg1n  8.253199e-04     mechanic
# 1  /tmp/tmplsjcmg1n  9.256169e-05       doctor
# 0  /tmp/tmplsjcmg1n  8.875153e-06         chef
# 5  /tmp/tmplsjcmg1n  5.217250e-06        judge
# 3  /tmp/tmplsjcmg1n  3.417874e-06       farmer
# 9  /tmp/tmplsjcmg1n  3.955540e-07       waiter

# %%
df1 = prediction.apply(pd.to_numeric, args=('coerce',))

# %%
prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs']) # to take the max prob
label = prediction['labels'][label_index]
conf_score = prediction['probs'][label_index]

print("Image file =", image_file)
print("Model prediction =", label, "\nwith Probability =", conf_score)
print("\nThe image is a", label,"with a probability of", round((conf_score*100), 2), "%")
# Out:
# Image file = test1.jpg
# Model prediction = firefighter
# with Probability = 0.8156740665435791
#
# The image is a firefighter with a probability of 81.57 %

# %% [markdown]
# ## Visualize predictions
# Now that we have scored a test image, we can visualize the prediction for this image

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import numpy as np
import json

IMAGE_SIZE = (18,12)
plt.figure(figsize=IMAGE_SIZE)
img_np=mpimg.imread(image_file)
img = Image.fromarray(img_np.astype('uint8'),'RGB')
x, y = img.size

fig,ax = plt.subplots(1, figsize=(15,15))
ax.imshow(img_np)

prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs'])
label = prediction['labels'][label_index]
conf_score = prediction['probs'][label_index]

display_text = '{} ({})'.format(label, round(conf_score, 2))
print(display_text)
color = 'blue' #Text Color
plt.text(70, 70, display_text, color=color, fontsize=50)
fig.savefig('predictiontest1.jpg', dpi=150) #Saving image
plt.show()
# Out:
# firefighter (0.82)

# %% [markdown]
# ### Test 2

# %%
image_url = 'https://th.bing.com/th/id/R342a61197e5a312843a98559a4de9044?rik=SSPx7eTPxGwSSw&riu=http%3a%2f%2fwww.gillespudlowski.com%2fwp-content%2fuploads%2f2010%2f09%2fW0J1685.jpg&ehk=QU6RvQiTjrWbF1yuEKoR6ponFbZy%2bxORLxHuF0L34kM%3d&risl=&pid=ImgRaw'
image_file = 'test2.jpg'
urllib.request.urlretrieve(image_url, filename=image_file)
print("Image is downloaded and ready to be predicted.")
# Out:
# Image is downloaded and ready to be predicted.

# %%
from IPython.display import Image
Image(filename=image_file)

# %%
import cv2 as cv
img = cv.imread(image_file)
print("Image informations:")
print("- Image filename:", image_file)
print("- Image shape:", img.shape)
print("- Image size:", img.size)
# Out:
# Image informations:
# - Image filename: test2.jpg
# - Image shape: (600, 900, 3)
# - Image size: 1620000

# %%
import requests

# URL for the web service
scoring_uri = aks_service.scoring_uri
# If the service is authenticated, set the key or token
key, _ = aks_service.get_keys()
# Load image data
data = open(image_file, 'rb').read()
# Set the content type
headers = {'Content-Type': 'application/octet-stream'}
# If authentication is enabled, set the authorization header
headers['Authorization'] = f'Bearer {key}'
# Make the request and display the response
resp = requests.post(scoring_uri, data, headers=headers)
print("Status code=",resp.status_code)
print("\nElapsed=", resp.elapsed)
print("\nResults=", resp.text)
# Out:
# Status code= 200
#
# Elapsed= 0:00:00.545270
#
# Results= {"filename": "/tmp/tmpba63xiuq", "probs": [3.6367930533742765e-07, 3.9542483136756346e-06, 1.0626923341305883e-08, 1.4411434545724688e-10, 3.4648731106479147e-10, 3.226603340067413e-08, 4.256951735559511e-10, 1.568684865560499e-06, 1.613714033510405e-07, 0.9999939203262329], "labels": ["chef", "doctor", "engineer", "farmer", "firefighter", "judge", "mechanic", "pilot", "police", "waiter"]}

# %%
prediction=pd.DataFrame(resp.json()) #Convert the Json into a pandas dataframe
prediction.sort_values(by='probs', ascending=False)
# Out:
#            filename         probs       labels
# 9  /tmp/tmpba63xiuq  9.999939e-01       waiter
# 1  /tmp/tmpba63xiuq  3.954248e-06       doctor
# 7  /tmp/tmpba63xiuq  1.568685e-06        pilot
# 0  /tmp/tmpba63xiuq  3.636793e-07         chef
# 8  /tmp/tmpba63xiuq  1.613714e-07       police
# 5  /tmp/tmpba63xiuq  3.226603e-08        judge
# 2  /tmp/tmpba63xiuq  1.062692e-08     engineer
# 6  /tmp/tmpba63xiuq  4.256952e-10     mechanic
# 4  /tmp/tmpba63xiuq  3.464873e-10  firefighter
# 3  /tmp/tmpba63xiuq  1.441143e-10       farmer

# %%
prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs'])
label = prediction['labels'][label_index]
conf_score = prediction['probs'][label_index]

print("Image file =", image_file)
print("Model prediction =", label, "\nwith Probability =", conf_score)
print("\nThe image is a", label,"with a probability of", round((conf_score*100), 2), "%")
# Out:
# Image file = test2.jpg
# Model prediction = waiter
# with Probability = 0.9999939203262329
#
# The image is a waiter with a probability of 100.0 %

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import numpy as np
import json

IMAGE_SIZE = (18,12)
plt.figure(figsize=IMAGE_SIZE)
img_np=mpimg.imread(image_file)
img = Image.fromarray(img_np.astype('uint8'),'RGB')
x, y = img.size

fig,ax = plt.subplots(1, figsize=(15,15))
# Display the image
ax.imshow(img_np)

prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs'])
label = prediction['labels'][label_index]
conf_score = prediction['probs'][label_index]

display_text = '{} ({})'.format(label, round(conf_score, 4))
print(display_text)

color = 'red' #Text Color
plt.text(70, 70, display_text, color=color, fontsize=50)

fig.savefig('predictiontest2.jpg', dpi=150) #Saving image

plt.show()
# Out:
# waiter (1.0)

# %% [markdown]
# ### Test 3

# %%
image_url = 'https://th.bing.com/th/id/R846cf91eb377695a47864db028992398?rik=Vps3%2fiTiIALtpQ&riu=http%3a%2f%2fwww.bioalaune.com%2fimg%2farticle%2fthumb%2f900x500%2f26679-interview_de_christophe_lamarliere_agriculteur_bio_grande_echelle.jpg&ehk=goUjlH6oMYbH4rckoPYasKwdsjrRQMo7oTHbjdGCtak%3d&risl=&pid=ImgRaw'
image_file = 'test3.jpg'
urllib.request.urlretrieve(image_url, filename=image_file)
print("Image is downloaded and ready to be predicted.")
# Out:
# Image is downloaded and ready to be predicted.

# %%
from IPython.display import Image
Image(filename=image_file)

# %%
import cv2 as cv
img = cv.imread(image_file)
print("Image informations:")
print("- Image filename:", image_file)
print("- Image shape:", img.shape)
print("- Image size:", img.size)
# Out:
# Image informations:
# - Image filename: test3.jpg
# - Image shape: (495, 900, 3)
# - Image size: 1336500

# %%
import requests

# URL for the web service
scoring_uri = aks_service.scoring_uri
# If the service is authenticated, set the key or token
key, _ = aks_service.get_keys()
# Load image data
data = open(image_file, 'rb').read()
# Set the content type
headers = {'Content-Type': 'application/octet-stream'}
# If authentication is enabled, set the authorization header
headers['Authorization'] = f'Bearer {key}'
# Make the request and display the response
resp = requests.post(scoring_uri, data, headers=headers)
print("Status code=",resp.status_code)
print("\nElapsed=", resp.elapsed)
print("\nResults=", resp.text)
# Out:
# Status code= 200
#
# Elapsed= 0:00:00.541192
#
# Results= {"filename": "/tmp/tmp743tfni6", "probs": [2.6428963906255376e-07, 6.118892542872345e-06, 5.765104106103536e-06, 0.9998788833618164, 7.77085290337709e-07, 2.4266751097457018e-06, 2.910316652560141e-06, 3.7494826301553985e-06, 6.778357055736706e-05, 3.139517139061354e-05], "labels": ["chef", "doctor", "engineer", "farmer", "firefighter", "judge", "mechanic", "pilot", "police", "waiter"]}

# %%
prediction=pd.DataFrame(resp.json()) #Convert the Json into a pandas dataframe
prediction.sort_values(by='probs', ascending=False)
# Out:
#            filename         probs       labels
# 3  /tmp/tmp743tfni6  9.998789e-01       farmer
# 8  /tmp/tmp743tfni6  6.778357e-05       police
# 9  /tmp/tmp743tfni6  3.139517e-05       waiter
# 1  /tmp/tmp743tfni6  6.118893e-06       doctor
# 2  /tmp/tmp743tfni6  5.765104e-06     engineer
# 7  /tmp/tmp743tfni6  3.749483e-06        pilot
# 6  /tmp/tmp743tfni6  2.910317e-06     mechanic
# 5  /tmp/tmp743tfni6  2.426675e-06        judge
# 4  /tmp/tmp743tfni6  7.770853e-07  firefighter
# 0  /tmp/tmp743tfni6  2.642896e-07         chef

# %%
prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs'])
label = prediction['labels'][label_index]
conf_score = prediction['probs'][label_index]

print("Image file =", image_file)
print("Model prediction =", label, "\nwith Probability =", conf_score)
print("\nThe image is a", label,"with a probability of", round((conf_score*100), 2), "%")
# Out:
# Image file = test3.jpg
# Model prediction = farmer
# with Probability = 0.9998788833618164
#
# The image is a farmer with a probability of 99.99 %

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import numpy as np
import json

IMAGE_SIZE = (18,12)
plt.figure(figsize=IMAGE_SIZE)
img_np=mpimg.imread(image_file)
img = Image.fromarray(img_np.astype('uint8'),'RGB')
x, y = img.size

fig,ax = plt.subplots(1, figsize=(15,15))
# Display the image
ax.imshow(img_np)

prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs'])
label = prediction['labels'][label_index]
conf_score = prediction['probs'][label_index]

display_text = '{} ({})'.format(label, round(conf_score, 4))
print(display_text)

color = 'red' #Text Color
plt.text(70, 70, display_text, color=color, fontsize=50)

fig.savefig('predictiontest3.jpg', dpi=150) #Saving image

plt.show()
# Out:
# farmer (0.9999)

# %% [markdown]
# ## 11. Clean up ressources

# %%
aks_service.delete()
compute_target.delete()
model.delete()

# %% [markdown]
# > End of notebook
