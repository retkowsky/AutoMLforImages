# %% [markdown]
# # AutoML for Images
#
# ### Image Classification with Azure ML and AutoML for Images (Image Classification Task)
# Distracted Drivers: https://www.kaggle.com/varanr/distracted-driver-detection/#data

# %% [markdown]
# <img src="https://storage.googleapis.com/kaggle-competitions/kaggle/5048/media/output_DEb8oT.gif">

# %% [markdown]
# ## Setup
# > To use this notebook, **you will need to install the private preview package for AutoML for Images from the private index**.

# %%
#!pip install --upgrade "azureml-train-core<0.1.1" "azureml-train-automl<0.1.1" "azureml-contrib-dataset<0.1.1" --extra-index-url "https://azuremlsdktestpypi.azureedge.net/automl_for_images_private_preview/"

# %% [markdown]
# ## 1. Informations

# %%
import numpy as np
import json
import os
import urllib
from zipfile import ZipFile
import seaborn as sns
import pandas as pd

# %%
import sys
print("Python version =", sys.version)
# Out:
# Python version = 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 19:07:31)
# [GCC 7.3.0]

# %%
import datetime
now = datetime.datetime.now()
print("Today =", now)
# Out:
# Today = 2021-05-06 16:20:44.529366

# %%
import azureml.core
print("You are using Azure ML version", azureml.core.VERSION)
# Out:
# You are using Azure ML version 0.1.0.36312295

# %%
# Your local platform
import platform,socket,re,uuid,json,psutil,logging

def getSystemInfo():
    try:
        info={}
        info['Platform']=platform.system()
        info['Platform-release']=platform.release()
        info['Platform-version']=platform.version()
        info['Architecture']=platform.machine()
        info['Hostname']=socket.gethostname()
        info['IP-address']=socket.gethostbyname(socket.gethostname())
        info['MAC-address']=':'.join(re.findall('..', '%012x' % uuid.getnode()))
        info['Processor']=platform.processor()
        info['RAM']=str(round(psutil.virtual_memory().total / (1024.0 **3)))+" Go"
        return json.dumps(info)
    except Exception as e:
        logging.exception(e)

json.loads(getSystemInfo())
# Out:
# {'Platform': 'Linux',
#  'Platform-release': '5.4.0-1043-azure',
#  'Platform-version': '#45~18.04.1-Ubuntu SMP Sat Mar 20 16:16:05 UTC 2021',
#  'Architecture': 'x86_64',
#  'Hostname': 'computeinstancenbooks',
#  'IP-address': '127.0.0.1',
#  'MAC-address': 'ad:ef:a4:70:9a:e8',
#  'Processor': 'x86_64',
#  'RAM': '27 Go'}

# %% [markdown]
# ## 2. Workspace setup
# In order to train and deploy models in Azure ML, you will first need to set up a workspace.
#
# An [Azure ML Workspace](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#workspace) is an Azure resource that organizes and coordinates the actions of many other Azure resources to assist in executing and sharing machine learning workflows. In particular, an Azure ML Workspace coordinates storage, databases, and compute resources providing added functionality for machine learning experimentation, deployment, inference, and the monitoring of deployed models.
#
# > Create an Azure ML Workspace within your Azure subscription, or load an existing workspace.

# %%
subscription_id='TOBEREPLACED'   
resource_group='automlvision-rg'   
workspace_name='automlvision'

# %%
from azureml.core import Workspace
try:
   ws = Workspace(subscription_id = subscription_id, resource_group = resource_group, workspace_name = workspace_name)
   ws.write_config()
   print("OK")
except:
   print("Error: Workspace not found")
# Out:
# OK

# %%
from azureml.core import Workspace
ws = Workspace.from_config()

# %%
ws.name, ws.resource_group
# Out:
# ('automlvision', 'automlvision-rg')

# %% [markdown]
# ## 3. Azure ML GPU Compute target setup
# **You will need to provide a [Compute Target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) that will be used for your AutoML model training.** <br><br>
# **AutoML models for image tasks require GPU SKUs and support NC and ND families.** We recommend using the NCsv3-series (with v100 GPUs) for faster training. Using a compute target with a multi-GPU VM SKU will leverage the multiple GPUs to speed up training. Additionally, setting up a compute target with multiple nodes will allow for faster model training by leveraging parallelism, when tuning hyperparameters for your model.

# %%
from azureml.core.compute import AmlCompute, ComputeTarget

cluster_name = "gpu-drivers"

try:
    compute_target = ws.compute_targets[cluster_name]
    print('Found existing compute target.')
except KeyError:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_NC6', #GPU cluster
                                                           idle_seconds_before_scaledown=1800, #Time out
                                                           min_nodes=0, 
                                                           max_nodes=4)

    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

# Can poll for a minimum number of nodes and for a specific timeout.
# If no min_node_count is provided, it will use the scale settings for the cluster.
compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
# Out:
# Found existing compute target.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
# Compute status
compute_target.provisioning_state
# Out:
# 'Succeeded'

# %%
# Compute cluster information
compute_target.get_status().serialize()
# Out:
# {'currentNodeCount': 0,
#  'targetNodeCount': 0,
#  'nodeStateCounts': {'preparingNodeCount': 0,
#   'runningNodeCount': 0,
#   'idleNodeCount': 0,
#   'unusableNodeCount': 0,
#   'leavingNodeCount': 0,
#   'preemptedNodeCount': 0},
#  'allocationState': 'Steady',
#  'allocationStateTransitionTime': '2021-05-06T16:19:08.046000+00:00',
#  'errors': None,
#  'creationTime': '2021-05-06T14:54:39.283254+00:00',
#  'modifiedTime': '2021-05-06T14:54:54.727846+00:00',
#  'provisioningState': 'Succeeded',
#  'provisioningStateTransitionTime': None,
#  'scaleSettings': {'minNodeCount': 0,
#   'maxNodeCount': 4,
#   'nodeIdleTimeBeforeScaleDown': 'PT1800S'},
#  'vmPriority': 'Dedicated',
#  'vmSize': 'STANDARD_NC6'}

# %%
# Compute VM size
compute_target.vm_size
# Out:
# 'STANDARD_NC6'

# %%
#List of available compute clusters in your Azure ML workspace
listcomputeservers = ws.compute_targets
for list in listcomputeservers:
    print(list)
# Out:
# cluster-aks-gpu
# cluster-aksgpu
# computeinstancenbooks
# DefLabelNC6
# gpu-mask-classif
# gpu-mask-objdet
# gpu-drivers

# %% [markdown]
# ## 4. Experiment Setup
# Create an [Experiment](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#experiment) in your workspace to track your model training runs

# %%
from azureml.core import Experiment

experiment_name = 'AutomlImages-DistractedDrivers' #Name of your experimentation
experiment = Experiment(ws, name=experiment_name)

# %%
experiment
# Out:
# Experiment(Name: AutomlImages-DistractedDrivers,
# Workspace: automlvision)

# %% [markdown]
# ## 5. Dataset with input Training Data
# In order to generate models for computer vision, you will need to bring in labeled image data as input for model training in the form of an AzureML Labeled Dataset. You can either use a Labeled Dataset that you have exported from a Data Labeling project, or create a new Labeled Dataset with your labeled training data

# %%
# %pwd
# Out:
# '/mnt/batch/tasks/shared/LS_root/mounts/clusters/computeinstancenbooks/code/Users/seretkow/AutoML Distracted Drivers'

# %%
# %mkdir driversimages

# %%
# %cd driversimages
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/computeinstancenbooks/code/Users/seretkow/AutoML Distracted Drivers/driversimages

# %%
# Download images files
download_url = 'https://github.com/retkowsky/CustomVision_Datasets/blob/master/distracteddrivers.zip?raw=true'
zip_file = 'distracteddrivers.zip'
urllib.request.urlretrieve(download_url, filename=zip_file)

# Unzip files
with ZipFile(zip_file, 'r') as zip:
    print('Unzip the zip file...')
    zip.extractall()
    print('Done!')
    
# Delete the downloaded zip file
print("\nDeleting the zip file")
os.remove(zip_file)
print("Done!")
# Out:
# Unzip the zip file...
# Done!
#
# Deleting the zip file
# Done!

# %% [markdown]
# ### List of images files

# %%
# We have some images for the tags in directories we want to detect
print(os.listdir('.'))
# Out:
# ['Drinking', 'Hair and makeup', 'Operating the radio', 'Reaching behind', 'Safe driving', 'Talking on the phone left', 'Talking on the phone right', 'Talking to passengers', 'Texting left', 'Texting right']

# %%
for root, _, files in os.walk('.'):
    print("Dir:", root, "with", len(files), "images files.")
# Out:
# Dir: . with 0 images files.
# Dir: ./Drinking with 50 images files.
# Dir: ./Hair and makeup with 50 images files.
# Dir: ./Operating the radio with 50 images files.
# Dir: ./Reaching behind with 50 images files.
# Dir: ./Safe driving with 50 images files.
# Dir: ./Talking on the phone left with 50 images files.
# Dir: ./Talking on the phone right with 50 images files.
# Dir: ./Talking to passengers with 50 images files.
# Dir: ./Texting left with 50 images files.
# Dir: ./Texting right with 50 images files.

# %%
# %ls *
# Out:
# Drinking:
# 'C6 (1).jpg'*   'C6 (19).jpg'*  'C6 (28).jpg'*  'C6 (37).jpg'*  'C6 (46).jpg'*
# 'C6 (10).jpg'*  'C6 (2).jpg'*   'C6 (29).jpg'*  'C6 (38).jpg'*  'C6 (47).jpg'*
# 'C6 (11).jpg'*  'C6 (20).jpg'*  'C6 (3).jpg'*   'C6 (39).jpg'*  'C6 (48).jpg'*
# 'C6 (12).jpg'*  'C6 (21).jpg'*  'C6 (30).jpg'*  'C6 (4).jpg'*   'C6 (49).jpg'*
# 'C6 (13).jpg'*  'C6 (22).jpg'*  'C6 (31).jpg'*  'C6 (40).jpg'*  'C6 (5).jpg'*
# 'C6 (14).jpg'*  'C6 (23).jpg'*  'C6 (32).jpg'*  'C6 (41).jpg'*  'C6 (50).jpg'*
# 'C6 (15).jpg'*  'C6 (24).jpg'*  'C6 (33).jpg'*  'C6 (42).jpg'*  'C6 (6).jpg'*
# 'C6 (16).jpg'*  'C6 (25).jpg'*  'C6 (34).jpg'*  'C6 (43).jpg'*  'C6 (7).jpg'*
# 'C6 (17).jpg'*  'C6 (26).jpg'*  'C6 (35).jpg'*  'C6 (44).jpg'*  'C6 (8).jpg'*
# 'C6 (18).jpg'*  'C6 (27).jpg'*  'C6 (36).jpg'*  'C6 (45).jpg'*  'C6 (9).jpg'*
#
# 'Hair and makeup':
# 'C8 (1).jpg'*   'C8 (19).jpg'*  'C8 (28).jpg'*  'C8 (37).jpg'*  'C8 (46).jpg'*
# 'C8 (10).jpg'*  'C8 (2).jpg'*   'C8 (29).jpg'*  'C8 (38).jpg'*  'C8 (47).jpg'*
# 'C8 (11).jpg'*  'C8 (20).jpg'*  'C8 (3).jpg'*   'C8 (39).jpg'*  'C8 (48).jpg'*
# 'C8 (12).jpg'*  'C8 (21).jpg'*  'C8 (30).jpg'*  'C8 (4).jpg'*   'C8 (49).jpg'*
# 'C8 (13).jpg'*  'C8 (22).jpg'*  'C8 (31).jpg'*  'C8 (40).jpg'*  'C8 (5).jpg'*
# 'C8 (14).jpg'*  'C8 (23).jpg'*  'C8 (32).jpg'*  'C8 (41).jpg'*  'C8 (50).jpg'*
# 'C8 (15).jpg'*  'C8 (24).jpg'*  'C8 (33).jpg'*  'C8 (42).jpg'*  'C8 (6).jpg'*
# 'C8 (16).jpg'*  'C8 (25).jpg'*  'C8 (34).jpg'*  'C8 (43).jpg'*  'C8 (7).jpg'*
# 'C8 (17).jpg'*  'C8 (26).jpg'*  'C8 (35).jpg'*  'C8 (44).jpg'*  'C8 (8).jpg'*
# 'C8 (18).jpg'*  'C8 (27).jpg'*  'C8 (36).jpg'*  'C8 (45).jpg'*  'C8 (9).jpg'*
#
# 'Operating the radio':
# 'C5 (1).jpg'*   'C5 (19).jpg'*  'C5 (28).jpg'*  'C5 (37).jpg'*  'C5 (46).jpg'*
# 'C5 (10).jpg'*  'C5 (2).jpg'*   'C5 (29).jpg'*  'C5 (38).jpg'*  'C5 (47).jpg'*
# 'C5 (11).jpg'*  'C5 (20).jpg'*  'C5 (3).jpg'*   'C5 (39).jpg'*  'C5 (48).jpg'*
# 'C5 (12).jpg'*  'C5 (21).jpg'*  'C5 (30).jpg'*  'C5 (4).jpg'*   'C5 (49).jpg'*
# 'C5 (13).jpg'*  'C5 (22).jpg'*  'C5 (31).jpg'*  'C5 (40).jpg'*  'C5 (5).jpg'*
# 'C5 (14).jpg'*  'C5 (23).jpg'*  'C5 (32).jpg'*  'C5 (41).jpg'*  'C5 (50).jpg'*
# 'C5 (15).jpg'*  'C5 (24).jpg'*  'C5 (33).jpg'*  'C5 (42).jpg'*  'C5 (6).jpg'*
# 'C5 (16).jpg'*  'C5 (25).jpg'*  'C5 (34).jpg'*  'C5 (43).jpg'*  'C5 (7).jpg'*
# 'C5 (17).jpg'*  'C5 (26).jpg'*  'C5 (35).jpg'*  'C5 (44).jpg'*  'C5 (8).jpg'*
# 'C5 (18).jpg'*  'C5 (27).jpg'*  'C5 (36).jpg'*  'C5 (45).jpg'*  'C5 (9).jpg'*
#
# 'Reaching behind':
# 'C7 (1).jpg'*   'C7 (19).jpg'*  'C7 (28).jpg'*  'C7 (37).jpg'*  'C7 (46).jpg'*
# 'C7 (10).jpg'*  'C7 (2).jpg'*   'C7 (29).jpg'*  'C7 (38).jpg'*  'C7 (47).jpg'*
# 'C7 (11).jpg'*  'C7 (20).jpg'*  'C7 (3).jpg'*   'C7 (39).jpg'*  'C7 (48).jpg'*
# 'C7 (12).jpg'*  'C7 (21).jpg'*  'C7 (30).jpg'*  'C7 (4).jpg'*   'C7 (49).jpg'*
# 'C7 (13).jpg'*  'C7 (22).jpg'*  'C7 (31).jpg'*  'C7 (40).jpg'*  'C7 (5).jpg'*
# 'C7 (14).jpg'*  'C7 (23).jpg'*  'C7 (32).jpg'*  'C7 (41).jpg'*  'C7 (50).jpg'*
# 'C7 (15).jpg'*  'C7 (24).jpg'*  'C7 (33).jpg'*  'C7 (42).jpg'*  'C7 (6).jpg'*
# 'C7 (16).jpg'*  'C7 (25).jpg'*  'C7 (34).jpg'*  'C7 (43).jpg'*  'C7 (7).jpg'*
# 'C7 (17).jpg'*  'C7 (26).jpg'*  'C7 (35).jpg'*  'C7 (44).jpg'*  'C7 (8).jpg'*
# 'C7 (18).jpg'*  'C7 (27).jpg'*  'C7 (36).jpg'*  'C7 (45).jpg'*  'C7 (9).jpg'*
#
# 'Safe driving':
# 'CO (1).jpg'*   'CO (19).jpg'*  'CO (28).jpg'*  'CO (37).jpg'*  'CO (46).jpg'*
# 'CO (10).jpg'*  'CO (2).jpg'*   'CO (29).jpg'*  'CO (38).jpg'*  'CO (47).jpg'*
# 'CO (11).jpg'*  'CO (20).jpg'*  'CO (3).jpg'*   'CO (39).jpg'*  'CO (48).jpg'*
# 'CO (12).jpg'*  'CO (21).jpg'*  'CO (30).jpg'*  'CO (4).jpg'*   'CO (49).jpg'*
# 'CO (13).jpg'*  'CO (22).jpg'*  'CO (31).jpg'*  'CO (40).jpg'*  'CO (5).jpg'*
# 'CO (14).jpg'*  'CO (23).jpg'*  'CO (32).jpg'*  'CO (41).jpg'*  'CO (50).jpg'*
# 'CO (15).jpg'*  'CO (24).jpg'*  'CO (33).jpg'*  'CO (42).jpg'*  'CO (6).jpg'*
# 'CO (16).jpg'*  'CO (25).jpg'*  'CO (34).jpg'*  'CO (43).jpg'*  'CO (7).jpg'*
# 'CO (17).jpg'*  'CO (26).jpg'*  'CO (35).jpg'*  'CO (44).jpg'*  'CO (8).jpg'*
# 'CO (18).jpg'*  'CO (27).jpg'*  'CO (36).jpg'*  'CO (45).jpg'*  'CO (9).jpg'*
#
# 'Talking on the phone left':
# 'C3 (1).jpg'*   'C3 (19).jpg'*  'C3 (28).jpg'*  'C3 (37).jpg'*  'C3 (46).jpg'*
# 'C3 (10).jpg'*  'C3 (2).jpg'*   'C3 (29).jpg'*  'C3 (38).jpg'*  'C3 (47).jpg'*
# 'C3 (11).jpg'*  'C3 (20).jpg'*  'C3 (3).jpg'*   'C3 (39).jpg'*  'C3 (48).jpg'*
# 'C3 (12).jpg'*  'C3 (21).jpg'*  'C3 (30).jpg'*  'C3 (4).jpg'*   'C3 (49).jpg'*
# 'C3 (13).jpg'*  'C3 (22).jpg'*  'C3 (31).jpg'*  'C3 (40).jpg'*  'C3 (5).jpg'*
# 'C3 (14).jpg'*  'C3 (23).jpg'*  'C3 (32).jpg'*  'C3 (41).jpg'*  'C3 (50).jpg'*
# 'C3 (15).jpg'*  'C3 (24).jpg'*  'C3 (33).jpg'*  'C3 (42).jpg'*  'C3 (6).jpg'*
# 'C3 (16).jpg'*  'C3 (25).jpg'*  'C3 (34).jpg'*  'C3 (43).jpg'*  'C3 (7).jpg'*
# 'C3 (17).jpg'*  'C3 (26).jpg'*  'C3 (35).jpg'*  'C3 (44).jpg'*  'C3 (8).jpg'*
# 'C3 (18).jpg'*  'C3 (27).jpg'*  'C3 (36).jpg'*  'C3 (45).jpg'*  'C3 (9).jpg'*
#
# 'Talking on the phone right':
# 'C2 (1).jpg'*   'C2 (19).jpg'*  'C2 (28).jpg'*  'C2 (37).jpg'*  'C2 (46).jpg'*
# 'C2 (10).jpg'*  'C2 (2).jpg'*   'C2 (29).jpg'*  'C2 (38).jpg'*  'C2 (47).jpg'*
# 'C2 (11).jpg'*  'C2 (20).jpg'*  'C2 (3).jpg'*   'C2 (39).jpg'*  'C2 (48).jpg'*
# 'C2 (12).jpg'*  'C2 (21).jpg'*  'C2 (30).jpg'*  'C2 (4).jpg'*   'C2 (49).jpg'*
# 'C2 (13).jpg'*  'C2 (22).jpg'*  'C2 (31).jpg'*  'C2 (40).jpg'*  'C2 (5).jpg'*
# 'C2 (14).jpg'*  'C2 (23).jpg'*  'C2 (32).jpg'*  'C2 (41).jpg'*  'C2 (50).jpg'*
# 'C2 (15).jpg'*  'C2 (24).jpg'*  'C2 (33).jpg'*  'C2 (42).jpg'*  'C2 (6).jpg'*
# 'C2 (16).jpg'*  'C2 (25).jpg'*  'C2 (34).jpg'*  'C2 (43).jpg'*  'C2 (7).jpg'*
# 'C2 (17).jpg'*  'C2 (26).jpg'*  'C2 (35).jpg'*  'C2 (44).jpg'*  'C2 (8).jpg'*
# 'C2 (18).jpg'*  'C2 (27).jpg'*  'C2 (36).jpg'*  'C2 (45).jpg'*  'C2 (9).jpg'*
#
# 'Talking to passengers':
# 'C9 (1).jpg'*   'C9 (19).jpg'*  'C9 (28).jpg'*  'C9 (37).jpg'*  'C9 (46).jpg'*
# 'C9 (10).jpg'*  'C9 (2).jpg'*   'C9 (29).jpg'*  'C9 (38).jpg'*  'C9 (47).jpg'*
# 'C9 (11).jpg'*  'C9 (20).jpg'*  'C9 (3).jpg'*   'C9 (39).jpg'*  'C9 (48).jpg'*
# 'C9 (12).jpg'*  'C9 (21).jpg'*  'C9 (30).jpg'*  'C9 (4).jpg'*   'C9 (49).jpg'*
# 'C9 (13).jpg'*  'C9 (22).jpg'*  'C9 (31).jpg'*  'C9 (40).jpg'*  'C9 (5).jpg'*
# 'C9 (14).jpg'*  'C9 (23).jpg'*  'C9 (32).jpg'*  'C9 (41).jpg'*  'C9 (50).jpg'*
# 'C9 (15).jpg'*  'C9 (24).jpg'*  'C9 (33).jpg'*  'C9 (42).jpg'*  'C9 (6).jpg'*
# 'C9 (16).jpg'*  'C9 (25).jpg'*  'C9 (34).jpg'*  'C9 (43).jpg'*  'C9 (7).jpg'*
# 'C9 (17).jpg'*  'C9 (26).jpg'*  'C9 (35).jpg'*  'C9 (44).jpg'*  'C9 (8).jpg'*
# 'C9 (18).jpg'*  'C9 (27).jpg'*  'C9 (36).jpg'*  'C9 (45).jpg'*  'C9 (9).jpg'*
#
# 'Texting left':
# 'C4 (1).jpg'*   'C4 (19).jpg'*  'C4 (28).jpg'*  'C4 (37).jpg'*  'C4 (46).jpg'*
# 'C4 (10).jpg'*  'C4 (2).jpg'*   'C4 (29).jpg'*  'C4 (38).jpg'*  'C4 (47).jpg'*
# 'C4 (11).jpg'*  'C4 (20).jpg'*  'C4 (3).jpg'*   'C4 (39).jpg'*  'C4 (48).jpg'*
# 'C4 (12).jpg'*  'C4 (21).jpg'*  'C4 (30).jpg'*  'C4 (4).jpg'*   'C4 (49).jpg'*
# 'C4 (13).jpg'*  'C4 (22).jpg'*  'C4 (31).jpg'*  'C4 (40).jpg'*  'C4 (5).jpg'*
# 'C4 (14).jpg'*  'C4 (23).jpg'*  'C4 (32).jpg'*  'C4 (41).jpg'*  'C4 (50).jpg'*
# 'C4 (15).jpg'*  'C4 (24).jpg'*  'C4 (33).jpg'*  'C4 (42).jpg'*  'C4 (6).jpg'*
# 'C4 (16).jpg'*  'C4 (25).jpg'*  'C4 (34).jpg'*  'C4 (43).jpg'*  'C4 (7).jpg'*
# 'C4 (17).jpg'*  'C4 (26).jpg'*  'C4 (35).jpg'*  'C4 (44).jpg'*  'C4 (8).jpg'*
# 'C4 (18).jpg'*  'C4 (27).jpg'*  'C4 (36).jpg'*  'C4 (45).jpg'*  'C4 (9).jpg'*
#
# 'Texting right':
# 'C1 (1).jpg'*   'C1 (19).jpg'*  'C1 (28).jpg'*  'C1 (37).jpg'*  'C1 (46).jpg'*
# 'C1 (10).jpg'*  'C1 (2).jpg'*   'C1 (29).jpg'*  'C1 (38).jpg'*  'C1 (47).jpg'*
# 'C1 (11).jpg'*  'C1 (20).jpg'*  'C1 (3).jpg'*   'C1 (39).jpg'*  'C1 (48).jpg'*
# 'C1 (12).jpg'*  'C1 (21).jpg'*  'C1 (30).jpg'*  'C1 (4).jpg'*   'C1 (49).jpg'*
# 'C1 (13).jpg'*  'C1 (22).jpg'*  'C1 (31).jpg'*  'C1 (40).jpg'*  'C1 (5).jpg'*
# 'C1 (14).jpg'*  'C1 (23).jpg'*  'C1 (32).jpg'*  'C1 (41).jpg'*  'C1 (50).jpg'*
# 'C1 (15).jpg'*  'C1 (24).jpg'*  'C1 (33).jpg'*  'C1 (42).jpg'*  'C1 (6).jpg'*
# 'C1 (16).jpg'*  'C1 (25).jpg'*  'C1 (34).jpg'*  'C1 (43).jpg'*  'C1 (7).jpg'*
# 'C1 (17).jpg'*  'C1 (26).jpg'*  'C1 (35).jpg'*  'C1 (44).jpg'*  'C1 (8).jpg'*
# 'C1 (18).jpg'*  'C1 (27).jpg'*  'C1 (36).jpg'*  'C1 (45).jpg'*  'C1 (9).jpg'*

# %% [markdown]
# ### Some samples:

# %%
# !pwd
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/computeinstancenbooks/code/Users/seretkow/AutoML Distracted Drivers/driversimages

# %%
from IPython.display import Image
sample_image = 'Safe driving/CO (1).jpg'
Image(filename=sample_image)

# %%
sample_image = 'texting right/C1 (1).jpg'
Image(filename=sample_image)

# %%
sample_image = 'Talking on the phone right/C2 (1).jpg'
Image(filename=sample_image)

# %%
sample_image = 'Talking on the phone left/C3 (1).jpg'
Image(filename=sample_image)

# %%
sample_image = 'Texting left/C4 (11).jpg'
Image(filename=sample_image)

# %%
sample_image = 'Operating the radio/C5 (1).jpg'
Image(filename=sample_image)

# %%
sample_image = 'Drinking/c6 (10).jpg'
Image(filename=sample_image)

# %%
sample_image = 'Reaching behind/c7 (10).jpg'
Image(filename=sample_image)

# %%
sample_image = 'Hair and makeup/c8 (11).jpg'
Image(filename=sample_image)

# %%
sample_image = 'Talking to passengers/c9 (2).jpg'
Image(filename=sample_image)

# %% [markdown]
# ### Convert the downloaded data to JSONL

# %%
# %cd ..
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/computeinstancenbooks/code/Users/seretkow/AutoML Distracted Drivers

# %%
src = "driversimages/"

train_validation_ratio = 5

# Retrieving default datastore that got automatically created when we setup a workspace
workspaceblobstore = ws.get_default_datastore().name

# Path to the training and validation files
train_annotations_file = os.path.join(src, "train_annotations.jsonl")
validation_annotations_file = os.path.join(src, "validation_annotations.jsonl")

# sample json line dictionary
json_line_sample = \
    {
        "image_url": "AmlDatastore://" + workspaceblobstore + "/"
                     + os.path.basename(os.path.dirname(src)),
        "label": "",
        "label_confidence": 1.0
    }

index = 0
# Scan each sub directary and generate jsonl line
with open(train_annotations_file, 'w') as train_f:
    with open(validation_annotations_file, 'w') as validation_f:
        for className in os.listdir(src):
            subDir = src + className
            if not os.path.isdir(subDir):
                continue
            # Scan each sub directary
            print("Parsing " + subDir)
            for image in os.listdir(subDir):
                json_line = dict(json_line_sample)
                json_line["image_url"] += f"/{className}/{image}"
                json_line["label"] = className

                if index % train_validation_ratio == 0:
                    # validation annotation
                    validation_f.write(json.dumps(json_line) + "\n")
                else:
                    # train annotation
                    train_f.write(json.dumps(json_line) + "\n")
                index += 1
# Out:
# Parsing driversimages/Drinking
# Parsing driversimages/Hair and makeup
# Parsing driversimages/Operating the radio
# Parsing driversimages/Reaching behind
# Parsing driversimages/Safe driving
# Parsing driversimages/Talking on the phone left
# Parsing driversimages/Talking on the phone right
# Parsing driversimages/Talking to passengers
# Parsing driversimages/Texting left
# Parsing driversimages/Texting right

# %% [markdown]
# ### Upload the JSONL file and images to Datastore
# In order to use the data for training in Azure ML, we upload it to our Azure ML Workspace via a [Datastore](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores). The datastore provides a mechanism for you to upload/download data, and interact with it from your remote compute targets. It is an abstraction over Azure Storage.

# %%
# Retrieving default datastore that got automatically created when we setup a workspace
ds = ws.get_default_datastore()
ds.upload(src_dir='./driversimages/', target_path='driversimages')
# Out:
# Uploading an estimated of 502 files
# Target already exists. Skipping upload for driversimages/train_annotations.jsonl
# Target already exists. Skipping upload for driversimages/validation_annotations.jsonl
# Uploading ./driversimages/Drinking/C6 (1).jpg
# Uploaded ./driversimages/Drinking/C6 (1).jpg, 1 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (10).jpg
# Uploaded ./driversimages/Drinking/C6 (10).jpg, 2 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (11).jpg
# Uploaded ./driversimages/Drinking/C6 (11).jpg, 3 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (12).jpg
# Uploaded ./driversimages/Drinking/C6 (12).jpg, 4 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (13).jpg
# Uploaded ./driversimages/Drinking/C6 (13).jpg, 5 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (14).jpg
# Uploaded ./driversimages/Drinking/C6 (14).jpg, 6 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (15).jpg
# Uploaded ./driversimages/Drinking/C6 (15).jpg, 7 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (16).jpg
# Uploaded ./driversimages/Drinking/C6 (16).jpg, 8 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (17).jpg
# Uploaded ./driversimages/Drinking/C6 (17).jpg, 9 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (18).jpg
# Uploaded ./driversimages/Drinking/C6 (18).jpg, 10 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (19).jpg
# Uploaded ./driversimages/Drinking/C6 (19).jpg, 11 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (2).jpg
# Uploaded ./driversimages/Drinking/C6 (2).jpg, 12 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (20).jpg
# Uploaded ./driversimages/Drinking/C6 (20).jpg, 13 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (21).jpg
# Uploaded ./driversimages/Drinking/C6 (21).jpg, 14 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (22).jpg
# Uploaded ./driversimages/Drinking/C6 (22).jpg, 15 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (23).jpg
# Uploaded ./driversimages/Drinking/C6 (23).jpg, 16 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (24).jpg
# Uploaded ./driversimages/Drinking/C6 (24).jpg, 17 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (25).jpg
# Uploaded ./driversimages/Drinking/C6 (25).jpg, 18 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (26).jpg
# Uploaded ./driversimages/Drinking/C6 (26).jpg, 19 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (27).jpg
# Uploaded ./driversimages/Drinking/C6 (27).jpg, 20 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (28).jpg
# Uploaded ./driversimages/Drinking/C6 (28).jpg, 21 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (29).jpg
# Uploaded ./driversimages/Drinking/C6 (29).jpg, 22 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (3).jpg
# Uploaded ./driversimages/Drinking/C6 (3).jpg, 23 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (30).jpg
# Uploaded ./driversimages/Drinking/C6 (30).jpg, 24 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (31).jpg
# Uploaded ./driversimages/Drinking/C6 (31).jpg, 25 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (32).jpg
# Uploaded ./driversimages/Drinking/C6 (32).jpg, 26 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (33).jpg
# Uploaded ./driversimages/Drinking/C6 (33).jpg, 27 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (34).jpg
# Uploaded ./driversimages/Drinking/C6 (34).jpg, 28 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (35).jpg
# Uploaded ./driversimages/Drinking/C6 (35).jpg, 29 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (36).jpg
# Uploaded ./driversimages/Drinking/C6 (36).jpg, 30 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (37).jpg
# Uploaded ./driversimages/Drinking/C6 (37).jpg, 31 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (38).jpg
# Uploaded ./driversimages/Drinking/C6 (38).jpg, 32 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (39).jpg
# Uploaded ./driversimages/Drinking/C6 (39).jpg, 33 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (4).jpg
# Uploaded ./driversimages/Drinking/C6 (4).jpg, 34 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (40).jpg
# Uploaded ./driversimages/Drinking/C6 (40).jpg, 35 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (41).jpg
# Uploaded ./driversimages/Drinking/C6 (41).jpg, 36 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (42).jpg
# Uploaded ./driversimages/Drinking/C6 (42).jpg, 37 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (43).jpg
# Uploaded ./driversimages/Drinking/C6 (43).jpg, 38 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (44).jpg
# Uploaded ./driversimages/Drinking/C6 (44).jpg, 39 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (45).jpg
# Uploaded ./driversimages/Drinking/C6 (45).jpg, 40 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (46).jpg
# Uploaded ./driversimages/Drinking/C6 (46).jpg, 41 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (47).jpg
# Uploaded ./driversimages/Drinking/C6 (47).jpg, 42 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (48).jpg
# Uploaded ./driversimages/Drinking/C6 (48).jpg, 43 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (49).jpg
# Uploaded ./driversimages/Drinking/C6 (49).jpg, 44 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (5).jpg
# Uploaded ./driversimages/Drinking/C6 (5).jpg, 45 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (50).jpg
# Uploaded ./driversimages/Drinking/C6 (50).jpg, 46 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (6).jpg
# Uploaded ./driversimages/Drinking/C6 (6).jpg, 47 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (7).jpg
# Uploaded ./driversimages/Drinking/C6 (7).jpg, 48 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (8).jpg
# Uploaded ./driversimages/Drinking/C6 (8).jpg, 49 files out of an estimated total of 500
# Uploading ./driversimages/Drinking/C6 (9).jpg
# Uploaded ./driversimages/Drinking/C6 (9).jpg, 50 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (1).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (1).jpg, 51 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (10).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (10).jpg, 52 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (11).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (11).jpg, 53 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (12).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (12).jpg, 54 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (13).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (13).jpg, 55 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (14).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (14).jpg, 56 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (15).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (15).jpg, 57 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (16).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (16).jpg, 58 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (17).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (17).jpg, 59 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (18).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (18).jpg, 60 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (19).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (19).jpg, 61 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (2).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (2).jpg, 62 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (20).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (20).jpg, 63 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (21).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (21).jpg, 64 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (22).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (22).jpg, 65 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (23).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (23).jpg, 66 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (24).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (24).jpg, 67 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (25).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (25).jpg, 68 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (26).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (26).jpg, 69 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (27).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (27).jpg, 70 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (28).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (28).jpg, 71 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (29).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (29).jpg, 72 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (3).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (3).jpg, 73 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (30).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (30).jpg, 74 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (31).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (31).jpg, 75 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (32).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (32).jpg, 76 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (33).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (33).jpg, 77 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (34).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (34).jpg, 78 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (35).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (35).jpg, 79 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (36).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (36).jpg, 80 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (37).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (37).jpg, 81 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (38).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (38).jpg, 82 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (39).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (39).jpg, 83 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (4).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (4).jpg, 84 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (40).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (40).jpg, 85 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (41).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (41).jpg, 86 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (42).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (42).jpg, 87 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (43).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (43).jpg, 88 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (44).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (44).jpg, 89 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (45).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (45).jpg, 90 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (46).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (46).jpg, 91 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (47).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (47).jpg, 92 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (48).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (48).jpg, 93 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (49).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (49).jpg, 94 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (5).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (5).jpg, 95 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (50).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (50).jpg, 96 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (6).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (6).jpg, 97 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (7).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (7).jpg, 98 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (8).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (8).jpg, 99 files out of an estimated total of 500
# Uploading ./driversimages/Hair and makeup/C8 (9).jpg
# Uploaded ./driversimages/Hair and makeup/C8 (9).jpg, 100 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (1).jpg
# Uploaded ./driversimages/Operating the radio/C5 (1).jpg, 101 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (10).jpg
# Uploaded ./driversimages/Operating the radio/C5 (10).jpg, 102 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (11).jpg
# Uploaded ./driversimages/Operating the radio/C5 (11).jpg, 103 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (12).jpg
# Uploaded ./driversimages/Operating the radio/C5 (12).jpg, 104 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (13).jpg
# Uploaded ./driversimages/Operating the radio/C5 (13).jpg, 105 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (14).jpg
# Uploaded ./driversimages/Operating the radio/C5 (14).jpg, 106 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (15).jpg
# Uploaded ./driversimages/Operating the radio/C5 (15).jpg, 107 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (16).jpg
# Uploaded ./driversimages/Operating the radio/C5 (16).jpg, 108 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (17).jpg
# Uploaded ./driversimages/Operating the radio/C5 (17).jpg, 109 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (18).jpg
# Uploaded ./driversimages/Operating the radio/C5 (18).jpg, 110 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (19).jpg
# Uploaded ./driversimages/Operating the radio/C5 (19).jpg, 111 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (2).jpg
# Uploaded ./driversimages/Operating the radio/C5 (2).jpg, 112 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (20).jpg
# Uploaded ./driversimages/Operating the radio/C5 (20).jpg, 113 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (21).jpg
# Uploaded ./driversimages/Operating the radio/C5 (21).jpg, 114 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (22).jpg
# Uploaded ./driversimages/Operating the radio/C5 (22).jpg, 115 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (23).jpg
# Uploaded ./driversimages/Operating the radio/C5 (23).jpg, 116 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (24).jpg
# Uploaded ./driversimages/Operating the radio/C5 (24).jpg, 117 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (25).jpg
# Uploaded ./driversimages/Operating the radio/C5 (25).jpg, 118 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (26).jpg
# Uploaded ./driversimages/Operating the radio/C5 (26).jpg, 119 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (27).jpg
# Uploaded ./driversimages/Operating the radio/C5 (27).jpg, 120 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (28).jpg
# Uploaded ./driversimages/Operating the radio/C5 (28).jpg, 121 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (29).jpg
# Uploaded ./driversimages/Operating the radio/C5 (29).jpg, 122 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (3).jpg
# Uploaded ./driversimages/Operating the radio/C5 (3).jpg, 123 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (30).jpg
# Uploaded ./driversimages/Operating the radio/C5 (30).jpg, 124 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (31).jpg
# Uploaded ./driversimages/Operating the radio/C5 (31).jpg, 125 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (32).jpg
# Uploaded ./driversimages/Operating the radio/C5 (32).jpg, 126 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (33).jpg
# Uploaded ./driversimages/Operating the radio/C5 (33).jpg, 127 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (34).jpg
# Uploaded ./driversimages/Operating the radio/C5 (34).jpg, 128 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (35).jpg
# Uploaded ./driversimages/Operating the radio/C5 (35).jpg, 129 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (36).jpg
# Uploaded ./driversimages/Operating the radio/C5 (36).jpg, 130 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (37).jpg
# Uploaded ./driversimages/Operating the radio/C5 (37).jpg, 131 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (38).jpg
# Uploaded ./driversimages/Operating the radio/C5 (38).jpg, 132 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (39).jpg
# Uploaded ./driversimages/Operating the radio/C5 (39).jpg, 133 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (4).jpg
# Uploaded ./driversimages/Operating the radio/C5 (4).jpg, 134 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (40).jpg
# Uploaded ./driversimages/Operating the radio/C5 (40).jpg, 135 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (41).jpg
# Uploaded ./driversimages/Operating the radio/C5 (41).jpg, 136 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (42).jpg
# Uploaded ./driversimages/Operating the radio/C5 (42).jpg, 137 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (43).jpg
# Uploaded ./driversimages/Operating the radio/C5 (43).jpg, 138 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (44).jpg
# Uploaded ./driversimages/Operating the radio/C5 (44).jpg, 139 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (45).jpg
# Uploaded ./driversimages/Operating the radio/C5 (45).jpg, 140 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (46).jpg
# Uploaded ./driversimages/Operating the radio/C5 (46).jpg, 141 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (47).jpg
# Uploaded ./driversimages/Operating the radio/C5 (47).jpg, 142 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (48).jpg
# Uploaded ./driversimages/Operating the radio/C5 (48).jpg, 143 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (49).jpg
# Uploaded ./driversimages/Operating the radio/C5 (49).jpg, 144 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (5).jpg
# Uploaded ./driversimages/Operating the radio/C5 (5).jpg, 145 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (50).jpg
# Uploaded ./driversimages/Operating the radio/C5 (50).jpg, 146 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (6).jpg
# Uploaded ./driversimages/Operating the radio/C5 (6).jpg, 147 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (7).jpg
# Uploaded ./driversimages/Operating the radio/C5 (7).jpg, 148 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (8).jpg
# Uploaded ./driversimages/Operating the radio/C5 (8).jpg, 149 files out of an estimated total of 500
# Uploading ./driversimages/Operating the radio/C5 (9).jpg
# Uploaded ./driversimages/Operating the radio/C5 (9).jpg, 150 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (1).jpg
# Uploaded ./driversimages/Reaching behind/C7 (1).jpg, 151 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (10).jpg
# Uploaded ./driversimages/Reaching behind/C7 (10).jpg, 152 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (11).jpg
# Uploaded ./driversimages/Reaching behind/C7 (11).jpg, 153 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (12).jpg
# Uploaded ./driversimages/Reaching behind/C7 (12).jpg, 154 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (13).jpg
# Uploaded ./driversimages/Reaching behind/C7 (13).jpg, 155 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (14).jpg
# Uploaded ./driversimages/Reaching behind/C7 (14).jpg, 156 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (15).jpg
# Uploaded ./driversimages/Reaching behind/C7 (15).jpg, 157 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (16).jpg
# Uploaded ./driversimages/Reaching behind/C7 (16).jpg, 158 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (17).jpg
# Uploaded ./driversimages/Reaching behind/C7 (17).jpg, 159 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (18).jpg
# Uploaded ./driversimages/Reaching behind/C7 (18).jpg, 160 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (19).jpg
# Uploaded ./driversimages/Reaching behind/C7 (19).jpg, 161 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (2).jpg
# Uploaded ./driversimages/Reaching behind/C7 (2).jpg, 162 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (20).jpg
# Uploaded ./driversimages/Reaching behind/C7 (20).jpg, 163 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (21).jpg
# Uploaded ./driversimages/Reaching behind/C7 (21).jpg, 164 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (22).jpg
# Uploaded ./driversimages/Reaching behind/C7 (22).jpg, 165 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (23).jpg
# Uploaded ./driversimages/Reaching behind/C7 (23).jpg, 166 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (24).jpg
# Uploaded ./driversimages/Reaching behind/C7 (24).jpg, 167 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (25).jpg
# Uploaded ./driversimages/Reaching behind/C7 (25).jpg, 168 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (26).jpg
# Uploaded ./driversimages/Reaching behind/C7 (26).jpg, 169 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (27).jpg
# Uploaded ./driversimages/Reaching behind/C7 (27).jpg, 170 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (28).jpg
# Uploaded ./driversimages/Reaching behind/C7 (28).jpg, 171 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (29).jpg
# Uploaded ./driversimages/Reaching behind/C7 (29).jpg, 172 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (3).jpg
# Uploaded ./driversimages/Reaching behind/C7 (3).jpg, 173 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (30).jpg
# Uploaded ./driversimages/Reaching behind/C7 (30).jpg, 174 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (31).jpg
# Uploaded ./driversimages/Reaching behind/C7 (31).jpg, 175 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (32).jpg
# Uploaded ./driversimages/Reaching behind/C7 (32).jpg, 176 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (33).jpg
# Uploaded ./driversimages/Reaching behind/C7 (33).jpg, 177 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (34).jpg
# Uploaded ./driversimages/Reaching behind/C7 (34).jpg, 178 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (35).jpg
# Uploaded ./driversimages/Reaching behind/C7 (35).jpg, 179 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (36).jpg
# Uploaded ./driversimages/Reaching behind/C7 (36).jpg, 180 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (37).jpg
# Uploaded ./driversimages/Reaching behind/C7 (37).jpg, 181 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (38).jpg
# Uploaded ./driversimages/Reaching behind/C7 (38).jpg, 182 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (39).jpg
# Uploaded ./driversimages/Reaching behind/C7 (39).jpg, 183 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (4).jpg
# Uploaded ./driversimages/Reaching behind/C7 (4).jpg, 184 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (40).jpg
# Uploaded ./driversimages/Reaching behind/C7 (40).jpg, 185 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (41).jpg
# Uploaded ./driversimages/Reaching behind/C7 (41).jpg, 186 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (42).jpg
# Uploaded ./driversimages/Reaching behind/C7 (42).jpg, 187 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (43).jpg
# Uploaded ./driversimages/Reaching behind/C7 (43).jpg, 188 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (44).jpg
# Uploaded ./driversimages/Reaching behind/C7 (44).jpg, 189 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (45).jpg
# Uploaded ./driversimages/Reaching behind/C7 (45).jpg, 190 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (46).jpg
# Uploaded ./driversimages/Reaching behind/C7 (46).jpg, 191 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (47).jpg
# Uploaded ./driversimages/Reaching behind/C7 (47).jpg, 192 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (48).jpg
# Uploaded ./driversimages/Reaching behind/C7 (48).jpg, 193 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (49).jpg
# Uploaded ./driversimages/Reaching behind/C7 (49).jpg, 194 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (5).jpg
# Uploaded ./driversimages/Reaching behind/C7 (5).jpg, 195 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (50).jpg
# Uploaded ./driversimages/Reaching behind/C7 (50).jpg, 196 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (6).jpg
# Uploaded ./driversimages/Reaching behind/C7 (6).jpg, 197 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (7).jpg
# Uploaded ./driversimages/Reaching behind/C7 (7).jpg, 198 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (8).jpg
# Uploaded ./driversimages/Reaching behind/C7 (8).jpg, 199 files out of an estimated total of 500
# Uploading ./driversimages/Reaching behind/C7 (9).jpg
# Uploaded ./driversimages/Reaching behind/C7 (9).jpg, 200 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (1).jpg
# Uploaded ./driversimages/Safe driving/CO (1).jpg, 201 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (10).jpg
# Uploaded ./driversimages/Safe driving/CO (10).jpg, 202 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (11).jpg
# Uploaded ./driversimages/Safe driving/CO (11).jpg, 203 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (12).jpg
# Uploaded ./driversimages/Safe driving/CO (12).jpg, 204 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (13).jpg
# Uploaded ./driversimages/Safe driving/CO (13).jpg, 205 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (14).jpg
# Uploaded ./driversimages/Safe driving/CO (14).jpg, 206 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (15).jpg
# Uploaded ./driversimages/Safe driving/CO (15).jpg, 207 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (16).jpg
# Uploaded ./driversimages/Safe driving/CO (16).jpg, 208 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (17).jpg
# Uploaded ./driversimages/Safe driving/CO (17).jpg, 209 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (18).jpg
# Uploaded ./driversimages/Safe driving/CO (18).jpg, 210 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (19).jpg
# Uploaded ./driversimages/Safe driving/CO (19).jpg, 211 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (2).jpg
# Uploaded ./driversimages/Safe driving/CO (2).jpg, 212 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (20).jpg
# Uploaded ./driversimages/Safe driving/CO (20).jpg, 213 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (21).jpg
# Uploaded ./driversimages/Safe driving/CO (21).jpg, 214 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (22).jpg
# Uploaded ./driversimages/Safe driving/CO (22).jpg, 215 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (23).jpg
# Uploaded ./driversimages/Safe driving/CO (23).jpg, 216 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (24).jpg
# Uploaded ./driversimages/Safe driving/CO (24).jpg, 217 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (25).jpg
# Uploaded ./driversimages/Safe driving/CO (25).jpg, 218 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (26).jpg
# Uploaded ./driversimages/Safe driving/CO (26).jpg, 219 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (27).jpg
# Uploaded ./driversimages/Safe driving/CO (27).jpg, 220 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (28).jpg
# Uploaded ./driversimages/Safe driving/CO (28).jpg, 221 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (29).jpg
# Uploaded ./driversimages/Safe driving/CO (29).jpg, 222 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (3).jpg
# Uploaded ./driversimages/Safe driving/CO (3).jpg, 223 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (30).jpg
# Uploaded ./driversimages/Safe driving/CO (30).jpg, 224 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (31).jpg
# Uploaded ./driversimages/Safe driving/CO (31).jpg, 225 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (32).jpg
# Uploaded ./driversimages/Safe driving/CO (32).jpg, 226 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (33).jpg
# Uploaded ./driversimages/Safe driving/CO (33).jpg, 227 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (34).jpg
# Uploaded ./driversimages/Safe driving/CO (34).jpg, 228 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (35).jpg
# Uploaded ./driversimages/Safe driving/CO (35).jpg, 229 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (36).jpg
# Uploaded ./driversimages/Safe driving/CO (36).jpg, 230 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (37).jpg
# Uploaded ./driversimages/Safe driving/CO (37).jpg, 231 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (38).jpg
# Uploaded ./driversimages/Safe driving/CO (38).jpg, 232 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (39).jpg
# Uploaded ./driversimages/Safe driving/CO (39).jpg, 233 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (4).jpg
# Uploaded ./driversimages/Safe driving/CO (4).jpg, 234 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (40).jpg
# Uploaded ./driversimages/Safe driving/CO (40).jpg, 235 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (41).jpg
# Uploaded ./driversimages/Safe driving/CO (41).jpg, 236 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (42).jpg
# Uploaded ./driversimages/Safe driving/CO (42).jpg, 237 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (43).jpg
# Uploaded ./driversimages/Safe driving/CO (43).jpg, 238 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (44).jpg
# Uploaded ./driversimages/Safe driving/CO (44).jpg, 239 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (45).jpg
# Uploaded ./driversimages/Safe driving/CO (45).jpg, 240 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (46).jpg
# Uploaded ./driversimages/Safe driving/CO (46).jpg, 241 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (47).jpg
# Uploaded ./driversimages/Safe driving/CO (47).jpg, 242 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (48).jpg
# Uploaded ./driversimages/Safe driving/CO (48).jpg, 243 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (49).jpg
# Uploaded ./driversimages/Safe driving/CO (49).jpg, 244 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (5).jpg
# Uploaded ./driversimages/Safe driving/CO (5).jpg, 245 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (50).jpg
# Uploaded ./driversimages/Safe driving/CO (50).jpg, 246 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (6).jpg
# Uploaded ./driversimages/Safe driving/CO (6).jpg, 247 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (7).jpg
# Uploaded ./driversimages/Safe driving/CO (7).jpg, 248 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (8).jpg
# Uploaded ./driversimages/Safe driving/CO (8).jpg, 249 files out of an estimated total of 500
# Uploading ./driversimages/Safe driving/CO (9).jpg
# Uploaded ./driversimages/Safe driving/CO (9).jpg, 250 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (1).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (1).jpg, 251 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (10).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (10).jpg, 252 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (11).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (11).jpg, 253 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (12).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (12).jpg, 254 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (13).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (13).jpg, 255 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (14).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (14).jpg, 256 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (15).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (15).jpg, 257 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (16).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (16).jpg, 258 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (17).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (17).jpg, 259 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (18).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (18).jpg, 260 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (19).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (19).jpg, 261 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (2).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (2).jpg, 262 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (20).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (20).jpg, 263 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (21).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (21).jpg, 264 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (22).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (22).jpg, 265 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (23).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (23).jpg, 266 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (24).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (24).jpg, 267 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (25).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (25).jpg, 268 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (26).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (26).jpg, 269 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (27).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (27).jpg, 270 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (28).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (28).jpg, 271 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (29).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (29).jpg, 272 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (3).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (3).jpg, 273 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (30).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (30).jpg, 274 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (31).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (31).jpg, 275 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (32).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (32).jpg, 276 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (33).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (33).jpg, 277 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (34).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (34).jpg, 278 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (35).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (35).jpg, 279 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (36).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (36).jpg, 280 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (37).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (37).jpg, 281 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (38).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (38).jpg, 282 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (39).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (39).jpg, 283 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (4).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (4).jpg, 284 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (40).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (40).jpg, 285 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (41).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (41).jpg, 286 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (42).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (42).jpg, 287 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (43).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (43).jpg, 288 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (44).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (44).jpg, 289 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (45).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (45).jpg, 290 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (46).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (46).jpg, 291 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (47).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (47).jpg, 292 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (48).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (48).jpg, 293 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (49).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (49).jpg, 294 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (5).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (5).jpg, 295 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (50).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (50).jpg, 296 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (6).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (6).jpg, 297 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (7).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (7).jpg, 298 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (8).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (8).jpg, 299 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone left/C3 (9).jpg
# Uploaded ./driversimages/Talking on the phone left/C3 (9).jpg, 300 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone right/C2 (1).jpg
# Uploaded ./driversimages/Talking on the phone right/C2 (1).jpg, 301 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone right/C2 (10).jpg
# Uploaded ./driversimages/Talking on the phone right/C2 (10).jpg, 302 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone right/C2 (11).jpg
# Uploaded ./driversimages/Talking on the phone right/C2 (11).jpg, 303 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone right/C2 (12).jpg
# Uploaded ./driversimages/Talking on the phone right/C2 (12).jpg, 304 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone right/C2 (13).jpg
# Uploaded ./driversimages/Talking on the phone right/C2 (13).jpg, 305 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone right/C2 (14).jpg
# Uploaded ./driversimages/Talking on the phone right/C2 (14).jpg, 306 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone right/C2 (15).jpg
# Uploaded ./driversimages/Talking on the phone right/C2 (15).jpg, 307 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone right/C2 (16).jpg
# Uploaded ./driversimages/Talking on the phone right/C2 (16).jpg, 308 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone right/C2 (17).jpg
# Uploaded ./driversimages/Talking on the phone right/C2 (17).jpg, 309 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone right/C2 (18).jpg
# Uploaded ./driversimages/Talking on the phone right/C2 (18).jpg, 310 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone right/C2 (19).jpg
# Uploaded ./driversimages/Talking on the phone right/C2 (19).jpg, 311 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone right/C2 (2).jpg
# Uploaded ./driversimages/Talking on the phone right/C2 (2).jpg, 312 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone right/C2 (20).jpg
# Uploaded ./driversimages/Talking on the phone right/C2 (20).jpg, 313 files out of an estimated total of 500
# Uploading ./driversimages/Talking on the phone right/C2 (21).jpg
# ...
# Uploading ./driversimages/Talking to passengers/C9 (48).jpg
# Uploaded ./driversimages/Talking to passengers/C9 (48).jpg, 393 files out of an estimated total of 500
# Uploading ./driversimages/Talking to passengers/C9 (49).jpg
# Uploaded ./driversimages/Talking to passengers/C9 (49).jpg, 394 files out of an estimated total of 500
# Uploading ./driversimages/Talking to passengers/C9 (5).jpg
# Uploaded ./driversimages/Talking to passengers/C9 (5).jpg, 395 files out of an estimated total of 500
# Uploading ./driversimages/Talking to passengers/C9 (50).jpg
# Uploaded ./driversimages/Talking to passengers/C9 (50).jpg, 396 files out of an estimated total of 500
# Uploading ./driversimages/Talking to passengers/C9 (6).jpg
# Uploaded ./driversimages/Talking to passengers/C9 (6).jpg, 397 files out of an estimated total of 500
# Uploading ./driversimages/Talking to passengers/C9 (7).jpg
# Uploaded ./driversimages/Talking to passengers/C9 (7).jpg, 398 files out of an estimated total of 500
# Uploading ./driversimages/Talking to passengers/C9 (8).jpg
# Uploaded ./driversimages/Talking to passengers/C9 (8).jpg, 399 files out of an estimated total of 500
# Uploading ./driversimages/Talking to passengers/C9 (9).jpg
# Uploaded ./driversimages/Talking to passengers/C9 (9).jpg, 400 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (1).jpg
# Uploaded ./driversimages/Texting left/C4 (1).jpg, 401 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (10).jpg
# Uploaded ./driversimages/Texting left/C4 (10).jpg, 402 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (11).jpg
# Uploaded ./driversimages/Texting left/C4 (11).jpg, 403 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (12).jpg
# Uploaded ./driversimages/Texting left/C4 (12).jpg, 404 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (13).jpg
# Uploaded ./driversimages/Texting left/C4 (13).jpg, 405 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (14).jpg
# Uploaded ./driversimages/Texting left/C4 (14).jpg, 406 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (15).jpg
# Uploaded ./driversimages/Texting left/C4 (15).jpg, 407 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (16).jpg
# Uploaded ./driversimages/Texting left/C4 (16).jpg, 408 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (17).jpg
# Uploaded ./driversimages/Texting left/C4 (17).jpg, 409 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (18).jpg
# Uploaded ./driversimages/Texting left/C4 (18).jpg, 410 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (19).jpg
# Uploaded ./driversimages/Texting left/C4 (19).jpg, 411 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (2).jpg
# Uploaded ./driversimages/Texting left/C4 (2).jpg, 412 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (20).jpg
# Uploaded ./driversimages/Texting left/C4 (20).jpg, 413 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (21).jpg
# Uploaded ./driversimages/Texting left/C4 (21).jpg, 414 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (22).jpg
# Uploaded ./driversimages/Texting left/C4 (22).jpg, 415 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (23).jpg
# Uploaded ./driversimages/Texting left/C4 (23).jpg, 416 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (24).jpg
# Uploaded ./driversimages/Texting left/C4 (24).jpg, 417 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (25).jpg
# Uploaded ./driversimages/Texting left/C4 (25).jpg, 418 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (26).jpg
# Uploaded ./driversimages/Texting left/C4 (26).jpg, 419 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (27).jpg
# Uploaded ./driversimages/Texting left/C4 (27).jpg, 420 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (28).jpg
# Uploaded ./driversimages/Texting left/C4 (28).jpg, 421 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (29).jpg
# Uploaded ./driversimages/Texting left/C4 (29).jpg, 422 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (3).jpg
# Uploaded ./driversimages/Texting left/C4 (3).jpg, 423 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (30).jpg
# Uploaded ./driversimages/Texting left/C4 (30).jpg, 424 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (31).jpg
# Uploaded ./driversimages/Texting left/C4 (31).jpg, 425 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (32).jpg
# Uploaded ./driversimages/Texting left/C4 (32).jpg, 426 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (33).jpg
# Uploaded ./driversimages/Texting left/C4 (33).jpg, 427 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (34).jpg
# Uploaded ./driversimages/Texting left/C4 (34).jpg, 428 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (35).jpg
# Uploaded ./driversimages/Texting left/C4 (35).jpg, 429 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (36).jpg
# Uploaded ./driversimages/Texting left/C4 (36).jpg, 430 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (37).jpg
# Uploaded ./driversimages/Texting left/C4 (37).jpg, 431 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (38).jpg
# Uploaded ./driversimages/Texting left/C4 (38).jpg, 432 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (39).jpg
# Uploaded ./driversimages/Texting left/C4 (39).jpg, 433 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (4).jpg
# Uploaded ./driversimages/Texting left/C4 (4).jpg, 434 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (40).jpg
# Uploaded ./driversimages/Texting left/C4 (40).jpg, 435 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (41).jpg
# Uploaded ./driversimages/Texting left/C4 (41).jpg, 436 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (42).jpg
# Uploaded ./driversimages/Texting left/C4 (42).jpg, 437 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (43).jpg
# Uploaded ./driversimages/Texting left/C4 (43).jpg, 438 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (44).jpg
# Uploaded ./driversimages/Texting left/C4 (44).jpg, 439 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (45).jpg
# Uploaded ./driversimages/Texting left/C4 (45).jpg, 440 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (46).jpg
# Uploaded ./driversimages/Texting left/C4 (46).jpg, 441 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (47).jpg
# Uploaded ./driversimages/Texting left/C4 (47).jpg, 442 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (48).jpg
# Uploaded ./driversimages/Texting left/C4 (48).jpg, 443 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (49).jpg
# Uploaded ./driversimages/Texting left/C4 (49).jpg, 444 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (5).jpg
# Uploaded ./driversimages/Texting left/C4 (5).jpg, 445 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (50).jpg
# Uploaded ./driversimages/Texting left/C4 (50).jpg, 446 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (6).jpg
# Uploaded ./driversimages/Texting left/C4 (6).jpg, 447 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (7).jpg
# Uploaded ./driversimages/Texting left/C4 (7).jpg, 448 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (8).jpg
# Uploaded ./driversimages/Texting left/C4 (8).jpg, 449 files out of an estimated total of 500
# Uploading ./driversimages/Texting left/C4 (9).jpg
# Uploaded ./driversimages/Texting left/C4 (9).jpg, 450 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (1).jpg
# Uploaded ./driversimages/Texting right/C1 (1).jpg, 451 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (10).jpg
# Uploaded ./driversimages/Texting right/C1 (10).jpg, 452 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (11).jpg
# Uploaded ./driversimages/Texting right/C1 (11).jpg, 453 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (12).jpg
# Uploaded ./driversimages/Texting right/C1 (12).jpg, 454 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (13).jpg
# Uploaded ./driversimages/Texting right/C1 (13).jpg, 455 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (14).jpg
# Uploaded ./driversimages/Texting right/C1 (14).jpg, 456 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (15).jpg
# Uploaded ./driversimages/Texting right/C1 (15).jpg, 457 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (16).jpg
# Uploaded ./driversimages/Texting right/C1 (16).jpg, 458 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (17).jpg
# Uploaded ./driversimages/Texting right/C1 (17).jpg, 459 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (18).jpg
# Uploaded ./driversimages/Texting right/C1 (18).jpg, 460 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (19).jpg
# Uploaded ./driversimages/Texting right/C1 (19).jpg, 461 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (2).jpg
# Uploaded ./driversimages/Texting right/C1 (2).jpg, 462 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (20).jpg
# Uploaded ./driversimages/Texting right/C1 (20).jpg, 463 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (21).jpg
# Uploaded ./driversimages/Texting right/C1 (21).jpg, 464 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (22).jpg
# Uploaded ./driversimages/Texting right/C1 (22).jpg, 465 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (23).jpg
# Uploaded ./driversimages/Texting right/C1 (23).jpg, 466 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (24).jpg
# Uploaded ./driversimages/Texting right/C1 (24).jpg, 467 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (25).jpg
# Uploaded ./driversimages/Texting right/C1 (25).jpg, 468 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (26).jpg
# Uploaded ./driversimages/Texting right/C1 (26).jpg, 469 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (27).jpg
# Uploaded ./driversimages/Texting right/C1 (27).jpg, 470 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (28).jpg
# Uploaded ./driversimages/Texting right/C1 (28).jpg, 471 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (29).jpg
# Uploaded ./driversimages/Texting right/C1 (29).jpg, 472 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (3).jpg
# Uploaded ./driversimages/Texting right/C1 (3).jpg, 473 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (30).jpg
# Uploaded ./driversimages/Texting right/C1 (30).jpg, 474 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (31).jpg
# Uploaded ./driversimages/Texting right/C1 (31).jpg, 475 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (32).jpg
# Uploaded ./driversimages/Texting right/C1 (32).jpg, 476 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (33).jpg
# Uploaded ./driversimages/Texting right/C1 (33).jpg, 477 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (35).jpg
# Uploaded ./driversimages/Texting right/C1 (35).jpg, 478 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (36).jpg
# Uploaded ./driversimages/Texting right/C1 (36).jpg, 479 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (37).jpg
# Uploaded ./driversimages/Texting right/C1 (37).jpg, 480 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (38).jpg
# Uploaded ./driversimages/Texting right/C1 (38).jpg, 481 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (39).jpg
# Uploaded ./driversimages/Texting right/C1 (39).jpg, 482 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (4).jpg
# Uploaded ./driversimages/Texting right/C1 (4).jpg, 483 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (40).jpg
# Uploaded ./driversimages/Texting right/C1 (40).jpg, 484 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (41).jpg
# Uploaded ./driversimages/Texting right/C1 (41).jpg, 485 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (42).jpg
# Uploaded ./driversimages/Texting right/C1 (42).jpg, 486 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (43).jpg
# Uploaded ./driversimages/Texting right/C1 (43).jpg, 487 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (46).jpg
# Uploaded ./driversimages/Texting right/C1 (46).jpg, 488 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (47).jpg
# Uploaded ./driversimages/Texting right/C1 (47).jpg, 489 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (34).jpg
# Uploaded ./driversimages/Texting right/C1 (34).jpg, 490 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (44).jpg
# Uploaded ./driversimages/Texting right/C1 (44).jpg, 491 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (45).jpg
# Uploaded ./driversimages/Texting right/C1 (45).jpg, 492 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (48).jpg
# Uploaded ./driversimages/Texting right/C1 (48).jpg, 493 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (49).jpg
# Uploaded ./driversimages/Texting right/C1 (49).jpg, 494 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (5).jpg
# Uploaded ./driversimages/Texting right/C1 (5).jpg, 495 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (50).jpg
# Uploaded ./driversimages/Texting right/C1 (50).jpg, 496 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (6).jpg
# Uploaded ./driversimages/Texting right/C1 (6).jpg, 497 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (7).jpg
# Uploaded ./driversimages/Texting right/C1 (7).jpg, 498 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (8).jpg
# Uploaded ./driversimages/Texting right/C1 (8).jpg, 499 files out of an estimated total of 500
# Uploading ./driversimages/Texting right/C1 (9).jpg
# Uploaded ./driversimages/Texting right/C1 (9).jpg, 500 files out of an estimated total of 500
# Uploaded 500 files
# $AZUREML_DATAREFERENCE_ee926a92f5c94b648f905457fa09227b

# %%
ds
# Out:
# {
#   "name": "workspaceblobstore",
#   "container_name": "azureml-blobstore-35b5972d-bf00-4fce-9a9c-e87051db5dc3",
#   "account_name": "automlvision2130847930",
#   "protocol": "https",
#   "endpoint": "core.windows.net"
# }

# %% [markdown]
# Finally, we need to create an Azure ML [Dataset](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores) from the data we uploaded to the Datastore. We create one dataset for training and one for validation.

# %%
from azureml.contrib.dataset.labeled_dataset import _LabeledDatasetFactory, LabeledDatasetTask
from azureml.core import Dataset

training_dataset_name = 'DriversTrainingDataset'
if training_dataset_name in ws.datasets:
    training_dataset = ws.datasets.get(training_dataset_name)
    print('Found the training dataset', training_dataset_name)
else:
    # create training dataset
    training_dataset = _LabeledDatasetFactory.from_json_lines(
        task=LabeledDatasetTask.IMAGE_CLASSIFICATION, path=ds.path('driversimages/train_annotations.jsonl'))
    training_dataset = training_dataset.register(workspace=ws, name=training_dataset_name)
    
# create validation dataset
validation_dataset_name = "DriversValidationDataset"
if validation_dataset_name in ws.datasets:
    validation_dataset = ws.datasets.get(validation_dataset_name)
    print('Found the validation dataset', validation_dataset_name)
else:
    validation_dataset = _LabeledDatasetFactory.from_json_lines(
        task=LabeledDatasetTask.IMAGE_CLASSIFICATION, path=ds.path('driversimages/validation_annotations.jsonl'))
    validation_dataset = validation_dataset.register(workspace=ws, name=validation_dataset_name)

print()
print("Training dataset name:" + training_dataset.name)
print("Validation dataset name:" + validation_dataset.name)
# Out:
# Training dataset name:DriversTrainingDataset
# Validation dataset name:DriversValidationDataset

# %% [markdown]
# Validation dataset is optional. If no validation dataset is specified, by default 20% of your training data will be used for validation. You can control the percentage using the `split_ratio` argument - please refer to the documentation for more details.
#
# This is what the training dataset looks like

# %%
images=training_dataset.to_pandas_dataframe()

# %%
images.head(10)
# Out:
#                                            image_url            label  \
# 0  StreamInfo(AmlDatastore://driversimages/C0 Saf...  C0 Safe driving
# 1  StreamInfo(AmlDatastore://driversimages/C0 Saf...  C0 Safe driving
# 2  StreamInfo(AmlDatastore://driversimages/C0 Saf...  C0 Safe driving
# 3  StreamInfo(AmlDatastore://driversimages/C0 Saf...  C0 Safe driving
# 4  StreamInfo(AmlDatastore://driversimages/C0 Saf...  C0 Safe driving
# 5  StreamInfo(AmlDatastore://driversimages/C0 Saf...  C0 Safe driving
# 6  StreamInfo(AmlDatastore://driversimages/C0 Saf...  C0 Safe driving
# 7  StreamInfo(AmlDatastore://driversimages/C0 Saf...  C0 Safe driving
# 8  StreamInfo(AmlDatastore://driversimages/C0 Saf...  C0 Safe driving
# 9  StreamInfo(AmlDatastore://driversimages/C0 Saf...  C0 Safe driving
#
#    label_confidence
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# 5               1.0
# 6               1.0
# 7               1.0
# 8               1.0
# 9               1.0

# %%
images['label'].value_counts()
# Out:
# C4 Talking on the phone left     40
# C0 Safe driving                  40
# C9 Talking to passengers         40
# C7 Reaching behind               40
# C8 Hair and makeup               40
# C2 Talking on the phone right    40
# C1 Texting right                 40
# C5 Operating the radio           40
# C3 Texting left                  40
# C6 Drinking                      40
# Name: label, dtype: int64

# %%
images.shape
# Out:
# (400, 3)

# %%
# Percentage values
images['label'].value_counts(normalize=True)
# Out:
# C4 Talking on the phone left     0.1
# C0 Safe driving                  0.1
# C9 Talking to passengers         0.1
# C7 Reaching behind               0.1
# C8 Hair and makeup               0.1
# C2 Talking on the phone right    0.1
# C1 Texting right                 0.1
# C5 Operating the radio           0.1
# C3 Texting left                  0.1
# C6 Drinking                      0.1
# Name: label, dtype: float64

# %% [markdown]
# ## 6. Configuring your AutoML run for image tasks
# AutoML allows you to easily train models for Image Classification, Object Detection & Instance Segmentation on your image data. You can control the model algorithm to be used, specify hyperparameter values for your model as well as perform a sweep across the hyperparameter space to generate an optimal model. Parameters for configuring your AutoML runs for image related tasks are specified using the 'AutoMLImageConfig' - please refer to the [documentation](https://github.com/swatig007/automlForImages#readme) for the details on the parameters that can be used and their values.

# %% [markdown]
# When using AutoML for image tasks, you need to specify the model algorithms using the `model_name` parameter. You can either specify a single model or choose to sweep over multiple ones.<br><br> **Currently supported model algorithms for image classification: 'resnet18', 'resnet34', 'resnet50', 'mobilenetv2', 'seresnext'.**
#
# ### Using default hyperparameter values for the specified algorithm
#
# Before doing a large sweep to search for the optimal models and hyperparameters, we recommend trying the default values to get a first baseline. Next, you can explore multiple hyperparameters for the same model before sweeping over multiple models and their parameters. This is for employing a more iterative approach, because with multiple models and multiple hyperparameters for each (as we showcase in the next section), the search space grows exponentially and you need more iterations to find optimal configurations.
#
# If you wish to use the default hyperparameter values for a given algorithm (say **resnet50**), you can specify the config for your AutoML Image runs as follows:

# %%
from azureml.train.automl import AutoMLImageConfig
from azureml.train.hyperdrive import RandomParameterSampling
from azureml.train.hyperdrive import GridParameterSampling
from azureml.train.hyperdrive import choice

# %%
# AutoML Configuration
image_config_resnet34 = AutoMLImageConfig(task='image-classification', # AutoML Vision task
                                          compute_target=compute_target, # Compute target
                                          training_data=training_dataset, # Training dataset
                                          validation_data=validation_dataset, # Validation dataset
                                          hyperparameter_sampling=GridParameterSampling({'model_name': 
                                                                                        choice('resnet34')})) # CV Model

# %% [markdown]
# ## 7. Submitting an AutoML run for Computer Vision tasks
# Once you've created the config settings for your run, **you can submit an AutoML run** using the config in order to train a vision model using your training dataset.

# %%
automl_image_run = experiment.submit(image_config_resnet34)
# Out:
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>AutomlImages-DistractedDrivers</td><td>AutoML_fb9e2ec7-4531-43f5-a931-74c49de2c021</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_fb9e2ec7-4531-43f5-a931-74c49de2c021?wsid=/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/automlvision-rg/workspaces/automlvision&amp;tid=72f988bf-86f1-41af-91ab-2d7cd011db47" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %%
automl_image_run.wait_for_completion(wait_post_processing=True) # Wait until automl run is finished
# Out:
# {'runId': 'AutoML_fb9e2ec7-4531-43f5-a931-74c49de2c021',
#  'target': 'gpu-drivers',
#  'status': 'Completed',
#  'startTimeUtc': '2021-05-06T16:26:15.435603Z',
#  'endTimeUtc': '2021-05-06T16:36:24.6766Z',
#  'properties': {'num_iterations': '1',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'accuracy',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': None,
#   'target': 'gpu-drivers',
#   'AMLSettingsJsonString': '{"path":null,"name":"AutomlImages-DistractedDrivers","subscription_id":"70b8f39e-8863-49f7-b6ba-34a80799550c","resource_group":"automlvision-rg","workspace_name":"automlvision","region":"westeurope","compute_target":"gpu-drivers","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":false,"enable_run_restructure":false,"start_auxiliary_runs_before_parent_complete":false,"iterations":1,"primary_metric":"accuracy","task_type":"image-classification","data_script":null,"test_size":0.0,"validation_size":0.0,"n_cross_validations":null,"y_min":null,"y_max":null,"num_classes":null,"featurization":"off","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":1,"max_concurrent_iterations":1,"iteration_timeout_minutes":null,"mem_in_mb":null,"enforce_time_on_windows":false,"experiment_timeout_minutes":8640,"experiment_exit_score":null,"whitelist_models":null,"blacklist_algos":["TensorFlowDNN","TensorFlowLinearRegressor"],"supported_models":[],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":false,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"STANDARD_NC6","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":true,"scenario":"Vision","environment_label":null,"save_mlflow":false,"force_text_dnn":false,"enable_feature_sweeping":true,"enable_early_stopping":false,"early_stopping_n_iters":10,"arguments":null,"dataset_id":"f20dd12a-78b9-4bd3-9bed-4b850b48cbe3","hyperdrive_config":{"max_total_jobs":1,"max_concurrent_jobs":1,"generator_config":{"name":"GRID","parameter_space":"{\\"model_name\\": [\\"choice\\", [[\\"resnet34\\"]]]}","properties":null},"policy_config":null},"validation_dataset_id":"f037d75a-0643-45be-852c-7ed355028f1f","metrics":null,"enable_metric_confidence":false,"enable_ensembling":false,"enable_stack_ensembling":false,"ensemble_iterations":null,"enable_tf":false,"enable_subsampling":false,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"allowed_private_models":[],"label_column_name":"label","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":false}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"f20dd12a-78b9-4bd3-9bed-4b850b48cbe3\\"}, \\"validation_data\\": {\\"datasetId\\": \\"f037d75a-0643-45be-852c-7ed355028f1f\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': 'False',
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'automl',
#   'display_task_type': 'image-classification',
#   'dependencies_versions': '{"azureml-widgets": "1.26.0", "azureml-train": "1.26.0", "azureml-train-restclients-hyperdrive": "0.1.0.36312295", "azureml-train-core": "0.1.0.36312295", "azureml-train-automl": "0.1.0.36312295", "azureml-train-automl-runtime": "0.1.0.36312295", "azureml-train-automl-client": "0.1.0.36312295", "azureml-tensorboard": "1.26.0", "azureml-telemetry": "0.1.0.36312295", "azureml-sdk": "1.26.0", "azureml-samples": "0+unknown", "azureml-pipeline": "1.26.0", "azureml-pipeline-steps": "1.26.0", "azureml-pipeline-core": "1.26.0", "azureml-opendatasets": "1.26.0", "azureml-model-management-sdk": "1.0.1b6.post1", "azureml-mlflow": "1.26.0", "azureml-interpret": "0.1.0.36312295", "azureml-explain-model": "1.26.0", "azureml-defaults": "0.1.0.36312295", "azureml-dataset-runtime": "0.1.0.36312295", "azureml-dataprep": "2.14.2", "azureml-dataprep-rslex": "1.12.1", "azureml-dataprep-native": "33.0.0", "azureml-datadrift": "1.26.0", "azureml-core": "0.1.0.36312295", "azureml-contrib-services": "1.26.0", "azureml-contrib-server": "1.26.0", "azureml-contrib-reinforcementlearning": "1.26.0", "azureml-contrib-pipeline-steps": "1.26.0", "azureml-contrib-notebook": "1.26.0", "azureml-contrib-gbdt": "1.26.0", "azureml-contrib-fairness": "1.26.0", "azureml-contrib-dataset": "0.1.0.36312295", "azureml-cli-common": "1.26.0", "azureml-automl-runtime": "0.1.0.36312295", "azureml-automl-dnn-nlp": "1.26.0", "azureml-automl-core": "0.1.0.36312295", "azureml-accel-models": "1.26.0"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'environment_cpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_cpu_label': 'Latest',
#   'environment_gpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_gpu_label': 'Latest',
#   'root_attribution': 'automl',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://westeurope.api.azureml.ms/jasmine/v1.0/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourceGroups/automlvision-rg/providers/Microsoft.MachineLearningServices/workspaces/automlvision/experimentids/30970416-445e-4dda-a4d6-ed0d1a647081/cancel/AutoML_fb9e2ec7-4531-43f5-a931-74c49de2c021',
#   'ClientSdkVersion': '1.27.0.post1',
#   'snapshotId': '00000000-0000-0000-0000-000000000000'},
#  'inputDatasets': [{'dataset': {'id': 'f20dd12a-78b9-4bd3-9bed-4b850b48cbe3'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}, {'dataset': {'id': 'f037d75a-0643-45be-852c-7ed355028f1f'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'validation_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Serge Retkowsky'}

# %%
automl_image_run.id
# Out:
# 'AutoML_fb9e2ec7-4531-43f5-a931-74c49de2c021'

# %%
experiment
# Out:
# Experiment(Name: AutomlImages-DistractedDrivers,
# Workspace: automlvision)

# %%
# List of all the AutoML for Images metrics values
automlvisionmetrics = automl_image_run.get_metrics()
metricsdf=pd.DataFrame(automl_image_run.get_metrics()) # Convert to a pandas df
metricsdf
# Out:
#     precision  average_class_precision  recall  average_class_recall  \
# 0       2.843                    2.843     8.0                   8.0
# 1      10.870                   10.870    20.0                  20.0
# 2      27.943                   27.943    30.0                  30.0
# 3      55.521                   55.521    47.0                  47.0
# 4      65.354                   65.354    58.0                  58.0
# 5      70.156                   70.156    61.0                  61.0
# 6      75.143                   75.143    63.0                  63.0
# 7      77.541                   77.541    72.0                  72.0
# 8      88.131                   88.131    83.0                  83.0
# 9      88.674                   88.674    81.0                  81.0
# 10     87.994                   87.994    83.0                  83.0
# 11     89.228                   89.228    85.0                  85.0
# 12     85.852                   85.852    83.0                  83.0
# 13     85.515                   85.515    83.0                  83.0
# 14     86.455                   86.455    84.0                  84.0
#
#     average_class_f1_score  average_class_f2_score  average_sample_f1_score  \
# 0                    3.735                   5.159                      8.0
# 1                   12.319                  14.869                     20.0
# 2                   22.698                  25.887                     30.0
# 3                   44.869                  45.255                     47.0
# 4                   56.991                  56.460                     58.0
# 5                   61.607                  60.598                     61.0
# 6                   62.550                  61.724                     63.0
# 7                   71.464                  70.928                     72.0
# 8                   83.513                  82.650                     83.0
# 9                   81.998                  80.644                     81.0
# 10                  83.562                  82.670                     83.0
# 11                  85.146                  84.582                     85.0
# 12                  82.905                  82.652                     83.0
# 13                  82.865                  82.677                     83.0
# 14                  84.076                  83.785                     84.0
#
#      iou  average_sample_f2_score  accuracy
# 0    8.0                      8.0       8.0
# 1   20.0                     20.0      20.0
# 2   30.0                     30.0      30.0
# 3   47.0                     47.0      47.0
# 4   58.0                     58.0      58.0
# 5   61.0                     61.0      61.0
# 6   63.0                     63.0      63.0
# 7   72.0                     72.0      72.0
# 8   83.0                     83.0      83.0
# 9   81.0                     81.0      81.0
# 10  83.0                     83.0      83.0
# 11  85.0                     85.0      85.0
# 12  83.0                     83.0      83.0
# 13  83.0                     83.0      83.0
# 14  84.0                     84.0      84.0

# %%
# Let's plot the accuracy metric for the CV model, save the graph to a jpg file and log it to the Azure ML experiment
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize = (15,7))
plt.plot(automlvisionmetrics['accuracy'], 'r-', lw=4, alpha=.6)
plt.xlabel('iterations', fontsize=10)
plt.ylabel('accuracy', fontsize=10)
plt.title('resnet34 CV model accuracy', fontsize=12)

plt.savefig('accuracy_resnet34.jpg', dpi=150) # Saving image in a jpg file
automl_image_run.log_image(name='accuracy_resnet34.jpg', plot=plt) # Logging the graph into the Azure ML experiment

plt.show()

# %%
# Checking the output graph
# !ls accuracy_resnet34.jpg -l
# Out:
# -rwxrwxrwx 1 root root 95684 May  6 16:38 accuracy_resnet34.jpg

# %%
# You can view the jpg file in the experiment
experiment
# Out:
# Experiment(Name: AutomlImages-DistractedDrivers,
# Workspace: automlvision)

# %% [markdown]
# ## Let's improve using additionals models & hyperparameter tuning

# %% [markdown]
# ### Hyperparameter sweeping for your AutoML models for computer vision tasks
#
# When using AutoML for Images, you can perform a hyperparameter sweep over a defined parameter space, to find the optimal model. In this example, we sweep over the hyperparameters for each algorithm, **choosing from a range of values for learning_rate, optimizer, lr_scheduler, etc, to generate a model with the optimal 'accuracy'.** If hyperparameter values are not specified, then default values are used for the specified algorithm.
#
# We use **Random Sampling to pick samples from this parameter space and try a total of 20 iterations** with these different samples, running 4 iterations at a time on our compute target, which has been previously set up using 4 nodes. Please note that the more parameters the space has, the more iterations you need to find optimal models.
#
# We also leverage the **Bandit early termination policy** that terminates poor performing configs (those that are not within 20% slack of the best perfroming config), thus significantly saving compute resources.

# %% [markdown]
# ### List of model available for Image classification:
# Resnet18, Resnet34, Resnet50, Mobilenetv2, seresnext

# %%
from azureml.train.automl import AutoMLImageConfig
from azureml.train.hyperdrive import GridParameterSampling, RandomParameterSampling, BayesianParameterSampling
from azureml.train.hyperdrive import BanditPolicy, HyperDriveConfig, PrimaryMetricGoal
from azureml.train.hyperdrive import choice, uniform

#Options for the parameter space
parameter_space = {
    'model': choice(
        {
            'model_name': choice('seresnext', 'resnet50', 'resnet34', 'resnet18',  'mobilenetv2'),
            'learning_rate': uniform(0.0001, 0.01),
            'optimizer': choice('sgd', 'adam'),
            'layers_to_freeze': choice(0, 1, 2, 3, 4),

        },
        {
            'model_name': choice('seresnext'),
            'resize_size': choice(288, 320, 352), # model-specific
            'crop_size': choice(224, 256), # model-specific, crop_size should be smaller or equal than resize_size
        }
    )
}

#Options for the tuning part
tuning_settings = {
    'iterations': 20,
    'max_concurrent_iterations': 4, 
    'hyperparameter_sampling': RandomParameterSampling(parameter_space),  
    'policy': BanditPolicy(evaluation_interval=2, slack_factor=0.2, delay_evaluation=6) # Bandit strategy
}

#Configuration definition
automl_image_config = AutoMLImageConfig(task='image-classification', # AutoML task
                                        compute_target=compute_target, # Compute Target
                                        training_data=training_dataset, # Training dataset
                                        validation_data=validation_dataset, # Validation dataset
                                        primary_metric='accuracy', # AutoML Metric
                                        **tuning_settings)

# %%
automl_image_run = experiment.submit(automl_image_config)
# Out:
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>AutomlImages-DistractedDrivers</td><td>AutoML_5796f01c-594c-4d16-81f4-621a334336fc</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_5796f01c-594c-4d16-81f4-621a334336fc?wsid=/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/automlvision-rg/workspaces/automlvision&amp;tid=72f988bf-86f1-41af-91ab-2d7cd011db47" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %%
automl_image_run.wait_for_completion(wait_post_processing=True)
# Out:
# {'runId': 'AutoML_5796f01c-594c-4d16-81f4-621a334336fc',
#  'target': 'gpu-drivers',
#  'status': 'Completed',
#  'startTimeUtc': '2021-05-06T16:40:16.837847Z',
#  'endTimeUtc': '2021-05-06T17:09:46.020388Z',
#  'properties': {'num_iterations': '1',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'accuracy',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': None,
#   'target': 'gpu-drivers',
#   'AMLSettingsJsonString': '{"path":null,"name":"AutomlImages-DistractedDrivers","subscription_id":"70b8f39e-8863-49f7-b6ba-34a80799550c","resource_group":"automlvision-rg","workspace_name":"automlvision","region":"westeurope","compute_target":"gpu-drivers","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":false,"enable_run_restructure":false,"start_auxiliary_runs_before_parent_complete":false,"iterations":1,"primary_metric":"accuracy","task_type":"image-classification","data_script":null,"test_size":0.0,"validation_size":0.0,"n_cross_validations":null,"y_min":null,"y_max":null,"num_classes":null,"featurization":"off","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":1,"max_concurrent_iterations":1,"iteration_timeout_minutes":null,"mem_in_mb":null,"enforce_time_on_windows":false,"experiment_timeout_minutes":8640,"experiment_exit_score":null,"whitelist_models":null,"blacklist_algos":["TensorFlowDNN","TensorFlowLinearRegressor"],"supported_models":[],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":false,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"STANDARD_NC6","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":true,"scenario":"Vision","environment_label":null,"save_mlflow":false,"force_text_dnn":false,"enable_feature_sweeping":true,"enable_early_stopping":false,"early_stopping_n_iters":10,"arguments":null,"dataset_id":"f20dd12a-78b9-4bd3-9bed-4b850b48cbe3","hyperdrive_config":{"max_total_jobs":20,"max_concurrent_jobs":4,"generator_config":{"name":"RANDOM","parameter_space":"{\\"model\\": [\\"choice\\", [[{\\"model_name\\": [\\"choice\\", [[\\"seresnext\\", \\"resnet50\\", \\"resnet34\\", \\"resnet18\\", \\"mobilenetv2\\"]]], \\"learning_rate\\": [\\"uniform\\", [0.0001, 0.01]], \\"optimizer\\": [\\"choice\\", [[\\"sgd\\", \\"adam\\"]]], \\"layers_to_freeze\\": [\\"choice\\", [[0, 1, 2, 3, 4]]]}, {\\"model_name\\": [\\"choice\\", [[\\"seresnext\\"]]], \\"resize_size\\": [\\"choice\\", [[288, 320, 352]]], \\"crop_size\\": [\\"choice\\", [[224, 256]]]}]]]}","properties":null},"policy_config":{"name":"Bandit","properties":{"evaluation_interval":2,"delay_evaluation":6,"slack_factor":0.2}}},"validation_dataset_id":"f037d75a-0643-45be-852c-7ed355028f1f","metrics":null,"enable_metric_confidence":false,"enable_ensembling":false,"enable_stack_ensembling":false,"ensemble_iterations":null,"enable_tf":false,"enable_subsampling":false,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"allowed_private_models":[],"label_column_name":"label","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":false}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"f20dd12a-78b9-4bd3-9bed-4b850b48cbe3\\"}, \\"validation_data\\": {\\"datasetId\\": \\"f037d75a-0643-45be-852c-7ed355028f1f\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': 'False',
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'automl',
#   'display_task_type': 'image-classification',
#   'dependencies_versions': '{"azureml-widgets": "1.26.0", "azureml-train": "1.26.0", "azureml-train-restclients-hyperdrive": "0.1.0.36312295", "azureml-train-core": "0.1.0.36312295", "azureml-train-automl": "0.1.0.36312295", "azureml-train-automl-runtime": "0.1.0.36312295", "azureml-train-automl-client": "0.1.0.36312295", "azureml-tensorboard": "1.26.0", "azureml-telemetry": "0.1.0.36312295", "azureml-sdk": "1.26.0", "azureml-samples": "0+unknown", "azureml-pipeline": "1.26.0", "azureml-pipeline-steps": "1.26.0", "azureml-pipeline-core": "1.26.0", "azureml-opendatasets": "1.26.0", "azureml-model-management-sdk": "1.0.1b6.post1", "azureml-mlflow": "1.26.0", "azureml-interpret": "0.1.0.36312295", "azureml-explain-model": "1.26.0", "azureml-defaults": "0.1.0.36312295", "azureml-dataset-runtime": "0.1.0.36312295", "azureml-dataprep": "2.14.2", "azureml-dataprep-rslex": "1.12.1", "azureml-dataprep-native": "33.0.0", "azureml-datadrift": "1.26.0", "azureml-core": "0.1.0.36312295", "azureml-contrib-services": "1.26.0", "azureml-contrib-server": "1.26.0", "azureml-contrib-reinforcementlearning": "1.26.0", "azureml-contrib-pipeline-steps": "1.26.0", "azureml-contrib-notebook": "1.26.0", "azureml-contrib-gbdt": "1.26.0", "azureml-contrib-fairness": "1.26.0", "azureml-contrib-dataset": "0.1.0.36312295", "azureml-cli-common": "1.26.0", "azureml-automl-runtime": "0.1.0.36312295", "azureml-automl-dnn-nlp": "1.26.0", "azureml-automl-core": "0.1.0.36312295", "azureml-accel-models": "1.26.0"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'environment_cpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_cpu_label': 'Latest',
#   'environment_gpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_gpu_label': 'Latest',
#   'root_attribution': 'automl',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://westeurope.api.azureml.ms/jasmine/v1.0/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourceGroups/automlvision-rg/providers/Microsoft.MachineLearningServices/workspaces/automlvision/experimentids/30970416-445e-4dda-a4d6-ed0d1a647081/cancel/AutoML_5796f01c-594c-4d16-81f4-621a334336fc',
#   'ClientSdkVersion': '1.27.0.post1',
#   'snapshotId': '00000000-0000-0000-0000-000000000000'},
#  'inputDatasets': [{'dataset': {'id': 'f20dd12a-78b9-4bd3-9bed-4b850b48cbe3'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}, {'dataset': {'id': 'f037d75a-0643-45be-852c-7ed355028f1f'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'validation_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Serge Retkowsky'}

# %% [markdown]
# > When doing a hyperparameter sweep, **it can be useful to visualize the different configurations that were tried using the HyperDrive UI**. <br><br>You can navigate to this UI by going to the **'Child runs' tab in the UI of the main automl_image_run** from above, which is the HyperDrive parent run. Then you can go into the 'Child runs' tab of this one.

# %%
experiment
# Out:
# Experiment(Name: AutomlImages-DistractedDrivers,
# Workspace: automlvision)

# %% [markdown]
# ### You will see all the AutoML runs from the Child runs section.
# The **model column** will display detailled information about each model.<br>
# Example:

# %% [markdown]
# <img src="https://github.com/retkowsky/images/blob/master/automlvision.jpg?raw=true">

# %% [markdown]
# > You can find all the artefacts from the output+logs section of Azure ML

# %% [markdown]
# ## 8. Register the optimal CV model from the AutoML run
# Once the run completes, we can register the model that was created from the best run (configuration that resulted in the best primary metric)

# %%
from azureml.core import Run
hyperdrive_run = Run(experiment=experiment, run_id=automl_image_run.id + '_HD')
hyperdrive_run
# Out:
# Run(Experiment: AutomlImages-DistractedDrivers,
# Id: AutoML_5796f01c-594c-4d16-81f4-621a334336fc_HD,
# Type: hyperdrive,
# Status: Completed)

# %%
# Defining tags for the custom vision model
cvmodel_tags={"Data": "Images", 
              "Context" : "Distracted Drivers",
              "Task" : "Best AutoML Images",
              "Framework" : "AzureML AutoML for Images",
              "AutoML Metric" : "Accuracy"}

# %%
# Register the best model from the AutoML Vision run
best_child_run = automl_image_run.get_best_child()
model_name = best_child_run.properties['model_name']

model = best_child_run.register_model(model_name = model_name,
                                      model_path='outputs/model.pt',
                                      description='Distracted Drivers CV model',
                                      tags=cvmodel_tags)

# %%
# We can download the CV model
model.download(target_dir='.', exist_ok=False, exists_ok=None)
# Out:
# 'model.pt'

# %%
# Checking the downloaded .pt model file
# !ls model.pt -l
# Out:
# -rwxrwxrwx 1 root root 204727832 May  6 17:11 model.pt

# %% [markdown]
# ### Model informations from the Azure ML model repository

# %%
model
# Out:
# Model(workspace=Workspace.create(name='automlvision', subscription_id='70b8f39e-8863-49f7-b6ba-34a80799550c', resource_group='automlvision-rg'), name=AutoML5796f01c56, id=AutoML5796f01c56:1, version=1, tags={'Data': 'Images', 'Context': 'Distracted Drivers', 'Task': 'Best AutoML Images', 'Framework': 'AzureML AutoML for Images', 'AutoML Metric': 'Accuracy'}, properties={})

# %%
model.id
# Out:
# 'AutoML5796f01c56:1'

# %%
model.name
# Out:
# 'AutoML5796f01c56'

# %%
model.version
# Out:
# 1

# %%
model.tags
# Out:
# {'Data': 'Images',
#  'Context': 'Distracted Drivers',
#  'Task': 'Best AutoML Images',
#  'Framework': 'AzureML AutoML for Images',
#  'AutoML Metric': 'Accuracy'}

# %%
model.created_time
# Out:
# datetime.datetime(2021, 5, 6, 17, 11, 52, 337749, tzinfo=<isodate.tzinfo.Utc object at 0x7f18d23ea080>)

# %% [markdown]
# ## 9. Deploy model as a web service
# Once you have your trained model, you can deploy the model on Azure. **You can deploy your trained model as a web service on Azure Container Instances ([ACI](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-container-instance)) or Azure Kubernetes Service ([AKS](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-kubernetes-service)).**<br><br> ACI is the perfect option for testing deployments, while AKS is better suited for for high-scale, production usage. <br><br>
# **In this tutorial, we will deploy the model as a web service in AKS.**
# You will need to first create an AKS compute cluster, or use an existing AKS cluster. <br>
# You can use either GPU or CPU VM SKUs for your deployment cluster

# %%
# %%time
from azureml.core.compute import ComputeTarget, AksCompute
from azureml.exceptions import ComputeTargetException

# Choose a name for your cluster
aks_name = "cluster-aksgpu"

# Check to see if the cluster already exists
try:
    aks_target = ComputeTarget(workspace=ws, name=aks_name)
    print('Found existing compute target.')
except ComputeTargetException:
    print('Creating a new compute target...')
    # Provision AKS cluster with GPU machine
    prov_config = AksCompute.provisioning_configuration(vm_size="STANDARD_NC6", 
                                                        location="eastus2")
    # Create the cluster
    aks_target = ComputeTarget.create(workspace=ws, 
                                      name=aks_name, 
                                      provisioning_configuration=prov_config)
    aks_target.wait_for_completion(show_output=True)
# Out:
# Found existing compute target.
# CPU times: user 11.6 ms, sys: 12.4 ms, total: 23.9 ms
# Wall time: 162 ms

# %% [markdown]
# Next, you will need to define the inference configuration, that describes how to set up the web-service containing your model. You can use the scoring script and the environment from the training run in your inference config.
# You can then deploy the model as an AKS web service.

# %%
# Settings

from azureml.core.model import InferenceConfig
from azureml.core.webservice import AksWebservice
from azureml.core.webservice import Webservice
from azureml.core.model import Model
from azureml.core.environment import Environment

best_child_run.download_file('outputs/scoring_file_v_1_0_0.py', output_file_path='score.py')
environment = best_child_run.get_environment()
inference_config = InferenceConfig(entry_script='score.py', environment=environment)

endpoint_name='automldistracteddrivers' #Name of the deployed model

aks_tags={"Data": "Images", 
          "Topic" : "Distracted Drivers Custom Vision model", 
          "Task" : "Image Classification",
          "Framework" : "AutoML Images best model", 
          "AKS" : "True"}

aks_description="Computer vision model to detect Distracted Drivers"

aks_config = AksWebservice.deploy_configuration(autoscale_enabled=True,                                                    
                                                cpu_cores=1,
                                                memory_gb=50,
                                                enable_app_insights=True,
                                                description=aks_description,
                                                tags=aks_tags)

# %%
# Checking the file we downloaded
# !ls score.py -l
# Out:
# -rwxrwxrwx 1 root root 1921 May  6 17:12 score.py

# %%
# Viewing the score.py file
with open(os.path.join('score.py'), 'r') as f:
    print(f.read())
# Out:
# # ---------------------------------------------------------
# # Copyright (c) Microsoft Corporation. All rights reserved.
# # ---------------------------------------------------------
# import os
# import tempfile
# import logging
#
# from azureml.contrib.services.aml_request import rawhttp
# from azureml.automl.core.shared import logging_utilities
# from azureml.contrib.services.aml_response import AMLResponse
#
# from azureml.contrib.automl.dnn.vision.common.utils import _set_logging_parameters
# from azureml.contrib.automl.dnn.vision.common.model_export_utils import load_model, run_inference
# from azureml.contrib.automl.dnn.vision.common.logging_utils import get_logger
#
# from azureml.contrib.automl.dnn.vision.classification.inference.score import _score_with_model
#
# TASK_TYPE = 'image-classification'
# logger = get_logger('azureml.automl.core.scoring_script_images')
#
#
# def init():
#     global model
#
#     # Set up logging
#     _set_logging_parameters(TASK_TYPE, {})
#
#     model_path = os.path.join(os.getenv('AZUREML_MODEL_DIR'), 'model.pt')
#
#     try:
#         logger.info("Loading model from path: {}.".format(model_path))
#         model_settings = {"resize_size": 256, "crop_size": 224}
#         model = load_model(TASK_TYPE, model_path, **model_settings)
#         logger.info("Loading successful.")
#     except Exception as e:
#         logging_utilities.log_traceback(e, logger)
#         raise
#
#
# @rawhttp
# def run(request):
#     logger.info("Request: [{0}]".format(request))
#     if request.method == 'GET':
#         response_body = str.encode(request.full_path)
#         return AMLResponse(response_body, 200)
#     elif request.method == 'POST':
#         request_body = request.get_data()
#         logger.info("Running inference.")
#         result = run_inference(model, request_body, _score_with_model)
#         logger.info("Finished inferencing.")
#         return AMLResponse(result, 200)
#     else:
#         return AMLResponse("bad request", 500)

# %% [markdown]
# ### Let's deploy the CV model into AKS

# %%
# %%time
aks_service = Model.deploy(ws,
                           models=[model],
                           inference_config=inference_config,
                           deployment_config=aks_config,
                           deployment_target=aks_target,
                           name=endpoint_name,
                           overwrite=True)

aks_service.wait_for_deployment(show_output=True)

print("\nDone. Model is deployed. Ready to use!")
print("\nAKS service status=", aks_service.state)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running
# 2021-05-06 17:12:18+00:00 Creating Container Registry if not exists.
# 2021-05-06 17:12:18+00:00 Registering the environment..
# 2021-05-06 17:12:22+00:00 Use the existing image.
# 2021-05-06 17:12:25+00:00 Creating resources in AKS..
# 2021-05-06 17:12:28+00:00 Submitting deployment to compute.
# 2021-05-06 17:12:28+00:00 Checking the status of deployment automldistracteddrivers..
# 2021-05-06 17:13:00+00:00 Checking the status of inference endpoint automldistracteddrivers.
# Succeeded
# AKS service creation operation finished, operation "Succeeded"
#
# Done. Model is deployed. Ready to use!
#
# AKS service status= Healthy
# CPU times: user 387 ms, sys: 44 ms, total: 431 ms
# Wall time: 57.1 s

# %% [markdown]
# > Usually it takes 2 or 3 minutes to deploy. You can see the endpoint in Azure ML Studio

# %%
print("CV model endpoint:", aks_service.scoring_uri)
# Out:
# CV model endpoint: http://20.72.78.101:80/api/v1/service/automldistracteddrivers/score

# %%
print("CV model endpoint properties:", aks_service.properties)
# Out:
# CV model endpoint properties: {'hasInferenceSchema': 'False', 'hasHttps': 'False'}

# %%
print("CV model endpoint tags:", aks_service.tags)
# Out:
# CV model endpoint tags: {'Data': 'Images', 'Topic': 'Distracted Drivers Custom Vision model', 'Task': 'Image Classification', 'Framework': 'AutoML Images best model', 'AKS': 'True'}

# %%
# You can have access to the logs
#print(aks_service.get_logs())

# %% [markdown]
# ## 10. Test our deployed CV model
# Finally, let's test our deployed Computer Vision model to predict new images. You can pass in any image.

# %%
print("Our CV model endpoint:", aks_service.scoring_uri)
print("\nStatus=", aks_service.state)
# Out:
# Our CV model endpoint: http://20.72.78.101:80/api/v1/service/automldistracteddrivers/score
#
# Status= Healthy

# %% [markdown]
# ### Test 1

# %% [markdown]
# Let's download an image file to test:

# %%
image_url = 'https://github.com/retkowsky/CustomVision_Datasets/blob/master/Test%20(1).jpg?raw=true'
image_file = 'test1.jpg'
urllib.request.urlretrieve(image_url, filename=image_file)
print("Image is downloaded and ready to be predicted.")
# Out:
# Image is downloaded and ready to be predicted.

# %%
import cv2 as cv
img = cv.imread(image_file)
print("Image informations:")
print("- Image filename:", image_file)
print("- Image shape:", img.shape)
print("- Image size:", img.size)
# Out:
# Image informations:
# - Image filename: test1.jpg
# - Image shape: (480, 640, 3)
# - Image size: 921600

# %%
from IPython.display import Image
Image(filename=image_file)

# %%
import requests

# URL for the web service
scoring_uri = aks_service.scoring_uri

# If the service is authenticated, set the key or token
key, _ = aks_service.get_keys()

# Load image data
data = open(image_file, 'rb').read()

# Set the content type
headers = {'Content-Type': 'application/octet-stream'}

# If authentication is enabled, set the authorization header
headers['Authorization'] = f'Bearer {key}'

# Make the request and display the response
resp = requests.post(scoring_uri, data, headers=headers)
print("Status code=",resp.status_code)
print("Elapsed=", resp.elapsed)
print("Results=", resp.text)
# Out:
# Status code= 200
# Elapsed= 0:00:00.362690
# Results= {"filename": "/tmp/tmphxxotqfu", "probs": [0.0002897828526329249, 0.0017640087753534317, 1.981965033337474e-05, 0.0011074821231886744, 5.666612560162321e-05, 0.00010159391240449622, 5.490180046763271e-05, 0.9951554536819458, 0.00012607109965756536, 0.001324267708696425], "labels": ["C0 Safe driving", "C1 Texting right", "C2 Talking on the phone right", "C3 Texting left", "C4 Talking on the phone left", "C5 Operating the radio", "C6 Drinking", "C7 Reaching behind", "C8 Hair and makeup", "C9 Talking to passengers"]}

# %%
prediction=pd.DataFrame(resp.json()) #Convert the Json into a pandas dataframe
prediction.sort_values(by='probs', ascending=False)
# Out:
#            filename     probs                         labels
# 7  /tmp/tmphxxotqfu  0.995155             C7 Reaching behind
# 1  /tmp/tmphxxotqfu  0.001764               C1 Texting right
# 9  /tmp/tmphxxotqfu  0.001324       C9 Talking to passengers
# 3  /tmp/tmphxxotqfu  0.001107                C3 Texting left
# 0  /tmp/tmphxxotqfu  0.000290                C0 Safe driving
# 8  /tmp/tmphxxotqfu  0.000126             C8 Hair and makeup
# 5  /tmp/tmphxxotqfu  0.000102         C5 Operating the radio
# 4  /tmp/tmphxxotqfu  0.000057   C4 Talking on the phone left
# 6  /tmp/tmphxxotqfu  0.000055                    C6 Drinking
# 2  /tmp/tmphxxotqfu  0.000020  C2 Talking on the phone right

# %%
prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs']) # to take the max prob
label = prediction['labels'][label_index]
proba = prediction['probs'][label_index]

print("Image file =", image_file)
print("Model prediction =", label, "\nwith Probability =", proba)
print("\nThe image is someone who is", label,"with a probability of", round((proba*100), 2), "%")
# Out:
# Image file = test1.jpg
# Model prediction = C7 Reaching behind
# with Probability = 0.9951554536819458
#
# The image is someone who is C7 Reaching behind with a probability of 99.52 %

# %% [markdown]
# ## Visualize predictions
# Now that we have scored a test image, we can visualize the prediction for this image

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import numpy as np
import json

IMAGE_SIZE = (18,12)
plt.figure(figsize=IMAGE_SIZE)
img_np=mpimg.imread(image_file)
img = Image.fromarray(img_np.astype('uint8'),'RGB')
x, y = img.size

fig,ax = plt.subplots(1, figsize=(15,15))
# Display the image
ax.imshow(img_np)

prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs'])
label = prediction['labels'][label_index]
proba = prediction['probs'][label_index]

display_text = '{} ({})'.format(label, round(proba, 4))
print(display_text)

color = 'red' # Text color
plt.text(30, 30, display_text, color=color, fontsize=30)

fig.savefig('predictiontest1.jpg', dpi=150) #Saving image

plt.show()
# Out:
# C7 Reaching behind (0.9952)

# %% [markdown]
# ### Test 2

# %%
image_url = 'https://github.com/retkowsky/CustomVision_Datasets/blob/master/Test%20(3).jpg?raw=true'
image_file = 'test2.jpg'
urllib.request.urlretrieve(image_url, filename=image_file)
print("Image is downloaded and ready to be predicted.")
# Out:
# Image is downloaded and ready to be predicted.

# %%
from IPython.display import Image
Image(filename=image_file)

# %%
import cv2 as cv
img = cv.imread(image_file)
print("Image informations:")
print("- Image filename:", image_file)
print("- Image shape:", img.shape)
print("- Image size:", img.size)
# Out:
# Image informations:
# - Image filename: test2.jpg
# - Image shape: (480, 640, 3)
# - Image size: 921600

# %%
import requests

# URL for the web service
scoring_uri = aks_service.scoring_uri

# If the service is authenticated, set the key or token
key, _ = aks_service.get_keys()

# Load image data
data = open(image_file, 'rb').read()

# Set the content type
headers = {'Content-Type': 'application/octet-stream'}

# If authentication is enabled, set the authorization header
headers['Authorization'] = f'Bearer {key}'

# Make the request and display the response
resp = requests.post(scoring_uri, data, headers=headers)
print("Status code=",resp.status_code)
print("Elapsed=", resp.elapsed)
print("Results=", resp.text)
# Out:
# Status code= 200
# Elapsed= 0:00:00.353781
# Results= {"filename": "/tmp/tmp6folxa72", "probs": [0.0009686320554465055, 5.3286221373127773e-05, 0.9901577830314636, 0.0010986266424879432, 0.0005069135804660618, 0.0001168654125649482, 0.00013770662189926952, 0.00033322826493531466, 0.004995984025299549, 0.0016309372149407864], "labels": ["C0 Safe driving", "C1 Texting right", "C2 Talking on the phone right", "C3 Texting left", "C4 Talking on the phone left", "C5 Operating the radio", "C6 Drinking", "C7 Reaching behind", "C8 Hair and makeup", "C9 Talking to passengers"]}

# %%
prediction=pd.DataFrame(resp.json()) #Convert the Json into a pandas dataframe
prediction.sort_values(by='probs', ascending=False)
# Out:
#            filename     probs                         labels
# 2  /tmp/tmp6folxa72  0.990158  C2 Talking on the phone right
# 8  /tmp/tmp6folxa72  0.004996             C8 Hair and makeup
# 9  /tmp/tmp6folxa72  0.001631       C9 Talking to passengers
# 3  /tmp/tmp6folxa72  0.001099                C3 Texting left
# 0  /tmp/tmp6folxa72  0.000969                C0 Safe driving
# 4  /tmp/tmp6folxa72  0.000507   C4 Talking on the phone left
# 7  /tmp/tmp6folxa72  0.000333             C7 Reaching behind
# 6  /tmp/tmp6folxa72  0.000138                    C6 Drinking
# 5  /tmp/tmp6folxa72  0.000117         C5 Operating the radio
# 1  /tmp/tmp6folxa72  0.000053               C1 Texting right

# %%
prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs'])
label = prediction['labels'][label_index]
conf_score = prediction['probs'][label_index]

print("Image file =", image_file)
print("Model prediction =", label, "\nwith Probability =", conf_score)
print("\nThe image is someone who is", label,"with a probability of", round((conf_score*100), 2), "%")
# Out:
# Image file = test2.jpg
# Model prediction = C2 Talking on the phone right
# with Probability = 0.9901577830314636
#
# The image is someone who is C2 Talking on the phone right with a probability of 99.02 %

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import numpy as np
import json

IMAGE_SIZE = (18,12)
plt.figure(figsize=IMAGE_SIZE)
img_np=mpimg.imread(image_file)
img = Image.fromarray(img_np.astype('uint8'),'RGB')
x, y = img.size

fig,ax = plt.subplots(1, figsize=(15,15))
# Display the image
ax.imshow(img_np)

prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs'])
label = prediction['labels'][label_index]
conf_score = prediction['probs'][label_index]

display_text = '{} ({})'.format(label, round(conf_score, 4))
print(display_text)

color = 'red' #Text Color
plt.text(30, 30, display_text, color=color, fontsize=30)

fig.savefig('predictiontest2.jpg', dpi=150) #Saving image

plt.show()
# Out:
# C2 Talking on the phone right (0.9902)

# %% [markdown]
# ### Test 3

# %%
image_url = 'https://github.com/retkowsky/CustomVision_Datasets/blob/master/Test%20(24).jpg?raw=true'
image_file = 'test3.jpg'
urllib.request.urlretrieve(image_url, filename=image_file)
print("Image is downloaded and ready to be predicted.")
# Out:
# Image is downloaded and ready to be predicted.

# %%
from IPython.display import Image
Image(filename=image_file)

# %%
import cv2 as cv
img = cv.imread(image_file)
print("Image informations:")
print("- Image filename:", image_file)
print("- Image shape:", img.shape)
print("- Image size:", img.size)
# Out:
# Image informations:
# - Image filename: test3.jpg
# - Image shape: (480, 640, 3)
# - Image size: 921600

# %%
import requests

# URL for the web service
scoring_uri = aks_service.scoring_uri

# If the service is authenticated, set the key or token
key, _ = aks_service.get_keys()

# Load image data
data = open(image_file, 'rb').read()

# Set the content type
headers = {'Content-Type': 'application/octet-stream'}

# If authentication is enabled, set the authorization header
headers['Authorization'] = f'Bearer {key}'

# Make the request and display the response
resp = requests.post(scoring_uri, data, headers=headers)
print("Status code=",resp.status_code)
print("Elapsed=", resp.elapsed)
print("Results=", resp.text)
# Out:
# Status code= 200
# Elapsed= 0:00:00.442817
# Results= {"filename": "/tmp/tmpzkjklj0v", "probs": [7.197500235633925e-05, 0.0004232039791531861, 0.0024810556787997484, 3.577833194867708e-05, 0.0003292012552265078, 0.00041973585030063987, 0.9576422572135925, 0.00015783355047460645, 0.038207825273275375, 0.00023116721422411501], "labels": ["C0 Safe driving", "C1 Texting right", "C2 Talking on the phone right", "C3 Texting left", "C4 Talking on the phone left", "C5 Operating the radio", "C6 Drinking", "C7 Reaching behind", "C8 Hair and makeup", "C9 Talking to passengers"]}

# %%
prediction=pd.DataFrame(resp.json()) #Convert the Json into a pandas dataframe
prediction.sort_values(by='probs', ascending=False)
# Out:
#            filename     probs                         labels
# 6  /tmp/tmpzkjklj0v  0.957642                    C6 Drinking
# 8  /tmp/tmpzkjklj0v  0.038208             C8 Hair and makeup
# 2  /tmp/tmpzkjklj0v  0.002481  C2 Talking on the phone right
# 1  /tmp/tmpzkjklj0v  0.000423               C1 Texting right
# 5  /tmp/tmpzkjklj0v  0.000420         C5 Operating the radio
# 4  /tmp/tmpzkjklj0v  0.000329   C4 Talking on the phone left
# 9  /tmp/tmpzkjklj0v  0.000231       C9 Talking to passengers
# 7  /tmp/tmpzkjklj0v  0.000158             C7 Reaching behind
# 0  /tmp/tmpzkjklj0v  0.000072                C0 Safe driving
# 3  /tmp/tmpzkjklj0v  0.000036                C3 Texting left

# %%
prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs'])
label = prediction['labels'][label_index]
conf_score = prediction['probs'][label_index]

print("Image file =", image_file)
print("Model prediction =", label, "\nwith Probability =", conf_score)
print("\nThe image is someone who is", label,"with a probability of", round((conf_score*100), 2), "%")
# Out:
# Image file = test3.jpg
# Model prediction = C6 Drinking
# with Probability = 0.9576422572135925
#
# The image is someone who is C6 Drinking with a probability of 95.76 %

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import numpy as np
import json

IMAGE_SIZE = (18,12)
plt.figure(figsize=IMAGE_SIZE)
img_np=mpimg.imread(image_file)
img = Image.fromarray(img_np.astype('uint8'),'RGB')
x, y = img.size

fig,ax = plt.subplots(1, figsize=(15,15))
# Display the image
ax.imshow(img_np)

prediction = json.loads(resp.text)
label_index = np.argmax(prediction['probs'])
label = prediction['labels'][label_index]
conf_score = prediction['probs'][label_index]

display_text = '{} ({})'.format(label, round(conf_score, 4))
print(display_text)

color = 'red' #Text Color
plt.text(30, 30, display_text, color=color, fontsize=30)

fig.savefig('predictiontest3.jpg', dpi=150) #Saving image

plt.show()
# Out:
# C6 Drinking (0.9576)

# %% [markdown]
# ## 11. Clean up ressources

# %%
# Let's delete the service
#aks_service.delete()

# %%
# Let's delete our Azure ML GPU compute cluster
#compute_target.delete()

# %% [markdown]
# > End of notebook
