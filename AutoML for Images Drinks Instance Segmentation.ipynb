# %% [markdown]
# # Training an Instance Segmentation model using AutoML
# In this notebook, we go over how you can use AutoML for training an Instance Segmentation model. We will use a small dataset to train the model, demonstrate how you can tune hyperparameters of the model to optimize model performance and deploy the model to use in inference scenarios.

# %%
#!pip install --upgrade "azureml-train-core<0.1.1" "azureml-train-automl<0.1.1" "azureml-contrib-dataset<0.1.1" --extra-index-url "https://azuremlsdktestpypi.azureedge.net/automl_for_images_private_preview/"

# %% [markdown]
# ## Workspace setup
# In order to train and deploy models in Azure ML, you will first need to set up a workspace.
#
# An [Azure ML Workspace](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#workspace) is an Azure resource that organizes and coordinates the actions of many other Azure resources to assist in executing and sharing machine learning workflows. In particular, an Azure ML Workspace coordinates storage, databases, and compute resources providing added functionality for machine learning experimentation, deployment, inference, and the monitoring of deployed models.
#
# Create an Azure ML Workspace within your Azure subscription, or load an existing workspace.

# %%
## specify workspace parameters
subscription_id='TobeReplaced'   
resource_group='automlvision-rg'   
workspace_name='automlvision'

from azureml.core.workspace import Workspace
ws = Workspace.create(name = workspace_name,
                      subscription_id = subscription_id,
                      resource_group = resource_group, 
                      exist_ok = True)

# %% [markdown]
# ## Compute target setup
# You will need to provide a [Compute Target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) that will be used for your AutoML model training. AutoML models for image tasks require GPU SKUs and support NC and ND families. We recommend using the NCsv3-series (with v100 GPUs) for faster training. Using a compute target with a multi-GPU VM SKU will leverage the multiple GPUs to speed up training. Additionally, setting up a compute target with multiple nodes will allow for faster model training by leveraging parallelism, when tuning hyperparameters for your model.

# %%
from azureml.core.compute import AmlCompute, ComputeTarget

cluster_name = "gpu-drinks"

try:
    compute_target = ws.compute_targets[cluster_name]
    print('Found existing compute target.')
except KeyError:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_NC6', 
                                                           idle_seconds_before_scaledown=1800,
                                                           min_nodes=0, 
                                                           max_nodes=4)

    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)
    
# Can poll for a minimum number of nodes and for a specific timeout.
# If no min_node_count is provided, it will use the scale settings for the cluster.
compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
# Out:
# Creating a new compute target...
# Creating.........
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Experiment Setup
# Create an [Experiment](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#experiment) in your workspace to track your model training runs

# %%
from azureml.core import Experiment

experiment_name = 'Automl-Drinks-instance-segmentation' 
experiment = Experiment(ws, name=experiment_name)

# %% [markdown]
# ## Dataset with input Training Data
# In order to generate models for computer vision, you will need to bring in labeled image data as input for model training in the form of an AzureML Labeled Dataset. You can either use a Labeled Dataset that you have exported from a Data Labeling project, or create a new Labeled Dataset with your labeled training data

# %% [markdown]
# In this notebook, we use a toy dataset called Fridge Objects, which includes 128 images of 4 classes of beverage container {can, carton, milk bottle, water bottle} photos taken on different backgrounds. We first download and unzip the data locally.

# %%
import os
import urllib
from zipfile import ZipFile

# download data
download_url = 'https://cvbp-secondary.z19.web.core.windows.net/datasets/object_detection/odFridgeObjectsMask.zip'
data_file = './odFridgeObjectsMask.zip'
urllib.request.urlretrieve(download_url, filename=data_file)

# extract files
with ZipFile(data_file, 'r') as zip:
    print('extracting files...')
    zip.extractall()
    print('done')
    
# delete zip file
os.remove(data_file)
# Out:
# extracting files...
# done

# %% [markdown]
# This is a sample image from this dataset:

# %%
from IPython.display import Image
Image(filename='./odFridgeObjectsMask/images/31.jpg')

# %% [markdown]
# ### Convert the downloaded data to JSONL
# In this example, the fridge object dataset is annotated in Pascal VOC format, where each image corresponds to an xml file. Each xml file contains information on where its corresponding image file is located and also contains information about the bounding boxes and the object labels. In order to use this data to create an AzureML Datset, we first need to convert it to the required JSONL format.
#
# The following script is creating two .jsonl files (one for training and one for validation) in the parent folder of the dataset. The train / validation ratio corresponds to 20% of the data going into the validation file.

# %%
#import sys
#!{sys.executable} -m pip install numpy==1.18.5 pillow==8.0.1 scikit-image==0.17.2 simplification==0.5.7

# %%
from jsonl_converter import convert_mask_in_VOC_to_jsonl

data_path = "./odFridgeObjectsMask/"
convert_mask_in_VOC_to_jsonl(data_path, ws)
# Out:
# Parsing ./odFridgeObjectsMask/1.xml
# Parsing ./odFridgeObjectsMask/10.xml
# Parsing ./odFridgeObjectsMask/100.xml
# Parsing ./odFridgeObjectsMask/101.xml
# Parsing ./odFridgeObjectsMask/102.xml
# Parsing ./odFridgeObjectsMask/103.xml
# Parsing ./odFridgeObjectsMask/104.xml
# Parsing ./odFridgeObjectsMask/105.xml
# Parsing ./odFridgeObjectsMask/106.xml
# Parsing ./odFridgeObjectsMask/107.xml
# Parsing ./odFridgeObjectsMask/108.xml
# Parsing ./odFridgeObjectsMask/109.xml
# Parsing ./odFridgeObjectsMask/11.xml
# Parsing ./odFridgeObjectsMask/110.xml
# Parsing ./odFridgeObjectsMask/111.xml
# Parsing ./odFridgeObjectsMask/112.xml
# Parsing ./odFridgeObjectsMask/113.xml
# Parsing ./odFridgeObjectsMask/114.xml
# Parsing ./odFridgeObjectsMask/115.xml
# Parsing ./odFridgeObjectsMask/116.xml
# Parsing ./odFridgeObjectsMask/117.xml
# Parsing ./odFridgeObjectsMask/118.xml
# Parsing ./odFridgeObjectsMask/119.xml
# Parsing ./odFridgeObjectsMask/12.xml
# Parsing ./odFridgeObjectsMask/120.xml
# Parsing ./odFridgeObjectsMask/121.xml
# Parsing ./odFridgeObjectsMask/122.xml
# Parsing ./odFridgeObjectsMask/123.xml
# Parsing ./odFridgeObjectsMask/124.xml
# Parsing ./odFridgeObjectsMask/125.xml
# Parsing ./odFridgeObjectsMask/126.xml
# Parsing ./odFridgeObjectsMask/127.xml
# Parsing ./odFridgeObjectsMask/128.xml
# Parsing ./odFridgeObjectsMask/13.xml
# Parsing ./odFridgeObjectsMask/14.xml
# Parsing ./odFridgeObjectsMask/15.xml
# Parsing ./odFridgeObjectsMask/16.xml
# Parsing ./odFridgeObjectsMask/17.xml
# Parsing ./odFridgeObjectsMask/18.xml
# Parsing ./odFridgeObjectsMask/19.xml
# Parsing ./odFridgeObjectsMask/2.xml
# Parsing ./odFridgeObjectsMask/20.xml
# Parsing ./odFridgeObjectsMask/21.xml
# Parsing ./odFridgeObjectsMask/22.xml
# Parsing ./odFridgeObjectsMask/23.xml
# Parsing ./odFridgeObjectsMask/24.xml
# Parsing ./odFridgeObjectsMask/25.xml
# Parsing ./odFridgeObjectsMask/26.xml
# Parsing ./odFridgeObjectsMask/27.xml
# Parsing ./odFridgeObjectsMask/28.xml
# Parsing ./odFridgeObjectsMask/29.xml
# Parsing ./odFridgeObjectsMask/3.xml
# Parsing ./odFridgeObjectsMask/30.xml
# Parsing ./odFridgeObjectsMask/31.xml
# Parsing ./odFridgeObjectsMask/32.xml
# Parsing ./odFridgeObjectsMask/33.xml
# Parsing ./odFridgeObjectsMask/34.xml
# Parsing ./odFridgeObjectsMask/35.xml
# Parsing ./odFridgeObjectsMask/36.xml
# Parsing ./odFridgeObjectsMask/37.xml
# Parsing ./odFridgeObjectsMask/38.xml
# Parsing ./odFridgeObjectsMask/39.xml
# Parsing ./odFridgeObjectsMask/4.xml
# Parsing ./odFridgeObjectsMask/40.xml
# Parsing ./odFridgeObjectsMask/41.xml
# Parsing ./odFridgeObjectsMask/42.xml
# Parsing ./odFridgeObjectsMask/43.xml
# Parsing ./odFridgeObjectsMask/44.xml
# Parsing ./odFridgeObjectsMask/45.xml
# Parsing ./odFridgeObjectsMask/46.xml
# Parsing ./odFridgeObjectsMask/47.xml
# Parsing ./odFridgeObjectsMask/48.xml
# Parsing ./odFridgeObjectsMask/49.xml
# Parsing ./odFridgeObjectsMask/5.xml
# Parsing ./odFridgeObjectsMask/50.xml
# Parsing ./odFridgeObjectsMask/51.xml
# Parsing ./odFridgeObjectsMask/52.xml
# Parsing ./odFridgeObjectsMask/53.xml
# Parsing ./odFridgeObjectsMask/54.xml
# Parsing ./odFridgeObjectsMask/55.xml
# Parsing ./odFridgeObjectsMask/56.xml
# Parsing ./odFridgeObjectsMask/57.xml
# Parsing ./odFridgeObjectsMask/58.xml
# Parsing ./odFridgeObjectsMask/59.xml
# Parsing ./odFridgeObjectsMask/6.xml
# Parsing ./odFridgeObjectsMask/60.xml
# Parsing ./odFridgeObjectsMask/61.xml
# Parsing ./odFridgeObjectsMask/62.xml
# Parsing ./odFridgeObjectsMask/63.xml
# Parsing ./odFridgeObjectsMask/64.xml
# Parsing ./odFridgeObjectsMask/65.xml
# Parsing ./odFridgeObjectsMask/66.xml
# Parsing ./odFridgeObjectsMask/67.xml
# Parsing ./odFridgeObjectsMask/68.xml
# Parsing ./odFridgeObjectsMask/69.xml
# Parsing ./odFridgeObjectsMask/7.xml
# Parsing ./odFridgeObjectsMask/70.xml
# Parsing ./odFridgeObjectsMask/71.xml
# Parsing ./odFridgeObjectsMask/72.xml
# Parsing ./odFridgeObjectsMask/73.xml
# Parsing ./odFridgeObjectsMask/74.xml
# Parsing ./odFridgeObjectsMask/75.xml
# Parsing ./odFridgeObjectsMask/76.xml
# Parsing ./odFridgeObjectsMask/77.xml
# Parsing ./odFridgeObjectsMask/78.xml
# Parsing ./odFridgeObjectsMask/79.xml
# Parsing ./odFridgeObjectsMask/8.xml
# Parsing ./odFridgeObjectsMask/80.xml
# Parsing ./odFridgeObjectsMask/81.xml
# Parsing ./odFridgeObjectsMask/82.xml
# Parsing ./odFridgeObjectsMask/83.xml
# Parsing ./odFridgeObjectsMask/84.xml
# Parsing ./odFridgeObjectsMask/85.xml
# Parsing ./odFridgeObjectsMask/86.xml
# Parsing ./odFridgeObjectsMask/87.xml
# Parsing ./odFridgeObjectsMask/88.xml
# Parsing ./odFridgeObjectsMask/89.xml
# Parsing ./odFridgeObjectsMask/9.xml
# Parsing ./odFridgeObjectsMask/90.xml
# Parsing ./odFridgeObjectsMask/91.xml
# Parsing ./odFridgeObjectsMask/92.xml
# Parsing ./odFridgeObjectsMask/93.xml
# Parsing ./odFridgeObjectsMask/94.xml
# Parsing ./odFridgeObjectsMask/95.xml
# Parsing ./odFridgeObjectsMask/96.xml
# Parsing ./odFridgeObjectsMask/97.xml
# Parsing ./odFridgeObjectsMask/98.xml
# Parsing ./odFridgeObjectsMask/99.xml

# %% [markdown]
# ### Upload the JSONL file and images to Datastore
# In order to use the data for training in Azure ML, we upload it to our Azure ML Workspace via a [Datastore](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores). The datastore provides a mechanism for you to upload/download data, and interact with it from your remote compute targets. It is an abstraction over Azure Storage.

# %%
# Retrieving default datastore that got automatically created when we setup a workspace
ds = ws.get_default_datastore()
ds.upload(src_dir='./odFridgeObjectsMask', target_path='odFridgeObjectsMask')
# Out:
# Uploading an estimated of 386 files
# Target already exists. Skipping upload for odFridgeObjectsMask/train_annotations.jsonl
# Target already exists. Skipping upload for odFridgeObjectsMask/validation_annotations.jsonl
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/1.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/10.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/100.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/101.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/102.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/103.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/104.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/105.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/106.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/107.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/108.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/109.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/11.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/110.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/111.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/112.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/113.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/114.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/115.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/116.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/117.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/118.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/119.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/12.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/120.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/121.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/122.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/123.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/124.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/125.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/126.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/127.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/128.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/13.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/14.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/15.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/16.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/17.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/18.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/19.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/2.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/20.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/21.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/22.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/23.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/24.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/25.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/26.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/27.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/28.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/29.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/3.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/30.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/31.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/32.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/33.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/34.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/35.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/36.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/37.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/38.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/39.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/4.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/40.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/41.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/42.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/43.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/44.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/45.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/46.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/47.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/48.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/49.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/5.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/50.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/51.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/52.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/53.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/54.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/55.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/56.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/57.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/58.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/59.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/6.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/60.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/61.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/62.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/63.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/64.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/65.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/66.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/67.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/68.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/69.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/7.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/70.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/71.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/72.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/73.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/74.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/75.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/76.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/77.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/78.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/79.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/8.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/80.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/81.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/82.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/83.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/84.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/85.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/86.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/87.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/88.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/89.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/9.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/90.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/91.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/92.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/93.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/94.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/95.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/96.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/97.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/98.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/annotations/99.xml
# Target already exists. Skipping upload for odFridgeObjectsMask/images/1.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/10.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/100.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/101.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/102.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/103.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/104.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/105.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/106.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/107.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/108.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/109.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/11.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/110.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/111.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/112.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/113.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/114.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/115.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/116.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/117.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/118.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/119.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/12.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/120.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/121.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/122.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/123.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/124.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/125.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/126.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/127.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/128.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/13.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/14.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/15.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/16.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/17.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/18.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/19.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/2.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/20.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/21.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/22.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/23.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/24.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/25.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/26.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/27.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/28.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/29.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/3.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/30.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/31.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/32.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/33.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/34.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/35.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/36.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/37.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/38.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/39.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/4.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/40.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/41.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/42.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/43.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/44.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/45.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/46.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/47.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/48.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/49.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/5.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/50.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/51.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/52.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/53.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/54.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/55.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/56.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/57.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/58.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/59.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/6.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/60.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/61.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/62.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/63.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/64.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/65.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/66.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/67.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/68.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/69.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/7.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/70.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/71.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/72.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/73.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/74.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/75.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/76.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/77.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/78.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/79.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/8.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/80.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/81.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/82.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/83.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/84.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/85.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/86.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/87.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/88.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/89.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/9.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/90.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/91.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/92.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/93.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/94.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/95.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/96.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/97.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/98.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/images/99.jpg
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/1.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/10.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/100.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/101.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/102.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/103.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/104.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/105.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/106.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/107.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/108.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/109.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/11.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/110.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/111.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/112.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/113.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/114.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/115.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/116.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/117.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/118.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/119.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/12.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/120.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/121.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/122.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/123.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/124.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/125.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/126.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/127.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/128.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/13.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/14.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/15.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/16.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/17.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/18.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/19.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/2.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/20.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/21.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/22.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/23.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/24.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/25.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/26.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/27.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/28.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/29.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/3.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/30.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/31.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/32.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/33.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/34.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/35.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/36.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/37.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/38.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/39.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/4.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/40.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/41.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/42.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/43.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/44.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/45.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/46.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/47.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/48.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/49.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/5.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/50.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/51.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/52.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/53.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/54.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/55.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/56.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/57.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/58.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/59.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/6.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/60.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/61.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/62.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/63.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/64.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/65.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/66.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/67.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/68.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/69.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/7.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/70.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/71.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/72.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/73.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/74.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/75.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/76.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/77.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/78.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/79.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/8.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/80.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/81.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/82.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/83.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/84.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/85.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/86.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/87.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/88.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/89.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/9.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/90.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/91.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/92.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/93.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/94.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/95.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/96.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/97.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/98.png
# Target already exists. Skipping upload for odFridgeObjectsMask/segmentation-masks/99.png
# Uploaded 0 files
# $AZUREML_DATAREFERENCE_7d2690978ee84a7cbf23aaee4275a5d9

# %% [markdown]
# Finally, we need to create an Azure ML [Dataset](https://docs.microsoft.com/en-us/azure/machine-learning/concept-azure-machine-learning-architecture#datasets-and-datastores) from the data we uploaded to the Datastore. We create one dataset for training and one for validation.

# %%
from azureml.contrib.dataset.labeled_dataset import _LabeledDatasetFactory, LabeledDatasetTask
from azureml.core import Dataset

training_dataset_name = 'odFridgeObjectsMaskTrainingDataset'
if training_dataset_name in ws.datasets:
    training_dataset = ws.datasets.get(training_dataset_name)
    print('Found the training dataset', training_dataset_name)
else:
    # create training dataset
    training_dataset = _LabeledDatasetFactory.from_json_lines(
        task=LabeledDatasetTask.IMAGE_INSTANCE_SEGMENTATION, path=ds.path('odFridgeObjectsMask/train_annotations.jsonl'))
    training_dataset = training_dataset.register(workspace=ws, name=training_dataset_name)
    
# create validation dataset
validation_dataset_name = "odFridgeObjectsMaskValidationDataset"
if validation_dataset_name in ws.datasets:
    validation_dataset = ws.datasets.get(validation_dataset_name)
    print('Found the validation dataset', validation_dataset_name)
else:
    validation_dataset = _LabeledDatasetFactory.from_json_lines(
        task=LabeledDatasetTask.IMAGE_INSTANCE_SEGMENTATION, path=ds.path('odFridgeObjectsMask/validation_annotations.jsonl'))
    validation_dataset = validation_dataset.register(workspace=ws, name=validation_dataset_name)
    
    
print("Training dataset name: " + training_dataset.name)
print("Validation dataset name: " + validation_dataset.name)
# Out:
# Found the training dataset odFridgeObjectsMaskTrainingDataset
# Found the validation dataset odFridgeObjectsMaskValidationDataset
# Training dataset name: odFridgeObjectsMaskTrainingDataset
# Validation dataset name: odFridgeObjectsMaskValidationDataset

# %% [markdown]
# Validation dataset is optional. If no validation dataset is specified, by default 20% of your training data will be used for validation. You can control the percentage using the `split_ratio` argument - please refer to the documentation for more details.
#
# This is what the training dataset looks like

# %%
training_dataset.to_pandas_dataframe()
# Out:
#                                              image_url  \
# 0    StreamInfo(AmlDatastore://odFridgeObjectsMask/...
# 1    StreamInfo(AmlDatastore://odFridgeObjectsMask/...
# 2    StreamInfo(AmlDatastore://odFridgeObjectsMask/...
# 3    StreamInfo(AmlDatastore://odFridgeObjectsMask/...
# 4    StreamInfo(AmlDatastore://odFridgeObjectsMask/...
# ..                                                 ...
# 97   StreamInfo(AmlDatastore://odFridgeObjectsMask/...
# 98   StreamInfo(AmlDatastore://odFridgeObjectsMask/...
# 99   StreamInfo(AmlDatastore://odFridgeObjectsMask/...
# 100  StreamInfo(AmlDatastore://odFridgeObjectsMask/...
# 101  StreamInfo(AmlDatastore://odFridgeObjectsMask/...
#
#                                       image_details  \
# 0    {'format': 'jpg', 'width': 499, 'height': 666}
# 1    {'format': 'jpg', 'width': 499, 'height': 666}
# 2    {'format': 'jpg', 'width': 499, 'height': 666}
# 3    {'format': 'jpg', 'width': 499, 'height': 666}
# 4    {'format': 'jpg', 'width': 499, 'height': 666}
# ..                                              ...
# 97   {'format': 'jpg', 'width': 499, 'height': 666}
# 98   {'format': 'jpg', 'width': 499, 'height': 666}
# 99   {'format': 'jpg', 'width': 499, 'height': 666}
# 100  {'format': 'jpg', 'width': 499, 'height': 666}
# 101  {'format': 'jpg', 'width': 499, 'height': 666}
#
#                                                  label
# 0    [{'label': 'carton', 'bbox': 'null', 'isCrowd'...
# 1    [{'label': 'can', 'bbox': 'null', 'isCrowd': 0...
# 2    [{'label': 'water_bottle', 'bbox': 'null', 'is...
# 3    [{'label': 'water_bottle', 'bbox': 'null', 'is...
# 4    [{'label': 'can', 'bbox': 'null', 'isCrowd': 0...
# ..                                                 ...
# 97   [{'label': 'carton', 'bbox': 'null', 'isCrowd'...
# 98   [{'label': 'carton', 'bbox': 'null', 'isCrowd'...
# 99   [{'label': 'carton', 'bbox': 'null', 'isCrowd'...
# 100  [{'label': 'carton', 'bbox': 'null', 'isCrowd'...
# 101  [{'label': 'can', 'bbox': 'null', 'isCrowd': 0...
#
# [102 rows x 3 columns]

# %%
training_dataset.to_pandas_dataframe().shape
# Out:
# (102, 3)

# %% [markdown]
# ## Configuring your AutoML run for image tasks
# AutoML allows you to easily train models for Image Classification, Object Detection & Instance Segmentation on your image data. You can control the model algorithm to be used, specify hyperparameter values for your model as well as perform a sweep across the hyperparameter space to generate an optimal model. Parameters for configuring your AutoML runs for image related tasks are specified using the 'AutoMLImageConfig' - please refer to the [documentation](https://github.com/swatig007/automlForImages/blob/main/README.md) for the details on the parameters that can be used and their values.

# %% [markdown]
# When using AutoML for image tasks, you need to specify the model algorithms using the `model_name` parameter. You can either specify the specifc model algorithm/hyperparameter config to use or choose to sweep over the hyperparameter space. Currently supported algorithms for Instance segmentation include 'maskrcnn_resnet50_fpn'.

# %% [markdown]
# ### Using default hyperparameter values for the specified algorithm
# Before doing a large sweep to search for the optimal models and hyperparameters, we recommend trying the default values to get a first baseline. Next, you can explore multiple hyperparameters for the same model before sweeping over multiple models and their parameters. This is for employing a more iterative approach, because with multiple models and multiple hyperparameters for each (as we showcase in the next section), the search space grows exponentially and you need more iterations to find optimal configurations.
#
# If you wish to use the default hyperparameter values for a given algorithm (say maskrcnn), you can specify the config for your AutoML Image runs as follows:

# %%
from azureml.train.automl import AutoMLImageConfig
from azureml.train.hyperdrive import GridParameterSampling, choice

image_config_maskrcnn = AutoMLImageConfig(
      task='image-instance-segmentation',
      compute_target=compute_target,
      training_data=training_dataset,
      validation_data=validation_dataset,
      hyperparameter_sampling=GridParameterSampling({'model_name': choice('maskrcnn_resnet50_fpn')}))

# %% [markdown]
# ### Submitting an AutoML run for Computer Vision tasks
# Once you've created the config settings for your run, you can submit an AutoML run using the config in order to train a vision model using your training dataset.

# %%
automl_image_run = experiment.submit(image_config_maskrcnn)
# Out:
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>Automl-Drinks-instance-segmentation</td><td>AutoML_8e20412f-1412-4f44-872f-862caa8e6233</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_8e20412f-1412-4f44-872f-862caa8e6233?wsid=/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/automlvision-rg/workspaces/automlvision&amp;tid=72f988bf-86f1-41af-91ab-2d7cd011db47" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %%
automl_image_run.wait_for_completion(wait_post_processing=True)
# Out:
# {'runId': 'AutoML_8e20412f-1412-4f44-872f-862caa8e6233',
#  'target': 'gpu-drinks',
#  'status': 'Completed',
#  'startTimeUtc': '2021-05-18T07:28:46.211622Z',
#  'endTimeUtc': '2021-05-18T07:48:06.133313Z',
#  'properties': {'num_iterations': '1',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'mean_average_precision',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': None,
#   'target': 'gpu-drinks',
#   'AMLSettingsJsonString': '{"path":null,"name":"Automl-Drinks-instance-segmentation","subscription_id":"70b8f39e-8863-49f7-b6ba-34a80799550c","resource_group":"automlvision-rg","workspace_name":"automlvision","region":"westeurope","compute_target":"gpu-drinks","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":false,"enable_run_restructure":false,"start_auxiliary_runs_before_parent_complete":false,"enable_code_generation":false,"iterations":1,"primary_metric":"mean_average_precision","task_type":"image-instance-segmentation","data_script":null,"test_size":0.0,"validation_size":0.0,"n_cross_validations":null,"y_min":null,"y_max":null,"num_classes":null,"featurization":"off","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":1,"max_concurrent_iterations":1,"iteration_timeout_minutes":null,"mem_in_mb":null,"enforce_time_on_windows":false,"experiment_timeout_minutes":8640,"experiment_exit_score":null,"whitelist_models":null,"blacklist_algos":["TensorFlowDNN","TensorFlowLinearRegressor"],"supported_models":[],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":false,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"STANDARD_NC6","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":true,"scenario":"Vision","environment_label":null,"save_mlflow":false,"force_text_dnn":false,"enable_feature_sweeping":true,"enable_early_stopping":false,"early_stopping_n_iters":10,"arguments":null,"dataset_id":"bea6c486-272a-4c5a-b30e-a9d8b3bda38d","hyperdrive_config":{"max_total_jobs":1,"max_concurrent_jobs":1,"generator_config":{"name":"GRID","parameter_space":"{\\"model_name\\": [\\"choice\\", [[\\"maskrcnn_resnet50_fpn\\"]]]}","properties":null},"policy_config":null},"validation_dataset_id":"3b87e300-f146-4a02-a4ba-2abe883ed64a","run_source":"AutoMLImageSDK","metrics":null,"enable_metric_confidence":false,"enable_ensembling":false,"enable_stack_ensembling":false,"ensemble_iterations":null,"enable_tf":false,"enable_subsampling":false,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"allowed_private_models":[],"label_column_name":"label","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":false}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"bea6c486-272a-4c5a-b30e-a9d8b3bda38d\\"}, \\"validation_data\\": {\\"datasetId\\": \\"3b87e300-f146-4a02-a4ba-2abe883ed64a\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': 'False',
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'automl',
#   'display_task_type': 'image-instance-segmentation',
#   'dependencies_versions': '{"azureml-widgets": "1.27.0", "azureml-train": "1.27.0", "azureml-train-restclients-hyperdrive": "0.1.0.36994775", "azureml-train-core": "0.1.0.36994775", "azureml-train-automl": "0.1.0.36994775", "azureml-train-automl-runtime": "0.1.0.36994775", "azureml-train-automl-client": "0.1.0.36994775", "azureml-tensorboard": "1.27.0", "azureml-telemetry": "0.1.0.36994775", "azureml-sdk": "1.27.0", "azureml-samples": "0+unknown", "azureml-pipeline": "1.27.0", "azureml-pipeline-steps": "1.27.0", "azureml-pipeline-core": "1.27.0", "azureml-opendatasets": "1.27.0", "azureml-model-management-sdk": "1.0.1b6.post1", "azureml-mlflow": "1.27.0", "azureml-interpret": "0.1.0.36994775", "azureml-explain-model": "1.27.0", "azureml-defaults": "0.1.0.36994775", "azureml-dataset-runtime": "0.1.0.36994775", "azureml-dataprep": "2.15.0", "azureml-dataprep-rslex": "1.13.0", "azureml-dataprep-native": "33.0.0", "azureml-datadrift": "1.27.0", "azureml-core": "0.1.0.36994775", "azureml-contrib-services": "1.27.0", "azureml-contrib-server": "1.27.0", "azureml-contrib-reinforcementlearning": "1.27.0", "azureml-contrib-pipeline-steps": "1.27.0", "azureml-contrib-notebook": "1.27.0", "azureml-contrib-gbdt": "1.27.0", "azureml-contrib-fairness": "1.27.0", "azureml-contrib-dataset": "0.1.0.36994775", "azureml-cli-common": "1.27.0", "azureml-automl-runtime": "0.1.0.36994775", "azureml-automl-dnn-nlp": "1.27.0", "azureml-automl-core": "0.1.0.36994775", "azureml-accel-models": "1.27.0"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'environment_cpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_cpu_label': 'Latest',
#   'environment_gpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_gpu_label': 'Latest',
#   'root_attribution': 'automl',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://westeurope.api.azureml.ms/jasmine/v1.0/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourceGroups/automlvision-rg/providers/Microsoft.MachineLearningServices/workspaces/automlvision/experimentids/1bca2687-2761-47d7-82aa-490e99f37e82/cancel/AutoML_8e20412f-1412-4f44-872f-862caa8e6233',
#   'ClientSdkVersion': '1.28.0',
#   'snapshotId': '00000000-0000-0000-0000-000000000000'},
#  'inputDatasets': [{'dataset': {'id': 'bea6c486-272a-4c5a-b30e-a9d8b3bda38d'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}, {'dataset': {'id': '3b87e300-f146-4a02-a4ba-2abe883ed64a'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'validation_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Serge Retkowsky'}

# %% [markdown]
# ### Hyperparameter sweeping for your AutoML models for computer vision tasks
# In this example, we use the AutoMLImageConfig to train an Instance Segmentation model using maskrcnn_resnet50_fpn which is pretrained on COCO, a large-scale object detection, segmentation, and captioning dataset that contains over 200K labeled images with over 80 label cateogories.
#
# When using AutoML for computer vision, you can perform a hyperparameter sweep over a defined parameter space, to find the optimal model. In this example, we sweep over the hyperparameters for each algorithm, choosing from a range of values for learning_rate, optimizer, etc, to generate a model with the optimal 'accuracy'. If hyperparameter values are not specified, then default values are used for the specified algorithm.
#
# We use Random Sampling to pick samples from this parameter space and try a total of 20 iterations with these different samples, running 4 iterations at a time on our compute target, which has been previously set up using 4 nodes.  Please note that the more parameters the space has, the more iterations you need to find optimal models.
#
# We also leverage the Bandit early termination policy that terminates poor performing configs (those that are not within 20% slack of the best perfroming config), thus significantly saving compute resources.

# %%
from azureml.train.automl import AutoMLImageConfig
from azureml.train.hyperdrive import GridParameterSampling, RandomParameterSampling, BayesianParameterSampling
from azureml.train.hyperdrive import BanditPolicy, HyperDriveConfig, PrimaryMetricGoal
from azureml.train.hyperdrive import choice, uniform

parameter_space = {
    'model_name': choice('maskrcnn_resnet50_fpn'),
    'learning_rate': uniform(0.0001, 0.001),
    #'warmup_cosine_lr_warmup_epochs': choice(0, 3),
    'optimizer': choice('sgd', 'adam', 'adamw'),
    'min_size': choice(600, 800)
}

tuning_settings = {
    'iterations': 10, 
    'max_concurrent_iterations': 4, 
    'hyperparameter_sampling': RandomParameterSampling(parameter_space),  
    'policy': BanditPolicy(evaluation_interval=2, slack_factor=0.2, delay_evaluation=6)
}


automl_image_config = AutoMLImageConfig(task='image-instance-segmentation',
                                        compute_target=compute_target,
                                        training_data=training_dataset,
                                        validation_data=validation_dataset,
                                        primary_metric='mean_average_precision',
                                        **tuning_settings)

# %%
automl_image_run = experiment.submit(automl_image_config)
# Out:
# Submitting remote run.
# <table style="width:100%"><tr><th>Experiment</th><th>Id</th><th>Type</th><th>Status</th><th>Details Page</th><th>Docs Page</th></tr><tr><td>Automl-Drinks-instance-segmentation</td><td>AutoML_36efaa15-e5dd-4249-9711-74ef02233aaa</td><td>automl</td><td>NotStarted</td><td><a href="https://ml.azure.com/runs/AutoML_36efaa15-e5dd-4249-9711-74ef02233aaa?wsid=/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourcegroups/automlvision-rg/workspaces/automlvision&amp;tid=72f988bf-86f1-41af-91ab-2d7cd011db47" target="_blank" rel="noopener">Link to Azure Machine Learning studio</a></td><td><a href="https://docs.microsoft.com/en-us/python/api/overview/azure/ml/intro?view=azure-ml-py" target="_blank" rel="noopener">Link to Documentation</a></td></tr></table>

# %%
automl_image_run.wait_for_completion(wait_post_processing=True)
# Out:
# {'runId': 'AutoML_36efaa15-e5dd-4249-9711-74ef02233aaa',
#  'target': 'gpu-drinks',
#  'status': 'Completed',
#  'startTimeUtc': '2021-05-18T07:53:40.439691Z',
#  'endTimeUtc': '2021-05-18T08:58:44.801798Z',
#  'properties': {'num_iterations': '1',
#   'training_type': 'TrainFull',
#   'acquisition_function': 'EI',
#   'primary_metric': 'mean_average_precision',
#   'train_split': '0',
#   'acquisition_parameter': '0',
#   'num_cross_validation': None,
#   'target': 'gpu-drinks',
#   'AMLSettingsJsonString': '{"path":null,"name":"Automl-Drinks-instance-segmentation","subscription_id":"70b8f39e-8863-49f7-b6ba-34a80799550c","resource_group":"automlvision-rg","workspace_name":"automlvision","region":"westeurope","compute_target":"gpu-drinks","spark_service":null,"azure_service":"remote","many_models":false,"pipeline_fetch_max_batch_size":1,"enable_batch_run":false,"enable_run_restructure":false,"start_auxiliary_runs_before_parent_complete":false,"enable_code_generation":false,"iterations":1,"primary_metric":"mean_average_precision","task_type":"image-instance-segmentation","data_script":null,"test_size":0.0,"validation_size":0.0,"n_cross_validations":null,"y_min":null,"y_max":null,"num_classes":null,"featurization":"off","_ignore_package_version_incompatibilities":false,"is_timeseries":false,"max_cores_per_iteration":1,"max_concurrent_iterations":1,"iteration_timeout_minutes":null,"mem_in_mb":null,"enforce_time_on_windows":false,"experiment_timeout_minutes":8640,"experiment_exit_score":null,"whitelist_models":null,"blacklist_algos":["TensorFlowDNN","TensorFlowLinearRegressor"],"supported_models":[],"private_models":[],"auto_blacklist":true,"blacklist_samples_reached":false,"exclude_nan_labels":true,"verbosity":20,"_debug_log":"azureml_automl.log","show_warnings":false,"model_explainability":true,"service_url":null,"sdk_url":null,"sdk_packages":null,"enable_onnx_compatible_models":false,"enable_split_onnx_featurizer_estimator_models":false,"vm_type":"STANDARD_NC6","telemetry_verbosity":20,"send_telemetry":true,"enable_dnn":true,"scenario":"Vision","environment_label":null,"save_mlflow":false,"force_text_dnn":false,"enable_feature_sweeping":true,"enable_early_stopping":false,"early_stopping_n_iters":10,"arguments":null,"dataset_id":"bea6c486-272a-4c5a-b30e-a9d8b3bda38d","hyperdrive_config":{"max_total_jobs":10,"max_concurrent_jobs":4,"generator_config":{"name":"RANDOM","parameter_space":"{\\"model_name\\": [\\"choice\\", [[\\"maskrcnn_resnet50_fpn\\"]]], \\"learning_rate\\": [\\"uniform\\", [0.0001, 0.001]], \\"optimizer\\": [\\"choice\\", [[\\"sgd\\", \\"adam\\", \\"adamw\\"]]], \\"min_size\\": [\\"choice\\", [[600, 800]]]}","properties":null},"policy_config":{"name":"Bandit","properties":{"evaluation_interval":2,"delay_evaluation":6,"slack_factor":0.2}}},"validation_dataset_id":"3b87e300-f146-4a02-a4ba-2abe883ed64a","run_source":"AutoMLImageSDK","metrics":null,"enable_metric_confidence":false,"enable_ensembling":false,"enable_stack_ensembling":false,"ensemble_iterations":null,"enable_tf":false,"enable_subsampling":false,"subsample_seed":null,"enable_nimbusml":false,"enable_streaming":false,"force_streaming":false,"track_child_runs":true,"allowed_private_models":[],"label_column_name":"label","weight_column_name":null,"cv_split_column_names":null,"enable_local_managed":false,"_local_managed_run_id":null,"cost_mode":1,"lag_length":0,"metric_operation":"maximize","preprocess":false}',
#   'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"bea6c486-272a-4c5a-b30e-a9d8b3bda38d\\"}, \\"validation_data\\": {\\"datasetId\\": \\"3b87e300-f146-4a02-a4ba-2abe883ed64a\\"}, \\"datasets\\": 0}',
#   'EnableSubsampling': 'False',
#   'runTemplate': 'AutoML',
#   'azureml.runsource': 'automl',
#   'display_task_type': 'image-instance-segmentation',
#   'dependencies_versions': '{"azureml-widgets": "1.27.0", "azureml-train": "1.27.0", "azureml-train-restclients-hyperdrive": "0.1.0.36994775", "azureml-train-core": "0.1.0.36994775", "azureml-train-automl": "0.1.0.36994775", "azureml-train-automl-runtime": "0.1.0.36994775", "azureml-train-automl-client": "0.1.0.36994775", "azureml-tensorboard": "1.27.0", "azureml-telemetry": "0.1.0.36994775", "azureml-sdk": "1.27.0", "azureml-samples": "0+unknown", "azureml-pipeline": "1.27.0", "azureml-pipeline-steps": "1.27.0", "azureml-pipeline-core": "1.27.0", "azureml-opendatasets": "1.27.0", "azureml-model-management-sdk": "1.0.1b6.post1", "azureml-mlflow": "1.27.0", "azureml-interpret": "0.1.0.36994775", "azureml-explain-model": "1.27.0", "azureml-defaults": "0.1.0.36994775", "azureml-dataset-runtime": "0.1.0.36994775", "azureml-dataprep": "2.15.0", "azureml-dataprep-rslex": "1.13.0", "azureml-dataprep-native": "33.0.0", "azureml-datadrift": "1.27.0", "azureml-core": "0.1.0.36994775", "azureml-contrib-services": "1.27.0", "azureml-contrib-server": "1.27.0", "azureml-contrib-reinforcementlearning": "1.27.0", "azureml-contrib-pipeline-steps": "1.27.0", "azureml-contrib-notebook": "1.27.0", "azureml-contrib-gbdt": "1.27.0", "azureml-contrib-fairness": "1.27.0", "azureml-contrib-dataset": "0.1.0.36994775", "azureml-cli-common": "1.27.0", "azureml-automl-runtime": "0.1.0.36994775", "azureml-automl-dnn-nlp": "1.27.0", "azureml-automl-core": "0.1.0.36994775", "azureml-accel-models": "1.27.0"}',
#   '_aml_system_scenario_identification': 'Remote.Parent',
#   'ClientType': 'SDK',
#   'environment_cpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_cpu_label': 'Latest',
#   'environment_gpu_name': 'AzureML-AutoML-DNN-Vision-GPU',
#   'environment_gpu_label': 'Latest',
#   'root_attribution': 'automl',
#   'attribution': 'AutoML',
#   'Orchestrator': 'AutoML',
#   'CancelUri': 'https://westeurope.api.azureml.ms/jasmine/v1.0/subscriptions/70b8f39e-8863-49f7-b6ba-34a80799550c/resourceGroups/automlvision-rg/providers/Microsoft.MachineLearningServices/workspaces/automlvision/experimentids/1bca2687-2761-47d7-82aa-490e99f37e82/cancel/AutoML_36efaa15-e5dd-4249-9711-74ef02233aaa',
#   'ClientSdkVersion': '1.28.0',
#   'snapshotId': '00000000-0000-0000-0000-000000000000'},
#  'inputDatasets': [{'dataset': {'id': 'bea6c486-272a-4c5a-b30e-a9d8b3bda38d'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'training_data', 'mechanism': 'Direct'}}, {'dataset': {'id': '3b87e300-f146-4a02-a4ba-2abe883ed64a'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'validation_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'logFiles': {},
#  'submittedBy': 'Serge Retkowsky'}

# %% [markdown]
# ## Register the optimal vision model from the AutoML run
# Once the run completes, we can register the model that was created from the best run (configuration that resulted in the best primary metric)

# %%
# Register the model from the best run

best_child_run = automl_image_run.get_best_child()
model_name = best_child_run.properties['model_name']
model = best_child_run.register_model(model_name = model_name, model_path='outputs/model.pt')

# %% [markdown]
# ## Deploy model as a web service
# Once you have your trained model, you can deploy the model on Azure. You can deploy your trained model as a web service on Azure Container Instances ([ACI](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-container-instance)) or Azure Kubernetes Service ([AKS](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-azure-kubernetes-service)). ACI is the perfect option for testing deployments, while AKS is better suited for for high-scale, production usage.
# In this tutorial, we will deploy the model as a web service in AKS.

# %% [markdown]
# You will need to first create an AKS compute cluster, or use an existing AKS cluster. You can use either GPU or CPU VM SKUs for your deployment cluster

# %%
from azureml.core.compute import ComputeTarget, AksCompute
from azureml.exceptions import ComputeTargetException

# Choose a name for your cluster
aks_name = "cluster-aks-gpu"

# Check to see if the cluster already exists
try:
    aks_target = ComputeTarget(workspace=ws, name=aks_name)
    print('Found existing compute target')
except ComputeTargetException:
    print('Creating a new compute target...')
    # Provision AKS cluster with GPU machine
    prov_config = AksCompute.provisioning_configuration(vm_size="STANDARD_NC6", 
                                                        location="eastus2")
    # Create the cluster
    aks_target = ComputeTarget.create(workspace=ws, 
                                      name=aks_name, 
                                      provisioning_configuration=prov_config)
    aks_target.wait_for_completion(show_output=True)
# Out:
# Found existing compute target

# %% [markdown]
# Next, you will need to define the inference configuration, that describes how to set up the web-service containing your model. You can use the scoring script and the environment from the training run in your inference config.
# You can then deploy the model as an AKS web service.

# %%
#Deploy the model from the best run as an AKS web service
from azureml.core.model import InferenceConfig
from azureml.core.webservice import AksWebservice
from azureml.core.webservice import Webservice
from azureml.core.model import Model
from azureml.core.environment import Environment

best_child_run.download_file('outputs/scoring_file_v_1_0_0.py', output_file_path='score.py')
environment = best_child_run.get_environment()
inference_config = InferenceConfig(entry_script='score.py', environment=environment)

aks_config = AksWebservice.deploy_configuration(autoscale_enabled=True,                                                    
                                                    cpu_cores=1,
                                                    memory_gb=50,
                                                    enable_app_insights=True)

aks_service = Model.deploy(ws,
                           models=[model],
                           inference_config=inference_config,
                           deployment_config=aks_config,
                           deployment_target=aks_target,
                           name='automl-image-test',
                           overwrite=True)
aks_service.wait_for_deployment(show_output=True)
print(aks_service.state)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running
# 2021-05-18 09:02:14+00:00 Creating Container Registry if not exists.
# 2021-05-18 09:02:14+00:00 Registering the environment.
# 2021-05-18 09:02:15+00:00 Use the existing image.
# 2021-05-18 09:02:18+00:00 Creating resources in AKS..
# 2021-05-18 09:02:21+00:00 Submitting deployment to compute.
# 2021-05-18 09:02:22+00:00 Checking the status of deployment automl-image-test..
# 2021-05-18 09:03:12+00:00 Checking the status of inference endpoint automl-image-test.
# Succeeded
# AKS service creation operation finished, operation "Succeeded"
# Healthy

# %% [markdown]
# ## Test the web service
# Finally, let's test our deployed web service to predict new images. You can pass in any image. In this case, we'll use a random image from the dataset and pass it to te scoring URI.

# %%
import requests

# URL for the web service
scoring_uri = aks_service.scoring_uri

# If the service is authenticated, set the key or token
key, _ = aks_service.get_keys()

sample_image = './drinks.jpg'

# Load image data
data = open(sample_image, 'rb').read()

# Set the content type
headers = {'Content-Type': 'application/octet-stream'}

# If authentication is enabled, set the authorization header
headers['Authorization'] = f'Bearer {key}'

# Make the request and display the response
resp = requests.post(scoring_uri, data, headers=headers)

# %%
print(resp.text)
# Out:
# {"filename": "/tmp/tmp62tv51_o", "boxes": [{"box": {"topX": 0.7003984069824218, "topY": 0.4969247891283974, "bottomX": 0.9322698974609375, "bottomY": 0.8033094897712629}, "label": "can", "score": 0.998526930809021, "polygon": [[0.8525, 0.8031865042174321, 0.755, 0.8022492970946579, 0.74875, 0.7994376757263355, 0.745, 0.795688847235239, 0.72875, 0.7891283973758201, 0.725, 0.7835051546391752, 0.7175, 0.7797563261480788, 0.7125, 0.7722586691658857, 0.70375, 0.7656982193064668, 0.70125, 0.7600749765698219, 0.70125, 0.5688847235238987, 0.71, 0.5445173383317713, 0.7225, 0.528584817244611, 0.72625, 0.5182755388940956, 0.735, 0.507029053420806, 0.745, 0.49953139643861294, 0.75125, 0.49765698219306465, 0.8475, 0.4967197750702905, 0.86125, 0.4985941893158388, 0.87375, 0.5042174320524836, 0.895, 0.5079662605435802, 0.9125, 0.5201499531396439, 0.93125, 0.5595126522961574, 0.9325, 0.6044985941893158, 0.925, 0.6279287722586692, 0.92375, 0.6457357075913777, 0.9175, 0.662605435801312, 0.915, 0.6879100281162137, 0.91, 0.6982193064667291, 0.9075, 0.7216494845360825, 0.9025, 0.7338331771321462, 0.89875, 0.761012183692596, 0.89125, 0.7778819119025304, 0.88375, 0.7835051546391752, 0.88, 0.7891283973758201, 0.87, 0.7938144329896907, 0.8625, 0.8003748828491096, 0.8525, 0.8031865042174321]]}, {"box": {"topX": 0.2262286376953125, "topY": 0.2922858655620314, "bottomX": 0.3973850250244141, "bottomY": 0.6054883704860298}, "label": "milk_bottle", "score": 0.9976707100868225, "polygon": [[0.355, 0.60543580131209, 0.2825, 0.6044985941893158, 0.265, 0.5895032802249297, 0.26125, 0.5754451733833177, 0.2575, 0.5688847235238987, 0.25625, 0.5548266166822868, 0.2525, 0.5463917525773195, 0.25, 0.5323336457357076, 0.25, 0.4742268041237113, 0.24375, 0.4526710402999063, 0.2375, 0.4442361761949391, 0.2275, 0.4208059981255858, 0.22875, 0.40674789128397376, 0.2325, 0.39550140581068416, 0.2375, 0.3898781630740394, 0.23875, 0.38425492033739456, 0.245, 0.37488284910965325, 0.245, 0.3626991565135895, 0.23875, 0.3477038425492034, 0.235, 0.3430178069353327, 0.24, 0.30740393626991563, 0.2475, 0.2952202436738519, 0.25125, 0.2933458294283037, 0.31625, 0.2924086223055295, 0.325, 0.29615745079662603, 0.335, 0.3083411433926898, 0.345, 0.33083411433926896, 0.3475, 0.3392689784442362, 0.34375, 0.35238987816307404, 0.34625, 0.36457357075913777, 0.355, 0.37300843486410495, 0.3575, 0.3776944704779756, 0.37, 0.3851921274601687, 0.37875, 0.3983130271790066, 0.37875, 0.47703842549203374, 0.39, 0.5014058106841612, 0.3925, 0.5154639175257731, 0.39625, 0.5238987816307404, 0.3975, 0.5754451733833177, 0.395, 0.5810684161199625, 0.38125, 0.5932521087160263, 0.37, 0.5960637300843487, 0.3625, 0.6035613870665417, 0.355, 0.60543580131209]]}, {"box": {"topX": 0.4348393249511719, "topY": 0.2778796237992034, "bottomX": 0.621207275390625, "bottomY": 0.679865114020765}, "label": "water_bottle", "score": 0.9939553141593933, "polygon": [[0.57125, 0.6804123711340206, 0.54625, 0.6785379568884724, 0.52625, 0.6804123711340206, 0.50125, 0.6804123711340206, 0.48625, 0.6785379568884724, 0.47125, 0.6672914714151827, 0.46, 0.6616682286785379, 0.45625, 0.6569821930646673, 0.44875, 0.6391752577319587, 0.44125, 0.5641986879100281, 0.44, 0.5107778819119025, 0.435, 0.48828491096532334, 0.435, 0.42736644798500467, 0.44375, 0.41705716963448924, 0.4475, 0.4095595126522962, 0.4575, 0.4029990627928772, 0.46125, 0.3936269915651359, 0.46625, 0.38706654170571697, 0.46875, 0.3711340206185567, 0.47, 0.33270852858481725, 0.4675, 0.31115276476101217, 0.4675, 0.2849109653233365, 0.4725, 0.2802249297094658, 0.4775, 0.27835051546391754, 0.55125, 0.2774133083411434, 0.56375, 0.27928772258669166, 0.5675, 0.28116213683223995, 0.57, 0.2849109653233365, 0.57125, 0.2952202436738519, 0.57, 0.33270852858481725, 0.57375, 0.3486410496719775, 0.575, 0.3711340206185567, 0.58375, 0.3898781630740394, 0.59, 0.39550140581068416, 0.59625, 0.40487347703842547, 0.60625, 0.4114339268978444, 0.615, 0.42549203373945643, 0.61875, 0.45735707591377694, 0.61625 ...

# %% [markdown]
# ## Visualize predictions
# Now that we have scored a test image, we can visualize the predictions for this image

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
from matplotlib.lines import Line2D
from PIL import Image
import numpy as np
import json

IMAGE_SIZE = (18,12)
plt.figure(figsize=IMAGE_SIZE)
img_np=mpimg.imread(sample_image)
img = Image.fromarray(img_np.astype('uint8'),'RGB')
x, y = img.size

fig,ax = plt.subplots(1, figsize=(15,15))
# Display the image
ax.imshow(img_np)

# draw box and label for each detection 
detections = json.loads(resp.text)
for detect in detections['boxes']:
    label = detect['label']
    box = detect['box']
    polygon = detect['polygon']
    conf_score = detect['score']
    if conf_score > 0.6:
        ymin, xmin, ymax, xmax =  box['topY'],box['topX'], box['bottomY'],box['bottomX']
        topleft_x, topleft_y = x * xmin, y * ymin
        width, height = x * (xmax - xmin), y * (ymax - ymin)
        print('{}: [{}, {}, {}, {}], {}'.format(detect['label'], round(topleft_x, 3), 
                                                round(topleft_y, 3), round(width, 3), 
                                                round(height, 3), round(conf_score, 3)))

        color = 'blue'
        rect = patches.Rectangle((topleft_x, topleft_y), width, height, 
                                 linewidth=2, edgecolor=color,facecolor='none')

        ax.add_patch(rect)
        plt.text(topleft_x, topleft_y - 10, label, color=color, fontsize=20)
        
        polygon_np = np.array(polygon[0])
        polygon_np = polygon_np.reshape(-1, 2)
        polygon_np[:, 0] *= x
        polygon_np[:, 1] *= y
        poly = patches.Polygon(polygon_np, True, facecolor=color, alpha=0.4)
        ax.add_patch(poly)
        poly_line = Line2D(polygon_np[:, 0], polygon_np[:, 1], linewidth=2,
                           marker='o', markersize=8, markerfacecolor=color)
        ax.add_line(poly_line)

plt.show()
# Out:
# can: [349.499, 330.952, 115.704, 204.052], 0.999
# milk_bottle: [112.888, 194.662, 85.407, 208.593], 0.998
# water_bottle: [216.985, 185.068, 92.998, 267.722], 0.994

# %%
# Let's delete our Azure ML GPU compute cluster
compute_target.delete()
# Let's delete the service
aks_service.delete()
